# %% [markdown]
# # Association rule mining
#
# In this notebook, you'll implement the basic pairwise association rule mining algorithm.
#
# To keep the implementation simple, you will apply your implementation to a simplified dataset, namely, letters ("items") in words ("receipts" or "baskets").

# %% [markdown]
# ## Problem definition
#
# Let's say you have a fragment of text in some language. You wish to know whether there are association rules among the letters that appear in a word. In this problem:
#
# - Words are "receipts"
# - Letters within a word are "items"
#
# You want to know whether there are _association rules_ of the form, $a \implies b$, where $a$ and $b$ are letters. You will write code to do that by calculating for each rule its _confidence_, $\mathrm{conf}(a \implies b)$, which is an estimate of the conditional probability of $b$ given $a$, or $\mathrm{Pr}[b \,|\, a]$.

# %% [markdown]
# ## Sample text input
#
# Let's carry out this analysis on a "dummy" text fragment, which graphic designers refer to as the [_lorem ipsum_](https://en.wikipedia.org/wiki/Lorem_ipsum):

# %%
latin_text = """
Sed ut perspiciatis, unde omnis iste natus error sit
voluptatem accusantium doloremque laudantium, totam
rem aperiam eaque ipsa, quae ab illo inventore
veritatis et quasi architecto beatae vitae dicta
sunt, explicabo. Nemo enim ipsam voluptatem, quia
voluptas sit, aspernatur aut odit aut fugit, sed
quia consequuntur magni dolores eos, qui ratione
voluptatem sequi nesciunt, neque porro quisquam est,
qui dolorem ipsum, quia dolor sit amet consectetur
adipisci[ng] velit, sed quia non numquam [do] eius
modi tempora inci[di]dunt, ut labore et dolore
magnam aliquam quaerat voluptatem. Ut enim ad minima
veniam, quis nostrum exercitationem ullam corporis
suscipit laboriosam, nisi ut aliquid ex ea commodi
consequatur? Quis autem vel eum iure reprehenderit,
qui in ea voluptate velit esse, quam nihil molestiae
consequatur, vel illum, qui dolorem eum fugiat, quo
voluptas nulla pariatur?

At vero eos et accusamus et iusto odio dignissimos
ducimus, qui blanditiis praesentium voluptatum
deleniti atque corrupti, quos dolores et quas
molestias excepturi sint, obcaecati cupiditate non
provident, similique sunt in culpa, qui officia
deserunt mollitia animi, id est laborum et dolorum
fuga. Et harum quidem rerum facilis est et expedita
distinctio. Nam libero tempore, cum soluta nobis est
eligendi optio, cumque nihil impedit, quo minus id,
quod maxime placeat, facere possimus, omnis voluptas
assumenda est, omnis dolor repellendus. Temporibus
autem quibusdam et aut officiis debitis aut rerum
necessitatibus saepe eveniet, ut et voluptates
repudiandae sint et molestiae non recusandae. Itaque
earum rerum hic tenetur a sapiente delectus, ut aut
reiciendis voluptatibus maiores alias consequatur
aut perferendis doloribus asperiores repellat.
"""

print("First 100 characters:\n  {} ...".format(latin_text[:100]))
# Out:
# First 100 characters:
#
# Sed ut perspiciatis, unde omnis iste natus error sit
# voluptatem accusantium doloremque laudantium,  ...

# %% [markdown]
# **Exercise 0** (ungraded). Look up and read the translation of _lorem ipsum_!

# %% [markdown]
# **Data cleaning.** Like most data in the real world, this dataset is noisy. It has both uppercase and lowercase letters, words have repeated letters, and there are all sorts of non-alphabetic characters. For our analysis, we should keep all the letters and spaces (so we can identify distinct words), but we should ignore case and ignore repetition within a word.
#
# For example, the eighth word of this text is "error." As an _itemset_, it consists of the three unique letters, $\{e, o, r\}$. That is, treat the word as a set, meaning you only keep the unique letters.
#
# This itemset has six possible _itempairs_: $\{e, o\}$, $\{e, r\}$, and $\{o, r\}$.
#
# Start by writing some code to help "clean up" the input.

# %% [markdown]
# **Exercise 1** (`normalize_string_test`: 2 points). Complete the following function, `normalize_string(s)`, which should take a string (`str` object) `s` as input and returns a new string with all characters converted to lowercase and all non-alphabetic, non-space characters removed.
#
# > Scanning the sample text, `latin_text`, you may see things that look like special cases. For instance, `inci[di]dunt` and `[do]`. For these, simply remove the non-alphabetic characters and only separate the words if there is explicit whitespace.
# >
# > For instance, `inci[di]dunt` would become `incididunt` (as a single word) and `[do]` would become `do` as a standalone word because the original string has whitespace on either side. A period or comma without whitespace would, similarly, just be treated as a non-alphabetic character inside a word _unless_ there is explicit whitespace. So `e pluribus.unum basium` would become `e pluribusunum basium` even though your common-sense understanding might separate `pluribus` and `unum`.

# %%
import re
def normalize_string(s):
 '''   assert type (s) is str
    s=s.lower()
    print(s)
    regex = re.compile('[^a-zA-Z\s]')
    t=regex.sub('', s)

    return(t)'''
#
# YOUR CODE HERE
#
'''    initial=s.lower()
    final=""
    for i in initial:
        if i.isalpha()==True or i.isspace()==True:
            final = final+i
    return final '''
    
import re
def normalize_string(s):
    assert type (s) is str
    t=''
    s=s.lower()
    for i in s:
        if i.isalpha() or i.isspace():
            t=t+i
    return t

# Demo:
print(latin_text[:100], "...\n=>", normalize_string(latin_text[:100]), "...")
# Out:
# Sed ut perspiciatis, unde omnis iste natus error sit
# voluptatem accusantium doloremque laudantium,  ...
# =>
# sed ut perspiciatis unde omnis iste natus error sit
# voluptatem accusantium doloremque laudantium  ...

# %%
# `normalize_string_test`: Test cell
norm_latin_text = normalize_string(latin_text)

assert type(norm_latin_text) is str
assert len(norm_latin_text) == 1694
assert all([c.isalpha() or c.isspace() for c in norm_latin_text])
assert norm_latin_text == norm_latin_text.lower()

print("\n(Passed!)")
# Out:
# (Passed!)

# %% [markdown]
# **Exercise 2** (`get_normalized_words_test`: 1 point). Implement the following function, `get_normalized_words(s)`: given a string (`str` object) `s`, returns a list of its words, normalized per the definition of `normalize_string()`.

# %%
def get_normalized_words (s):
    assert type (s) is str
#
# YOUR CODE HERE
#
    '''initial=s.lower()
    final=""
    for i in initial:
        if i.isalpha()==True or i.isspace()==True:
            final = final+i
    return final.split() '''
    
    t=''
    s=s.lower()
    s=s.split()
    t=[i for i in s if i.isalpha() or i.isspace()]
    return t
# Demo:
print ("First five words:\n{}".format (get_normalized_words (latin_text)[:5]))
# Out:
# First five words:
# ['sed', 'ut', 'unde', 'omnis', 'iste']

# %%
# `get_normalized_words_test`: Test cell
norm_latin_words = get_normalized_words(norm_latin_text)

assert len(norm_latin_words) == 250
for i, w in [(20, 'illo'), (73, 'eius'), (144, 'deleniti'), (248, 'asperiores')]:
    assert norm_latin_words[i] == w

print ("\n(Passed.)")
# Out:
# (Passed.)

# %% [markdown]
# **Exercise 3** (`make_itemsets_test`: 2 points). Implement a function, `make_itemsets`, that given a list of strings converts the characters of each string into an itemset, returning the list of itemsets.

# %%
def make_itemsets(words):
    l=[]
    for i in words:
        c=[]
        for j in i:
            c.append(j)
        itemset=set(c)
        l.append(itemset)
    
    return(l)
#
# YOUR CODE HERE
#
'''    itemset=[]
    for i in words:
        names=[]
        for j in i: 
            if j not in names:
                names.append(j)
        names=set(names)
        itemset.append(names)
            
    return itemset'''
    
words=['sed', 'ut', 'unde', 'omnis', 'iste']
print(make_itemsets(words))
# Out:
# [{'d', 'e', 's'}, {'u', 't'}, {'d', 'u', 'n', 'e'}, {'m', 'o', 's', 'n', 'i'}, {'e', 'i', 's', 't'}]

# %%
# `make_itemsets_test`: Test cell
norm_latin_itemsets = make_itemsets(norm_latin_words)

# Lists should have the same size
assert len(norm_latin_itemsets) == len(norm_latin_words)

# Test a random sample
from random import sample
for i in sample(range(len(norm_latin_words)), 5):
    print('[{}]'.format(i), norm_latin_words[i], "-->", norm_latin_itemsets[i])
    assert set(norm_latin_words[i]) == norm_latin_itemsets[i]
print("\n(Passed!)")
# Out:
# [20] illo --> {'o', 'i', 'l'}
# [227] molestiae --> {'t', 'm', 'o', 's', 'i', 'l', 'a', 'e'}
# [189] eligendi --> {'n', 'i', 'l', 'd', 'e', 'g'}
# [22] veritatis --> {'r', 't', 'v', 's', 'i', 'a', 'e'}
# [231] earum --> {'m', 'a', 'e', 'r', 'u'}
#
# (Passed!)

# %% [markdown]
# ## Implementing the basic algorithm
#
# Recall the pseudocode for the algorithm that Rachel and Rich derived together:
#
# ![FindAssocRules (pseudocode)](https://ndownloader.figshare.com/files/7635700?private_link=3c473609741895a5cc2c)
#
# In the following series of exercises, let's implement this method. We'll build it "bottom-up," first defining small pieces and working our way toward the complete algorithm. This method allows us to test each piece before combining them.
#
# Observe that the bulk of the work in this procedure is just updating these tables, $T$ and $C$. So your biggest implementation decision is how to store those. A good choice is to use a dictionary

# %% [markdown]
# ## Aside: Default dictionaries
#
# Recall that the overall algorithm requires maintaining a table of item-pair (tuples) counts. It would be convenient to use a dictionary to store this table, where keys refer to item-pairs and the values are the counts.
#
# However, with Python's built-in dictionaries, you always to have to check whether a key exists before updating it. For example, consider this code fragment:
#
# ```python
# D = {'existing-key': 5} # Dictionary with one key-value pair
#
# D['existing-key'] += 1 # == 6
# D['new-key'] += 1  # Error: 'new-key' does not exist!
# ```
#
# The second attempt causes an error because `'new-key'` is not yet a member of the dictionary. So, a more correct approach would be to do the following:
#
# ```python
# D = {'existing-key': 5} # Dictionary with one key-value pair
#
# if 'existing-key' not in D:
#     D['existing-key'] = 0
# D['existing-key'] += 1
#
# if 'new-key' not in D:
#     D['new-key'] = 0
# D['new-key'] += 1
# ```
#
# This pattern is so common that there is a special form of dictionary, called a _default dictionary_, which is available from the `collections` module: [`collections.defaultdict`](https://docs.python.org/3/library/collections.html?highlight=defaultdict#collections.defaultdict).
#
# When you create a default dictionary, you need to provide a "factory" function that the dictionary can use to create an initial value when the key does *not* exist. For instance, in the preceding example, when the key was not present the code creates a new key with the initial value of an integer zero (0). Indeed, this default value is the one you get when you call `int()` with no arguments:

# %%
print (int ())
# Out:
# 0

# %%
from collections import defaultdict

D2 = defaultdict (int) # Empty dictionary

D2['existing-key'] = 5 # Create one key-value pair

D2['existing-key'] += 1 # Update
D2['new-key'] += 1

print (D2)
# Out:
# defaultdict(<class 'int'>, {'new-key': 1, 'existing-key': 6})

# %% [markdown]
# **Exercise 4** (`update_pair_counts_test`: 2 points). Start by implementing a function that enumerates all item-pairs within an itemset and updates a table in-place that tracks the counts of those item-pairs.
#
# You may assume all items in the given itemset (`itemset` argument) are distinct, i.e., that you may treat it as you would any set-like collection. You may also assume `pair_counts` is a default dictionary.

# %%
from collections import defaultdict
from itertools import combinations # Hint!

def update_pair_counts (pair_counts, itemset):
    """
    Updates a dictionary of pair counts for
    all pairs of items in a given itemset.
    """
    assert type (pair_counts) is defaultdict

#
# YOUR CODE HERE
#

    '''data=list(combinations(itemset, 2))
    data2=[(t[1], t[0]) for t in data]
    for i in data:
        pair_counts[i]+=1
    for j in data2:
        pair_counts[j]+=1
    return pair_counts '''
    
    for i,j in combinations(itemset,2):
        pair_counts[i,j]+=1
        pair_counts[j,i]+=1
    return pair_counts

# %%
# `update_pair_counts_test`: Test cell
itemset_1 = set("error")
itemset_2 = set("dolor")
pair_counts = defaultdict(int)

update_pair_counts(pair_counts, itemset_1)
assert len(pair_counts) == 6
update_pair_counts(pair_counts, itemset_2)
assert len(pair_counts) == 16

print('"{}" + "{}"\n==> {}'.format (itemset_1, itemset_2, pair_counts))
for a, b in pair_counts:
    assert (b, a) in pair_counts
    assert pair_counts[(a, b)] == pair_counts[(b, a)]
    
print ("\n(Passed!)")
# Out:
# "{'o', 'e', 'r'}" + "{'d', 'o', 'r', 'l'}"
# ==> defaultdict(<class 'int'>, {('o', 'e'): 1, ('d', 'o'): 1, ('o', 'l'): 1, ('o', 'r'): 2, ('e', 'r'): 1, ('e', 'o'): 1, ('r', 'l'): 1, ('l', 'o'): 1, ('d', 'r'): 1, ('r', 'o'): 2, ('r', 'd'): 1, ('r', 'e'): 1, ('l', 'r'): 1, ('d', 'l'): 1, ('o', 'd'): 1, ('l', 'd'): 1})
#
# (Passed!)

# %% [markdown]
# **Exercise 5** (`update_item_counts_test`: 2 points). Implement a procedure that, given an itemset, updates a table to track counts of each item.
#
# As with the previous exercise, you may assume all items in the given itemset (`itemset`) are distinct, i.e., that you may treat it as you would any set-like collection. You may also assume the table (`item_counts`) is a default dictionary.

# %%
def update_item_counts(item_counts, itemset):
#
# YOUR CODE HERE
#
    '''for i in itemset:
        item_counts[i]+=1
    return item_counts'''
    for i in itemset:
        item_counts[i]+=1
    return item_counts

# %%
# `update_item_counts_test`: Test cell
itemset_1 = set("error")
itemset_2 = set("dolor")

item_counts = defaultdict(int)
update_item_counts(item_counts, itemset_1)
assert len(item_counts) == 3
update_item_counts(item_counts, itemset_2)
assert len(item_counts) == 5

assert item_counts['d'] == 1
assert item_counts['e'] == 1
assert item_counts['l'] == 1
assert item_counts['o'] == 2
assert item_counts['r'] == 2

print("\n(Passed!)")
# Out:
# (Passed!)

# %% [markdown]
# **Exercise 6** (`filter_rules_by_conf_test`: 2 points). Given tables of item-pair counts and individual item counts, as well as a confidence threshold, return the rules that meet the threshold. The returned rules should be in the form of a dictionary whose key is the tuple, $(a, b)$ corresponding to the rule $a \Rightarrow b$, and whose value is the confidence of the rule, $\mathrm{conf}(a \Rightarrow b)$.
#
# You may assume that if $(a, b)$ is in the table of item-pair counts, then both $a$ and $b$ are in the table of individual item counts.

# %%
def filter_rules_by_conf (pair_counts, item_counts, threshold):
    rules = {} # (item_a, item_b) -> conf (item_a => item_b)
#
# YOUR CODE HERE
#

    
    '''for (i,j) in pair_counts.keys():
        if item_counts[i]>0:
            chance=pair_counts[(i,j)]/item_counts[i]
            if chance>=threshold:
                rules[(i,j)]=chance
        
    return rules'''
    
    for (i,j) in pair_counts:
        assert i in item_counts
        conf_ab=pair_counts[(i,j)]/item_counts[i]
        if conf_ab>=threshold:
            rules[(i,j)]=conf_ab
        
    return rules

# %%
# `filter_rules_by_conf_test`: Test cell
pair_counts = {('man', 'woman'): 5,
               ('bird', 'bee'): 3,
               ('red fish', 'blue fish'): 7}
item_counts = {'man': 7,
               'bird': 9,
               'red fish': 11}
rules = filter_rules_by_conf (pair_counts, item_counts, 0.5)
print("Found these rules:", rules)
assert ('man', 'woman') in rules
assert ('bird', 'bee') not in rules
assert ('red fish', 'blue fish') in rules
print("\n(Passed!)")
# Out:
# Found these rules: {('man', 'woman'): 0.7142857142857143, ('red fish', 'blue fish'): 0.6363636363636364}
#
# (Passed!)

# %% [markdown]
# **Aside: pretty printing the rules.** The output of rules above is a little messy; here's a little helper function that structures that output a little, which will be useful for both debugging and reporting purposes.

# %%
def gen_rule_str(a, b, val=None, val_fmt='{:.3f}', sep=" = "):
    text = "{} => {}".format(a, b)
    if val:
        text = "conf(" + text + ")"
        text += sep + val_fmt.format(val)
    return text

def print_rules(rules):
    if type(rules) is dict or type(rules) is defaultdict:
        from operator import itemgetter
        ordered_rules = sorted(rules.items(), key=itemgetter(1), reverse=True)
    else: # Assume rules is iterable
        ordered_rules = [((a, b), None) for a, b in rules]
    for (a, b), conf_ab in ordered_rules:
        print(gen_rule_str(a, b, conf_ab))

# Demo:
print_rules(rules)
# Out:
# conf(man => woman) = 0.714
# conf(red fish => blue fish) = 0.636

# %% [markdown]
# **Exercise 7** (`find_assoc_rules_test`: 3 points). Using the building blocks you implemented above, complete a function `find_assoc_rules` so that it implements the basic association rule mining algorithm and returns a dictionary of rules.
#
# In particular, your implementation may assume the following:
#
# 1. As indicated in its signature, below, the function takes two inputs: `receipts` and `threshold`.
# 1. The input, `receipts`, is a collection of itemsets: for every receipt `r` in `receipts`, `r` may be treated as a collection of unique items.
# 2. The input `threshold` is the minimum desired confidence value. That is, the function should only return rules whose confidence is at least `threshold`.
#
# The returned dictionary, `rules`, should be keyed by tuples $(a, b)$ corresponding to the rule $a \Rightarrow b$; each value should the the confidence $\mathrm{conf}(a \Rightarrow b)$ of the rule.

# %%
def find_assoc_rules(receipts, threshold):
#
# YOUR CODE HERE
#
    

    pair_counts=defaultdict(int)
    item_counts=defaultdict(int)
    for i in receipts:
        pair= update_pair_counts (pair_counts,i)
        print(pair)
        item=update_item_counts(item_counts, i)
        rule=filter_rules_by_conf (pair, item, threshold)
        
    return rule

# %%
# `find_assoc_rules_test`: Test cell
receipts = [set('abbc'), set('ac'), set('a')]
rules = find_assoc_rules(receipts, 0.6)

print("Original receipts as itemsets:", receipts)
print("Resulting rules:")
print_rules(rules)

assert ('a', 'b') not in rules
assert ('b', 'a') in rules
assert ('a', 'c') in rules
assert ('c', 'a') in rules
assert ('b', 'c') in rules
assert ('c', 'b') not in rules

print("\n(Passed!)")
# Out:
# defaultdict(<class 'int'>, {('c', 'a'): 1, ('b', 'a'): 1, ('a', 'c'): 1, ('a', 'b'): 1, ('b', 'c'): 1, ('c', 'b'): 1})
# defaultdict(<class 'int'>, {('c', 'a'): 2, ('b', 'a'): 1, ('a', 'c'): 2, ('a', 'b'): 1, ('b', 'c'): 1, ('c', 'b'): 1})
# defaultdict(<class 'int'>, {('c', 'a'): 2, ('b', 'a'): 1, ('a', 'c'): 2, ('a', 'b'): 1, ('b', 'c'): 1, ('c', 'b'): 1})
# Original receipts as itemsets: [{'c', 'a', 'b'}, {'a', 'c'}, {'a'}]
# Resulting rules:
# conf(b => a) = 1.000
# conf(b => c) = 1.000
# conf(c => a) = 1.000
# conf(a => c) = 0.667
#
# (Passed!)

# %% [markdown]
# **Exercise 8** (`latin_rules_test`: 2 points). For the Latin string, `latin_text`, use your `find_assoc_rules()` function to compute the rules whose confidence is at least 0.75. Store your result in a variable named `latin_rules`.

# %%
# Generate `latin_rules`:
#
# YOUR CODE HERE
#
a=get_normalized_words(latin_text)
b=make_itemsets(a)
latin_rules=find_assoc_rules(b,.75)
print_rules(latin_rules)
# Out:
# defaultdict(<class 'int'>, {('e', 'd'): 1, ('d', 's'): 1, ('s', 'e'): 1, ('d', 'e'): 1, ('e', 's'): 1, ('s', 'd'): 1})
# defaultdict(<class 'int'>, {('e', 'd'): 1, ('t', 'u'): 1, ('d', 's'): 1, ('s', 'e'): 1, ('u', 't'): 1, ('d', 'e'): 1, ('e', 's'): 1, ('s', 'd'): 1})
# defaultdict(<class 'int'>, {('e', 'd'): 2, ('d', 'u'): 1, ('t', 'u'): 1, ('u', 'n'): 1, ('s', 'e'): 1, ('n', 'u'): 1, ('u', 't'): 1, ('u', 'e'): 1, ('d', 'e'): 2, ('n', 'e'): 1, ('e', 'n'): 1, ('d', 's'): 1, ('n', 'd'): 1, ('d', 'n'): 1, ('s', 'd'): 1, ('u', 'd'): 1, ('e', 's'): 1, ('e', 'u'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 1, ('e', 'd'): 2, ('n', 'o'): 1, ('s', 'n'): 1, ('n', 'i'): 1, ('n', 'm'): 1, ('u', 'd'): 1, ('d', 's'): 1, ('d', 'e'): 2, ('u', 'e'): 1, ('m', 'i'): 1, ('i', 'o'): 1, ('n', 'u'): 1, ('o', 'i'): 1, ('u', 'n'): 1, ('o', 's'): 1, ('e', 'u'): 1, ('i', 'n'): 1, ('d', 'u'): 1, ('m', 's'): 1, ('t', 'u'): 1, ('o', 'm'): 1, ('u', 't'): 1, ('s', 'i'): 1, ('s', 'd'): 1, ('m', 'o'): 1, ('n', 'e'): 1, ('o', 'n'): 1, ('e', 'n'): 1, ('m', 'n'): 1, ('s', 'e'): 1, ('n', 'd'): 1, ('i', 's'): 1, ('d', 'n'): 1, ('n', 's'): 1, ('s', 'o'): 1, ('e', 's'): 1, ('s', 'm'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 1, ('e', 'd'): 2, ('i', 'o'): 1, ('t', 'i'): 1, ('u', 'd'): 1, ('i', 'e'): 1, ('n', 'o'): 1, ('d', 'e'): 2, ('u', 'e'): 1, ('m', 'i'): 1, ('s', 't'): 1, ('e', 's'): 2, ('o', 'i'): 1, ('u', 'n'): 1, ('o', 's'): 1, ('t', 'u'): 1, ('o', 'm'): 1, ('i', 't'): 1, ('m', 'o'): 1, ('n', 'e'): 1, ('t', 's'): 1, ('s', 'n'): 1, ('n', 'd'): 1, ('i', 's'): 2, ('n', 's'): 1, ('e', 'i'): 1, ('n', 'm'): 1, ('m', 'n'): 1, ('s', 'd'): 1, ('t', 'e'): 1, ('n', 'u'): 1, ('e', 'u'): 1, ('s', 'o'): 1, ('d', 'u'): 1, ('m', 's'): 1, ('s', 'e'): 2, ('u', 't'): 1, ('s', 'i'): 2, ('i', 'n'): 1, ('o', 'n'): 1, ('e', 'n'): 1, ('e', 't'): 1, ('d', 's'): 1, ('d', 'n'): 1, ('n', 'i'): 1, ('s', 'm'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 1, ('e', 'd'): 2, ('i', 'o'): 1, ('n', 't'): 1, ('t', 'i'): 1, ('u', 'd'): 1, ('i', 'e'): 1, ('n', 'o'): 1, ('d', 'e'): 2, ('u', 'e'): 1, ('s', 'u'): 1, ('m', 'i'): 1, ('s', 't'): 2, ('e', 's'): 2, ('o', 'i'): 1, ('u', 'n'): 2, ('o', 's'): 1, ('a', 'n'): 1, ('u', 's'): 1, ('t', 'u'): 2, ('o', 'm'): 1, ('i', 't'): 1, ('m', 'o'): 1, ('a', 'u'): 1, ('n', 'e'): 1, ('t', 's'): 2, ('t', 'a'): 1, ('t', 'n'): 1, ('s', 'n'): 2, ('n', 'd'): 1, ('i', 's'): 2, ('n', 's'): 2, ('e', 'i'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('m', 'n'): 1, ('s', 'a'): 1, ('a', 's'): 1, ('s', 'd'): 1, ('t', 'e'): 1, ('n', 'u'): 2, ('n', 'a'): 1, ('e', 'u'): 1, ('s', 'o'): 1, ('d', 'u'): 1, ('u', 'a'): 1, ('m', 's'): 1, ('s', 'e'): 2, ('u', 't'): 2, ('s', 'i'): 2, ('i', 'n'): 1, ('o', 'n'): 1, ('e', 'n'): 1, ('e', 't'): 1, ('d', 's'): 1, ('d', 'n'): 1, ('n', 'i'): 1, ('s', 'm'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 1, ('e', 'd'): 2, ('r', 'o'): 1, ('i', 'o'): 1, ('n', 't'): 1, ('t', 'i'): 1, ('u', 'd'): 1, ('i', 'e'): 1, ('n', 'o'): 1, ('d', 'e'): 2, ('u', 'e'): 1, ('s', 'u'): 1, ('m', 'i'): 1, ('s', 't'): 2, ('e', 'o'): 1, ('e', 's'): 2, ('o', 'i'): 1, ('u', 'n'): 2, ('r', 'e'): 1, ('o', 's'): 1, ('o', 'e'): 1, ('a', 'n'): 1, ('u', 's'): 1, ('t', 'u'): 2, ('o', 'm'): 1, ('o', 'r'): 1, ('i', 't'): 1, ('m', 'o'): 1, ('a', 'u'): 1, ('n', 'e'): 1, ('t', 's'): 2, ('t', 'a'): 1, ('t', 'n'): 1, ('s', 'n'): 2, ('n', 'd'): 1, ('i', 's'): 2, ('n', 's'): 2, ('e', 'i'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('e', 'r'): 1, ('m', 'n'): 1, ('s', 'a'): 1, ('a', 's'): 1, ('s', 'd'): 1, ('t', 'e'): 1, ('n', 'u'): 2, ('n', 'a'): 1, ('e', 'u'): 1, ('s', 'o'): 1, ('d', 'u'): 1, ('u', 'a'): 1, ('m', 's'): 1, ('s', 'e'): 2, ('u', 't'): 2, ('s', 'i'): 2, ('i', 'n'): 1, ('o', 'n'): 1, ('e', 'n'): 1, ('e', 't'): 1, ('d', 's'): 1, ('d', 'n'): 1, ('n', 'i'): 1, ('s', 'm'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 1, ('e', 'd'): 2, ('r', 'o'): 1, ('i', 'o'): 1, ('n', 't'): 1, ('t', 'i'): 2, ('u', 'd'): 1, ('i', 'e'): 1, ('n', 'o'): 1, ('d', 'e'): 2, ('u', 'e'): 1, ('s', 'u'): 1, ('m', 'i'): 1, ('s', 't'): 3, ('e', 'o'): 1, ('e', 's'): 2, ('o', 'i'): 1, ('u', 'n'): 2, ('r', 'e'): 1, ('o', 's'): 1, ('o', 'e'): 1, ('a', 'n'): 1, ('u', 's'): 1, ('t', 'u'): 2, ('o', 'm'): 1, ('o', 'r'): 1, ('i', 't'): 2, ('m', 'o'): 1, ('a', 'u'): 1, ('n', 'e'): 1, ('t', 's'): 3, ('t', 'a'): 1, ('t', 'n'): 1, ('s', 'n'): 2, ('n', 'd'): 1, ('i', 's'): 3, ('n', 's'): 2, ('e', 'i'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('e', 'r'): 1, ('m', 'n'): 1, ('s', 'a'): 1, ('a', 's'): 1, ('s', 'd'): 1, ('t', 'e'): 1, ('n', 'u'): 2, ('n', 'a'): 1, ('e', 'u'): 1, ('s', 'o'): 1, ('d', 'u'): 1, ('u', 'a'): 1, ('m', 's'): 1, ('s', 'e'): 2, ('u', 't'): 2, ('s', 'i'): 3, ('i', 'n'): 1, ('o', 'n'): 1, ('e', 'n'): 1, ('e', 't'): 1, ('d', 's'): 1, ('d', 'n'): 1, ('n', 'i'): 1, ('s', 'm'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 1, ('p', 'e'): 1, ('i', 'o'): 1, ('l', 'e'): 1, ('u', 'd'): 1, ('i', 'e'): 1, ('d', 'e'): 2, ('u', 'e'): 2, ('s', 'u'): 1, ('e', 'a'): 1, ('u', 'o'): 1, ('t', 'p'): 1, ('o', 'i'): 1, ('a', 'm'): 1, ('t', 'n'): 1, ('n', 'i'): 1, ('l', 'a'): 1, ('a', 'n'): 1, ('u', 's'): 1, ('t', 'u'): 3, ('m', 'n'): 1, ('i', 't'): 2, ('n', 'e'): 1, ('r', 'o'): 1, ('m', 'u'): 1, ('s', 'n'): 2, ('o', 'l'): 1, ('n', 'd'): 1, ('v', 'o'): 1, ('p', 'm'): 1, ('e', 'l'): 1, ('p', 't'): 1, ('v', 'e'): 1, ('a', 'u'): 2, ('p', 'o'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('u', 'p'): 1, ('n', 'u'): 2, ('l', 'u'): 1, ('l', 'm'): 1, ('e', 'u'): 2, ('s', 'o'): 1, ('m', 'a'): 1, ('u', 'a'): 2, ('m', 's'): 1, ('e', 'i'): 1, ('t', 'm'): 1, ('e', 'o'): 2, ('a', 'p'): 1, ('a', 'e'): 1, ('e', 'm'): 1, ('t', 's'): 3, ('e', 'n'): 1, ('e', 't'): 2, ('m', 'v'): 1, ('p', 'l'): 1, ('o', 'u'): 1, ('v', 'p'): 1, ('e', 's'): 2, ('p', 'u'): 1, ('s', 'm'): 1, ('e', 'd'): 2, ('t', 'v'): 1, ('n', 't'): 1, ('t', 'i'): 2, ('a', 'v'): 1, ('n', 'o'): 1, ('m', 'l'): 1, ('o', 'p'): 1, ('e', 'p'): 1, ('m', 'p'): 1, ('m', 'i'): 1, ('s', 't'): 3, ('s', 'i'): 3, ('o', 't'): 1, ('u', 'm'): 1, ('t', 'l'): 1, ('u', 'l'): 1, ('v', 'a'): 1, ('u', 'n'): 2, ('a', 'o'): 1, ('o', 's'): 1, ('m', 't'): 1, ('o', 'e'): 2, ('t', 'o'): 1, ('l', 'o'): 1, ('o', 'm'): 2, ('o', 'r'): 1, ('p', 'a'): 1, ('m', 'o'): 2, ('l', 't'): 1, ('t', 'a'): 2, ('n', 's'): 2, ('o', 'a'): 1, ('o', 'v'): 1, ('n', 'a'): 1, ('a', 't'): 2, ('n', 'm'): 1, ('s', 'a'): 1, ('a', 's'): 1, ('t', 'e'): 2, ('v', 'l'): 1, ('e', 'v'): 1, ('a', 'l'): 1, ('r', 'e'): 1, ('l', 'v'): 1, ('v', 'm'): 1, ('m', 'e'): 1, ('e', 'r'): 1, ('p', 'v'): 1, ('d', 'u'): 1, ('s', 'e'): 2, ('u', 't'): 3, ('v', 'u'): 1, ('s', 'd'): 1, ('v', 't'): 1, ('o', 'n'): 1, ('i', 's'): 3, ('d', 's'): 1, ('d', 'n'): 1, ('i', 'n'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 2, ('p', 'e'): 1, ('s', 'c'): 1, ('i', 'o'): 1, ('l', 'e'): 1, ('u', 'd'): 1, ('i', 'e'): 1, ('a', 'c'): 1, ('d', 'e'): 2, ('u', 'e'): 2, ('s', 'u'): 2, ('e', 'a'): 1, ('u', 'o'): 1, ('t', 'p'): 1, ('o', 'i'): 1, ('a', 'm'): 2, ('t', 'n'): 2, ('n', 'i'): 2, ('l', 'a'): 1, ('a', 'n'): 2, ('u', 's'): 2, ('c', 'a'): 1, ('t', 'u'): 4, ('m', 'n'): 2, ('i', 't'): 3, ('i', 'c'): 1, ('n', 'e'): 1, ('r', 'o'): 1, ('m', 'u'): 2, ('s', 'n'): 3, ('o', 'l'): 1, ('n', 'd'): 1, ('v', 'o'): 1, ('p', 'm'): 1, ('e', 'l'): 1, ('p', 't'): 1, ('v', 'e'): 1, ('a', 'u'): 3, ('i', 'u'): 1, ('p', 'o'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('u', 'p'): 1, ('c', 'u'): 1, ('n', 'c'): 1, ('c', 'n'): 1, ('n', 'u'): 3, ('l', 'u'): 1, ('l', 'm'): 1, ('e', 'u'): 2, ('s', 'o'): 1, ('m', 'a'): 2, ('u', 'a'): 3, ('m', 's'): 2, ('e', 'i'): 1, ('t', 'm'): 2, ('e', 'o'): 2, ('a', 'p'): 1, ('a', 'e'): 1, ('e', 'm'): 1, ('t', 's'): 4, ('e', 'n'): 1, ('e', 't'): 2, ('m', 'v'): 1, ('p', 'l'): 1, ('o', 'u'): 1, ('v', 'p'): 1, ('e', 's'): 2, ('p', 'u'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 2, ('t', 'v'): 1, ('n', 't'): 2, ('t', 'i'): 3, ('a', 'v'): 1, ('n', 'o'): 1, ('m', 'l'): 1, ('o', 'p'): 1, ('e', 'p'): 1, ('m', 'p'): 1, ('m', 'i'): 2, ('s', 't'): 4, ('u', 'i'): 1, ('s', 'i'): 4, ('o', 't'): 1, ('u', 'm'): 2, ('t', 'l'): 1, ('u', 'l'): 1, ('v', 'a'): 1, ('u', 'n'): 3, ('a', 'o'): 1, ('o', 's'): 1, ('m', 't'): 2, ('o', 'e'): 2, ('t', 'o'): 1, ('l', 'o'): 1, ('o', 'm'): 2, ('o', 'r'): 1, ('p', 'a'): 1, ('m', 'o'): 2, ('l', 't'): 1, ('i', 'a'): 1, ('t', 'a'): 3, ('c', 't'): 1, ('c', 'm'): 1, ('n', 's'): 3, ('o', 'a'): 1, ('o', 'v'): 1, ('n', 'a'): 2, ('a', 't'): 3, ('n', 'm'): 2, ('s', 'a'): 2, ('a', 's'): 2, ('t', 'e'): 2, ('v', 'l'): 1, ('e', 'v'): 1, ('a', 'l'): 1, ('r', 'e'): 1, ('l', 'v'): 1, ('v', 'm'): 1, ('m', 'e'): 1, ('m', 'c'): 1, ('e', 'r'): 1, ('p', 'v'): 1, ('d', 'u'): 1, ('u', 'c'): 1, ('s', 'e'): 2, ('t', 'c'): 1, ('a', 'i'): 1, ('u', 't'): 4, ('v', 'u'): 1, ('s', 'd'): 1, ('v', 't'): 1, ('o', 'n'): 1, ('i', 's'): 4, ('d', 's'): 1, ('c', 'i'): 1, ('d', 'n'): 1, ('i', 'n'): 2})
# defaultdict(<class 'int'>, {('i', 'm'): 2, ('p', 'e'): 1, ('s', 'c'): 1, ('i', 'o'): 1, ('l', 'e'): 2, ('u', 'd'): 2, ('i', 'e'): 1, ('a', 'c'): 1, ('d', 'e'): 3, ('u', 'e'): 3, ('s', 'u'): 2, ('d', 'm'): 1, ('e', 'a'): 1, ('u', 'o'): 2, ('t', 'p'): 1, ('o', 'i'): 1, ('m', 'q'): 1, ('a', 'm'): 2, ('t', 'n'): 2, ('n', 'i'): 2, ('l', 'a'): 1, ('a', 'n'): 2, ('u', 'r'): 1, ('u', 's'): 2, ('c', 'a'): 1, ('t', 'u'): 4, ('m', 'n'): 2, ('d', 'q'): 1, ('i', 't'): 3, ('r', 'u'): 1, ('i', 'c'): 1, ('n', 'e'): 1, ('r', 'o'): 2, ('m', 'u'): 3, ('s', 'n'): 3, ('o', 'l'): 2, ('n', 'd'): 1, ('q', 'm'): 1, ('v', 'o'): 1, ('d', 'l'): 1, ('p', 'm'): 1, ('r', 'q'): 1, ('e', 'l'): 2, ('e', 'q'): 1, ('d', 'o'): 1, ('p', 't'): 1, ('v', 'e'): 1, ('a', 'u'): 3, ('i', 'u'): 1, ('p', 'o'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('u', 'p'): 1, ('q', 'e'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('n', 'c'): 1, ('c', 'n'): 1, ('n', 'u'): 3, ('l', 'u'): 2, ('l', 'm'): 2, ('e', 'u'): 3, ('r', 'd'): 1, ('o', 'q'): 1, ('s', 'o'): 1, ('m', 'a'): 2, ('u', 'a'): 3, ('m', 's'): 2, ('e', 'i'): 1, ('t', 'm'): 2, ('e', 'o'): 3, ('a', 'p'): 1, ('a', 'e'): 1, ('e', 'm'): 2, ('t', 's'): 4, ('e', 'n'): 1, ('e', 't'): 2, ('m', 'v'): 1, ('p', 'l'): 1, ('o', 'u'): 2, ('v', 'p'): 1, ('e', 's'): 2, ('p', 'u'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 1, ('l', 'd'): 1, ('n', 't'): 2, ('t', 'i'): 3, ('a', 'v'): 1, ('n', 'o'): 1, ('m', 'l'): 2, ('o', 'p'): 1, ('e', 'p'): 1, ('l', 'r'): 1, ('m', 'p'): 1, ('m', 'i'): 2, ('s', 't'): 4, ('u', 'i'): 1, ('s', 'i'): 4, ('o', 't'): 1, ('u', 'm'): 3, ('t', 'l'): 1, ('u', 'l'): 2, ('v', 'a'): 1, ('u', 'n'): 3, ('a', 'o'): 1, ('o', 's'): 1, ('m', 't'): 2, ('o', 'e'): 3, ('r', 'm'): 1, ('m', 'r'): 1, ('t', 'o'): 1, ('d', 'r'): 1, ('o', 'd'): 1, ('l', 'o'): 2, ('o', 'm'): 3, ('o', 'r'): 2, ('q', 'u'): 1, ('p', 'a'): 1, ('m', 'o'): 3, ('l', 't'): 1, ('i', 'a'): 1, ('t', 'a'): 3, ('q', 'r'): 1, ('c', 't'): 1, ('c', 'm'): 1, ('n', 's'): 3, ('o', 'a'): 1, ('o', 'v'): 1, ('n', 'a'): 2, ('u', 'q'): 1, ('a', 't'): 3, ('q', 'o'): 1, ('n', 'm'): 2, ('s', 'a'): 2, ('a', 's'): 2, ('r', 'l'): 1, ('t', 'e'): 2, ('v', 'l'): 1, ('q', 'd'): 1, ('e', 'v'): 1, ('a', 'l'): 1, ('r', 'e'): 2, ('l', 'v'): 1, ('v', 'm'): 1, ('m', 'e'): 2, ('m', 'c'): 1, ('e', 'r'): 2, ('p', 'v'): 1, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 2, ('t', 'c'): 1, ('a', 'i'): 1, ('u', 't'): 4, ('v', 'u'): 1, ('s', 'd'): 1, ('v', 't'): 1, ('o', 'n'): 1, ('i', 's'): 4, ('l', 'q'): 1, ('d', 's'): 1, ('c', 'i'): 1, ('d', 'n'): 1, ('i', 'n'): 2})
# defaultdict(<class 'int'>, {('i', 'm'): 2, ('p', 'e'): 1, ('s', 'c'): 1, ('i', 'o'): 1, ('l', 'e'): 2, ('u', 'd'): 2, ('i', 'e'): 1, ('a', 'c'): 1, ('d', 'e'): 3, ('u', 'e'): 3, ('s', 'u'): 2, ('d', 'm'): 1, ('e', 'a'): 1, ('u', 'o'): 2, ('t', 'p'): 1, ('o', 'i'): 1, ('m', 'q'): 1, ('a', 'm'): 3, ('t', 'n'): 2, ('n', 'i'): 2, ('l', 'a'): 1, ('a', 'n'): 2, ('u', 'r'): 1, ('u', 's'): 2, ('c', 'a'): 1, ('t', 'u'): 4, ('m', 'n'): 2, ('d', 'q'): 1, ('i', 't'): 3, ('r', 'u'): 1, ('i', 'c'): 1, ('n', 'e'): 1, ('r', 'o'): 2, ('m', 'u'): 3, ('s', 'n'): 3, ('o', 'l'): 2, ('n', 'd'): 1, ('q', 'm'): 1, ('v', 'o'): 1, ('d', 'l'): 1, ('p', 'm'): 1, ('r', 'q'): 1, ('e', 'l'): 2, ('e', 'q'): 1, ('d', 'o'): 1, ('p', 't'): 1, ('v', 'e'): 1, ('a', 'u'): 3, ('i', 'u'): 1, ('p', 'o'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('u', 'p'): 1, ('q', 'e'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('n', 'c'): 1, ('c', 'n'): 1, ('n', 'u'): 3, ('l', 'u'): 2, ('l', 'm'): 2, ('e', 'u'): 3, ('r', 'd'): 1, ('o', 'q'): 1, ('s', 'o'): 1, ('m', 'a'): 3, ('u', 'a'): 3, ('m', 's'): 2, ('e', 'i'): 1, ('t', 'm'): 3, ('e', 'o'): 3, ('a', 'p'): 1, ('a', 'e'): 1, ('e', 'm'): 2, ('t', 's'): 4, ('e', 'n'): 1, ('e', 't'): 2, ('m', 'v'): 1, ('p', 'l'): 1, ('o', 'u'): 2, ('v', 'p'): 1, ('e', 's'): 2, ('p', 'u'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 1, ('l', 'd'): 1, ('n', 't'): 2, ('t', 'i'): 3, ('a', 'v'): 1, ('n', 'o'): 1, ('m', 'l'): 2, ('o', 'p'): 1, ('e', 'p'): 1, ('l', 'r'): 1, ('m', 'p'): 1, ('m', 'i'): 2, ('s', 't'): 4, ('u', 'i'): 1, ('s', 'i'): 4, ('o', 't'): 2, ('u', 'm'): 3, ('t', 'l'): 1, ('u', 'l'): 2, ('v', 'a'): 1, ('u', 'n'): 3, ('a', 'o'): 2, ('o', 's'): 1, ('m', 't'): 3, ('o', 'e'): 3, ('r', 'm'): 1, ('m', 'r'): 1, ('t', 'o'): 2, ('d', 'r'): 1, ('o', 'd'): 1, ('l', 'o'): 2, ('o', 'm'): 4, ('o', 'r'): 2, ('q', 'u'): 1, ('p', 'a'): 1, ('m', 'o'): 4, ('l', 't'): 1, ('i', 'a'): 1, ('t', 'a'): 4, ('q', 'r'): 1, ('c', 't'): 1, ('c', 'm'): 1, ('n', 's'): 3, ('o', 'a'): 2, ('o', 'v'): 1, ('n', 'a'): 2, ('u', 'q'): 1, ('a', 't'): 4, ('q', 'o'): 1, ('n', 'm'): 2, ('s', 'a'): 2, ('a', 's'): 2, ('r', 'l'): 1, ('t', 'e'): 2, ('v', 'l'): 1, ('q', 'd'): 1, ('e', 'v'): 1, ('a', 'l'): 1, ('r', 'e'): 2, ('l', 'v'): 1, ('v', 'm'): 1, ('m', 'e'): 2, ('m', 'c'): 1, ('e', 'r'): 2, ('p', 'v'): 1, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 2, ('t', 'c'): 1, ('a', 'i'): 1, ('u', 't'): 4, ('v', 'u'): 1, ('s', 'd'): 1, ('v', 't'): 1, ('o', 'n'): 1, ('i', 's'): 4, ('l', 'q'): 1, ('d', 's'): 1, ('c', 'i'): 1, ('d', 'n'): 1, ('i', 'n'): 2})
# defaultdict(<class 'int'>, {('i', 'm'): 2, ('p', 'e'): 1, ('s', 'c'): 1, ('i', 'o'): 1, ('l', 'e'): 2, ('u', 'd'): 2, ('i', 'e'): 1, ('a', 'c'): 1, ('d', 'e'): 3, ('u', 'e'): 3, ('s', 'u'): 2, ('d', 'm'): 1, ('e', 'a'): 1, ('u', 'o'): 2, ('t', 'p'): 1, ('o', 'i'): 1, ('m', 'q'): 1, ('a', 'm'): 3, ('t', 'n'): 2, ('n', 'i'): 2, ('l', 'a'): 1, ('a', 'n'): 2, ('u', 'r'): 1, ('u', 's'): 2, ('c', 'a'): 1, ('t', 'u'): 4, ('m', 'n'): 2, ('d', 'q'): 1, ('i', 't'): 3, ('r', 'u'): 1, ('i', 'c'): 1, ('n', 'e'): 1, ('r', 'o'): 2, ('m', 'u'): 3, ('s', 'n'): 3, ('o', 'l'): 2, ('n', 'd'): 1, ('q', 'm'): 1, ('v', 'o'): 1, ('d', 'l'): 1, ('p', 'm'): 1, ('r', 'q'): 1, ('e', 'l'): 2, ('e', 'q'): 1, ('d', 'o'): 1, ('p', 't'): 1, ('v', 'e'): 1, ('a', 'u'): 3, ('i', 'u'): 1, ('p', 'o'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('u', 'p'): 1, ('q', 'e'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('n', 'c'): 1, ('c', 'n'): 1, ('n', 'u'): 3, ('l', 'u'): 2, ('l', 'm'): 2, ('e', 'u'): 3, ('r', 'd'): 1, ('o', 'q'): 1, ('s', 'o'): 1, ('m', 'a'): 3, ('u', 'a'): 3, ('m', 's'): 2, ('e', 'i'): 1, ('t', 'm'): 3, ('e', 'o'): 3, ('a', 'p'): 1, ('a', 'e'): 1, ('e', 'm'): 3, ('t', 's'): 4, ('e', 'n'): 1, ('e', 't'): 2, ('m', 'v'): 1, ('p', 'l'): 1, ('o', 'u'): 2, ('v', 'p'): 1, ('e', 's'): 2, ('p', 'u'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 1, ('l', 'd'): 1, ('n', 't'): 2, ('t', 'i'): 3, ('a', 'v'): 1, ('n', 'o'): 1, ('m', 'l'): 2, ('o', 'p'): 1, ('e', 'p'): 1, ('l', 'r'): 1, ('m', 'p'): 1, ('m', 'i'): 2, ('s', 't'): 4, ('u', 'i'): 1, ('s', 'i'): 4, ('o', 't'): 2, ('u', 'm'): 3, ('t', 'l'): 1, ('u', 'l'): 2, ('v', 'a'): 1, ('u', 'n'): 3, ('a', 'o'): 2, ('o', 's'): 1, ('m', 't'): 3, ('o', 'e'): 3, ('r', 'm'): 2, ('m', 'r'): 2, ('t', 'o'): 2, ('d', 'r'): 1, ('o', 'd'): 1, ('l', 'o'): 2, ('o', 'm'): 4, ('o', 'r'): 2, ('q', 'u'): 1, ('p', 'a'): 1, ('m', 'o'): 4, ('l', 't'): 1, ('i', 'a'): 1, ('t', 'a'): 4, ('q', 'r'): 1, ('c', 't'): 1, ('c', 'm'): 1, ('n', 's'): 3, ('o', 'a'): 2, ('o', 'v'): 1, ('n', 'a'): 2, ('u', 'q'): 1, ('a', 't'): 4, ('q', 'o'): 1, ('n', 'm'): 2, ('s', 'a'): 2, ('a', 's'): 2, ('r', 'l'): 1, ('t', 'e'): 2, ('v', 'l'): 1, ('q', 'd'): 1, ('e', 'v'): 1, ('a', 'l'): 1, ('r', 'e'): 3, ('l', 'v'): 1, ('v', 'm'): 1, ('m', 'e'): 3, ('m', 'c'): 1, ('e', 'r'): 3, ('p', 'v'): 1, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 2, ('t', 'c'): 1, ('a', 'i'): 1, ('u', 't'): 4, ('v', 'u'): 1, ('s', 'd'): 1, ('v', 't'): 1, ('o', 'n'): 1, ('i', 's'): 4, ('l', 'q'): 1, ('d', 's'): 1, ('c', 'i'): 1, ('d', 'n'): 1, ('i', 'n'): 2})
# defaultdict(<class 'int'>, {('i', 'm'): 3, ('p', 'e'): 2, ('d', 'm'): 1, ('l', 'e'): 2, ('i', 'p'): 1, ('i', 'e'): 2, ('p', 'r'): 1, ('d', 'e'): 3, ('u', 'e'): 3, ('s', 'u'): 2, ('u', 'm'): 3, ('n', 't'): 2, ('o', 'i'): 1, ('l', 'a'): 1, ('v', 'l'): 1, ('u', 'r'): 1, ('t', 'u'): 4, ('i', 't'): 3, ('d', 'r'): 1, ('e', 'q'): 1, ('r', 'o'): 2, ('m', 'u'): 3, ('p', 't'): 1, ('o', 'l'): 2, ('n', 'd'): 1, ('p', 'v'): 1, ('p', 'm'): 2, ('e', 'l'): 2, ('a', 'u'): 3, ('s', 'd'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('q', 'e'): 1, ('r', 'i'): 1, ('q', 'm'): 1, ('r', 'd'): 1, ('m', 's'): 2, ('e', 'i'): 2, ('t', 'm'): 3, ('l', 'm'): 2, ('r', 'm'): 3, ('e', 'm'): 4, ('c', 'm'): 1, ('e', 't'): 2, ('m', 'v'): 1, ('p', 'l'): 1, ('o', 'v'): 1, ('n', 'i'): 2, ('l', 'd'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 1, ('n', 'o'): 1, ('m', 'l'): 2, ('i', 'r'): 1, ('m', 'i'): 3, ('u', 'i'): 1, ('s', 'i'): 4, ('t', 'l'): 1, ('u', 'l'): 2, ('o', 'e'): 3, ('m', 'r'): 3, ('t', 'o'): 2, ('o', 'd'): 1, ('l', 'o'): 2, ('o', 'm'): 4, ('o', 'r'): 2, ('q', 'u'): 1, ('l', 't'): 1, ('i', 'a'): 2, ('n', 'c'): 1, ('s', 'o'): 1, ('a', 'p'): 2, ('v', 'p'): 1, ('a', 't'): 4, ('q', 'o'): 1, ('n', 'm'): 2, ('a', 's'): 2, ('r', 'l'): 1, ('t', 'e'): 2, ('p', 'u'): 1, ('r', 'e'): 4, ('l', 'v'): 1, ('v', 'm'): 1, ('r', 'q'): 1, ('i', 'u'): 1, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 2, ('t', 'c'): 1, ('a', 'i'): 2, ('v', 'u'): 1, ('l', 'r'): 1, ('i', 's'): 4, ('l', 'q'): 1, ('d', 's'): 1, ('d', 'n'): 1, ('i', 'n'): 2, ('d', 'o'): 1, ('s', 'c'): 1, ('i', 'o'): 1, ('u', 'd'): 2, ('p', 'o'): 1, ('e', 'v'): 1, ('u', 'o'): 2, ('o', 'q'): 1, ('m', 'q'): 1, ('p', 'a'): 2, ('t', 'n'): 2, ('a', 'n'): 2, ('u', 's'): 2, ('c', 'a'): 1, ('m', 'n'): 2, ('i', 'c'): 1, ('n', 'e'): 1, ('s', 'n'): 3, ('q', 'r'): 1, ('d', 'l'): 1, ('a', 'r'): 1, ('u', 'p'): 1, ('v', 'e'): 1, ('e', 'r'): 4, ('r', 'p'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('a', 'c'): 1, ('n', 'u'): 3, ('l', 'u'): 2, ('e', 'a'): 2, ('e', 'u'): 3, ('u', 'a'): 3, ('e', 'o'): 3, ('a', 'e'): 2, ('c', 'n'): 1, ('t', 's'): 4, ('e', 'n'): 1, ('o', 'u'): 2, ('p', 'i'): 1, ('e', 's'): 2, ('r', 'a'): 1, ('t', 'p'): 1, ('t', 'i'): 3, ('o', 'p'): 1, ('e', 'p'): 2, ('m', 'p'): 2, ('s', 't'): 4, ('o', 't'): 2, ('v', 'a'): 1, ('u', 'n'): 3, ('a', 'o'): 2, ('o', 's'): 1, ('m', 't'): 3, ('u', 'q'): 1, ('d', 'q'): 1, ('m', 'o'): 4, ('r', 'u'): 1, ('t', 'a'): 4, ('c', 't'): 1, ('n', 's'): 3, ('o', 'a'): 2, ('m', 'a'): 4, ('s', 'a'): 2, ('q', 'd'): 1, ('a', 'l'): 1, ('a', 'm'): 4, ('n', 'a'): 2, ('m', 'e'): 4, ('m', 'c'): 1, ('v', 'o'): 1, ('u', 't'): 4, ('a', 'v'): 1, ('v', 't'): 1, ('o', 'n'): 1, ('c', 'i'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 3, ('p', 'e'): 2, ('d', 'm'): 1, ('l', 'e'): 2, ('i', 'p'): 1, ('i', 'e'): 2, ('p', 'r'): 1, ('d', 'e'): 3, ('u', 'e'): 4, ('s', 'u'): 2, ('u', 'm'): 3, ('n', 't'): 2, ('o', 'i'): 1, ('l', 'a'): 1, ('v', 'l'): 1, ('u', 'r'): 1, ('t', 'u'): 4, ('i', 't'): 3, ('d', 'r'): 1, ('e', 'q'): 2, ('r', 'o'): 2, ('m', 'u'): 3, ('p', 't'): 1, ('o', 'l'): 2, ('n', 'd'): 1, ('p', 'v'): 1, ('p', 'm'): 2, ('e', 'l'): 2, ('a', 'u'): 4, ('a', 'q'): 1, ('s', 'd'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('q', 'e'): 2, ('r', 'i'): 1, ('q', 'm'): 1, ('r', 'd'): 1, ('m', 's'): 2, ('e', 'i'): 2, ('t', 'm'): 3, ('l', 'm'): 2, ('r', 'm'): 3, ('e', 'm'): 4, ('c', 'm'): 1, ('e', 't'): 2, ('m', 'v'): 1, ('p', 'l'): 1, ('o', 'v'): 1, ('n', 'i'): 2, ('l', 'd'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 1, ('n', 'o'): 1, ('m', 'l'): 2, ('i', 'r'): 1, ('m', 'i'): 3, ('u', 'i'): 1, ('s', 'i'): 4, ('t', 'l'): 1, ('u', 'l'): 2, ('q', 'a'): 1, ('o', 'e'): 3, ('m', 'r'): 3, ('t', 'o'): 2, ('o', 'd'): 1, ('l', 'o'): 2, ('o', 'm'): 4, ('o', 'r'): 2, ('q', 'u'): 2, ('l', 't'): 1, ('i', 'a'): 2, ('n', 'c'): 1, ('s', 'o'): 1, ('a', 'p'): 2, ('v', 'p'): 1, ('a', 't'): 4, ('q', 'o'): 1, ('n', 'm'): 2, ('a', 's'): 2, ('r', 'l'): 1, ('t', 'e'): 2, ('p', 'u'): 1, ('r', 'e'): 4, ('l', 'v'): 1, ('v', 'm'): 1, ('r', 'q'): 1, ('i', 'u'): 1, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 2, ('t', 'c'): 1, ('a', 'i'): 2, ('v', 'u'): 1, ('l', 'r'): 1, ('i', 's'): 4, ('l', 'q'): 1, ('d', 's'): 1, ('d', 'n'): 1, ('i', 'n'): 2, ('d', 'o'): 1, ('s', 'c'): 1, ('i', 'o'): 1, ('u', 'd'): 2, ('p', 'o'): 1, ('e', 'v'): 1, ('u', 'o'): 2, ('o', 'q'): 1, ('m', 'q'): 1, ('p', 'a'): 2, ('t', 'n'): 2, ('a', 'n'): 2, ('u', 's'): 2, ('c', 'a'): 1, ('m', 'n'): 2, ('i', 'c'): 1, ('n', 'e'): 1, ('s', 'n'): 3, ('q', 'r'): 1, ('d', 'l'): 1, ('a', 'r'): 1, ('u', 'p'): 1, ('v', 'e'): 1, ('e', 'r'): 4, ('r', 'p'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('a', 'c'): 1, ('n', 'u'): 3, ('l', 'u'): 2, ('e', 'a'): 3, ('e', 'u'): 4, ('u', 'a'): 4, ('e', 'o'): 3, ('a', 'e'): 3, ('c', 'n'): 1, ('t', 's'): 4, ('e', 'n'): 1, ('o', 'u'): 2, ('p', 'i'): 1, ('e', 's'): 2, ('r', 'a'): 1, ('t', 'p'): 1, ('t', 'i'): 3, ('o', 'p'): 1, ('e', 'p'): 2, ('m', 'p'): 2, ('s', 't'): 4, ('o', 't'): 2, ('v', 'a'): 1, ('u', 'n'): 3, ('a', 'o'): 2, ('o', 's'): 1, ('m', 't'): 3, ('u', 'q'): 2, ('d', 'q'): 1, ('m', 'o'): 4, ('r', 'u'): 1, ('t', 'a'): 4, ('c', 't'): 1, ('n', 's'): 3, ('o', 'a'): 2, ('m', 'a'): 4, ('s', 'a'): 2, ('q', 'd'): 1, ('a', 'l'): 1, ('a', 'm'): 4, ('n', 'a'): 2, ('m', 'e'): 4, ('m', 'c'): 1, ('v', 'o'): 1, ('u', 't'): 4, ('a', 'v'): 1, ('v', 't'): 1, ('o', 'n'): 1, ('c', 'i'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 3, ('p', 'e'): 2, ('d', 'm'): 1, ('l', 'e'): 2, ('i', 'p'): 1, ('i', 'e'): 2, ('p', 'r'): 1, ('d', 'e'): 3, ('u', 'e'): 5, ('s', 'u'): 2, ('u', 'm'): 3, ('n', 't'): 2, ('o', 'i'): 1, ('l', 'a'): 1, ('v', 'l'): 1, ('u', 'r'): 1, ('t', 'u'): 4, ('i', 't'): 3, ('d', 'r'): 1, ('e', 'q'): 3, ('r', 'o'): 2, ('m', 'u'): 3, ('p', 't'): 1, ('o', 'l'): 2, ('n', 'd'): 1, ('p', 'v'): 1, ('p', 'm'): 2, ('e', 'l'): 2, ('a', 'u'): 5, ('a', 'q'): 2, ('s', 'd'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('q', 'e'): 3, ('r', 'i'): 1, ('q', 'm'): 1, ('r', 'd'): 1, ('m', 's'): 2, ('e', 'i'): 2, ('t', 'm'): 3, ('l', 'm'): 2, ('r', 'm'): 3, ('e', 'm'): 4, ('c', 'm'): 1, ('e', 't'): 2, ('m', 'v'): 1, ('p', 'l'): 1, ('o', 'v'): 1, ('n', 'i'): 2, ('l', 'd'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 1, ('n', 'o'): 1, ('m', 'l'): 2, ('i', 'r'): 1, ('m', 'i'): 3, ('u', 'i'): 1, ('s', 'i'): 4, ('t', 'l'): 1, ('u', 'l'): 2, ('q', 'a'): 2, ('o', 'e'): 3, ('m', 'r'): 3, ('t', 'o'): 2, ('o', 'd'): 1, ('l', 'o'): 2, ('o', 'm'): 4, ('o', 'r'): 2, ('q', 'u'): 3, ('l', 't'): 1, ('i', 'a'): 2, ('n', 'c'): 1, ('s', 'o'): 1, ('a', 'p'): 2, ('v', 'p'): 1, ('a', 't'): 4, ('q', 'o'): 1, ('n', 'm'): 2, ('a', 's'): 2, ('r', 'l'): 1, ('t', 'e'): 2, ('p', 'u'): 1, ('r', 'e'): 4, ('l', 'v'): 1, ('v', 'm'): 1, ('r', 'q'): 1, ('i', 'u'): 1, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 2, ('t', 'c'): 1, ('a', 'i'): 2, ('v', 'u'): 1, ('l', 'r'): 1, ('i', 's'): 4, ('l', 'q'): 1, ('d', 's'): 1, ('d', 'n'): 1, ('i', 'n'): 2, ('d', 'o'): 1, ('s', 'c'): 1, ('i', 'o'): 1, ('u', 'd'): 2, ('p', 'o'): 1, ('e', 'v'): 1, ('u', 'o'): 2, ('o', 'q'): 1, ('m', 'q'): 1, ('p', 'a'): 2, ('t', 'n'): 2, ('a', 'n'): 2, ('u', 's'): 2, ('c', 'a'): 1, ('m', 'n'): 2, ('i', 'c'): 1, ('n', 'e'): 1, ('s', 'n'): 3, ('q', 'r'): 1, ('d', 'l'): 1, ('a', 'r'): 1, ('u', 'p'): 1, ('v', 'e'): 1, ('e', 'r'): 4, ('r', 'p'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('a', 'c'): 1, ('n', 'u'): 3, ('l', 'u'): 2, ('e', 'a'): 4, ('e', 'u'): 5, ('u', 'a'): 5, ('e', 'o'): 3, ('a', 'e'): 4, ('c', 'n'): 1, ('t', 's'): 4, ('e', 'n'): 1, ('o', 'u'): 2, ('p', 'i'): 1, ('e', 's'): 2, ('r', 'a'): 1, ('t', 'p'): 1, ('t', 'i'): 3, ('o', 'p'): 1, ('e', 'p'): 2, ('m', 'p'): 2, ('s', 't'): 4, ('o', 't'): 2, ('v', 'a'): 1, ('u', 'n'): 3, ('a', 'o'): 2, ('o', 's'): 1, ('m', 't'): 3, ('u', 'q'): 3, ('d', 'q'): 1, ('m', 'o'): 4, ('r', 'u'): 1, ('t', 'a'): 4, ('c', 't'): 1, ('n', 's'): 3, ('o', 'a'): 2, ('m', 'a'): 4, ('s', 'a'): 2, ('q', 'd'): 1, ('a', 'l'): 1, ('a', 'm'): 4, ('n', 'a'): 2, ('m', 'e'): 4, ('m', 'c'): 1, ('v', 'o'): 1, ('u', 't'): 4, ('a', 'v'): 1, ('v', 't'): 1, ('o', 'n'): 1, ('c', 'i'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 3, ('p', 'e'): 2, ('d', 'm'): 1, ('l', 'e'): 2, ('i', 'p'): 1, ('i', 'e'): 2, ('p', 'r'): 1, ('d', 'e'): 3, ('u', 'e'): 5, ('s', 'u'): 2, ('u', 'm'): 3, ('n', 't'): 2, ('o', 'i'): 1, ('l', 'a'): 1, ('v', 'l'): 1, ('u', 'r'): 1, ('t', 'u'): 4, ('i', 't'): 3, ('d', 'r'): 1, ('e', 'q'): 3, ('r', 'o'): 2, ('m', 'u'): 3, ('p', 't'): 1, ('o', 'l'): 2, ('n', 'd'): 1, ('p', 'v'): 1, ('p', 'm'): 2, ('e', 'l'): 2, ('a', 'u'): 5, ('a', 'q'): 2, ('s', 'd'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('q', 'e'): 3, ('r', 'i'): 1, ('q', 'm'): 1, ('r', 'd'): 1, ('m', 's'): 2, ('e', 'i'): 2, ('t', 'm'): 3, ('l', 'm'): 2, ('r', 'm'): 3, ('e', 'm'): 4, ('c', 'm'): 1, ('e', 't'): 2, ('m', 'v'): 1, ('p', 'l'): 1, ('o', 'v'): 1, ('n', 'i'): 2, ('l', 'd'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 1, ('n', 'o'): 1, ('m', 'l'): 2, ('i', 'r'): 1, ('m', 'i'): 3, ('u', 'i'): 1, ('s', 'i'): 4, ('t', 'l'): 1, ('u', 'l'): 2, ('q', 'a'): 2, ('o', 'e'): 3, ('m', 'r'): 3, ('t', 'o'): 2, ('o', 'd'): 1, ('l', 'o'): 2, ('o', 'm'): 4, ('o', 'r'): 2, ('q', 'u'): 3, ('l', 't'): 1, ('i', 'a'): 2, ('n', 'c'): 1, ('s', 'o'): 1, ('a', 'p'): 2, ('v', 'p'): 1, ('a', 't'): 4, ('q', 'o'): 1, ('n', 'm'): 2, ('a', 's'): 2, ('r', 'l'): 1, ('t', 'e'): 2, ('p', 'u'): 1, ('r', 'e'): 4, ('l', 'v'): 1, ('v', 'm'): 1, ('r', 'q'): 1, ('i', 'u'): 1, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 2, ('t', 'c'): 1, ('a', 'i'): 2, ('v', 'u'): 1, ('l', 'r'): 1, ('i', 's'): 4, ('l', 'q'): 1, ('d', 's'): 1, ('d', 'n'): 1, ('i', 'n'): 2, ('d', 'o'): 1, ('s', 'c'): 1, ('i', 'o'): 1, ('u', 'd'): 2, ('p', 'o'): 1, ('e', 'v'): 1, ('u', 'o'): 2, ('o', 'q'): 1, ('m', 'q'): 1, ('p', 'a'): 2, ('t', 'n'): 2, ('a', 'n'): 2, ('u', 's'): 2, ('c', 'a'): 1, ('m', 'n'): 2, ('i', 'c'): 1, ('n', 'e'): 1, ('s', 'n'): 3, ('q', 'r'): 1, ('d', 'l'): 1, ('a', 'r'): 1, ('u', 'p'): 1, ('v', 'e'): 1, ('e', 'r'): 4, ('r', 'p'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('a', 'c'): 1, ('n', 'u'): 3, ('l', 'u'): 2, ('e', 'a'): 4, ('e', 'u'): 5, ('u', 'a'): 5, ('a', 'b'): 1, ('e', 'o'): 3, ('a', 'e'): 4, ('c', 'n'): 1, ('t', 's'): 4, ('e', 'n'): 1, ('o', 'u'): 2, ('p', 'i'): 1, ('e', 's'): 2, ('r', 'a'): 1, ('t', 'p'): 1, ('t', 'i'): 3, ('o', 'p'): 1, ('e', 'p'): 2, ('m', 'p'): 2, ('b', 'a'): 1, ('s', 't'): 4, ('o', 't'): 2, ('v', 'a'): 1, ('u', 'n'): 3, ('a', 'o'): 2, ('o', 's'): 1, ('m', 't'): 3, ('u', 'q'): 3, ('d', 'q'): 1, ('m', 'o'): 4, ('r', 'u'): 1, ('t', 'a'): 4, ('c', 't'): 1, ('n', 's'): 3, ('o', 'a'): 2, ('m', 'a'): 4, ('s', 'a'): 2, ('q', 'd'): 1, ('a', 'l'): 1, ('a', 'm'): 4, ('n', 'a'): 2, ('m', 'e'): 4, ('m', 'c'): 1, ('v', 'o'): 1, ('u', 't'): 4, ('a', 'v'): 1, ('v', 't'): 1, ('o', 'n'): 1, ('c', 'i'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 3, ('p', 'e'): 2, ('d', 'm'): 1, ('l', 'e'): 2, ('i', 'p'): 1, ('i', 'e'): 2, ('p', 'r'): 1, ('d', 'e'): 3, ('u', 'e'): 5, ('s', 'u'): 2, ('u', 'm'): 3, ('n', 't'): 2, ('o', 'i'): 2, ('l', 'a'): 1, ('v', 'l'): 1, ('u', 'r'): 1, ('t', 'u'): 4, ('i', 't'): 3, ('d', 'r'): 1, ('e', 'q'): 3, ('r', 'o'): 2, ('m', 'u'): 3, ('p', 't'): 1, ('o', 'l'): 3, ('n', 'd'): 1, ('p', 'v'): 1, ('p', 'm'): 2, ('e', 'l'): 2, ('a', 'u'): 5, ('a', 'q'): 2, ('s', 'd'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('q', 'e'): 3, ('r', 'i'): 1, ('q', 'm'): 1, ('r', 'd'): 1, ('m', 's'): 2, ('e', 'i'): 2, ('t', 'm'): 3, ('l', 'm'): 2, ('r', 'm'): 3, ('e', 'm'): 4, ('c', 'm'): 1, ('e', 't'): 2, ('m', 'v'): 1, ('p', 'l'): 1, ('o', 'v'): 1, ('n', 'i'): 2, ('l', 'd'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 1, ('n', 'o'): 1, ('m', 'l'): 2, ('i', 'r'): 1, ('m', 'i'): 3, ('u', 'i'): 1, ('s', 'i'): 4, ('t', 'l'): 1, ('u', 'l'): 2, ('q', 'a'): 2, ('o', 'e'): 3, ('m', 'r'): 3, ('t', 'o'): 2, ('o', 'd'): 1, ('l', 'o'): 3, ('o', 'm'): 4, ('o', 'r'): 2, ('q', 'u'): 3, ('l', 't'): 1, ('i', 'a'): 2, ('n', 'c'): 1, ('s', 'o'): 1, ('a', 'p'): 2, ('v', 'p'): 1, ('a', 't'): 4, ('q', 'o'): 1, ('n', 'm'): 2, ('a', 's'): 2, ('r', 'l'): 1, ('t', 'e'): 2, ('p', 'u'): 1, ('r', 'e'): 4, ('l', 'v'): 1, ('v', 'm'): 1, ('r', 'q'): 1, ('i', 'u'): 1, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 2, ('t', 'c'): 1, ('a', 'i'): 2, ('v', 'u'): 1, ('l', 'r'): 1, ('i', 's'): 4, ('l', 'q'): 1, ('d', 's'): 1, ('d', 'n'): 1, ('i', 'n'): 2, ('d', 'o'): 1, ('s', 'c'): 1, ('i', 'o'): 2, ('u', 'd'): 2, ('p', 'o'): 1, ('e', 'v'): 1, ('u', 'o'): 2, ('o', 'q'): 1, ('m', 'q'): 1, ('p', 'a'): 2, ('t', 'n'): 2, ('a', 'n'): 2, ('u', 's'): 2, ('c', 'a'): 1, ('m', 'n'): 2, ('i', 'c'): 1, ('n', 'e'): 1, ('s', 'n'): 3, ('q', 'r'): 1, ('d', 'l'): 1, ('a', 'r'): 1, ('u', 'p'): 1, ('v', 'e'): 1, ('e', 'r'): 4, ('r', 'p'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('a', 'c'): 1, ('n', 'u'): 3, ('l', 'u'): 2, ('e', 'a'): 4, ('e', 'u'): 5, ('u', 'a'): 5, ('a', 'b'): 1, ('e', 'o'): 3, ('a', 'e'): 4, ('c', 'n'): 1, ('t', 's'): 4, ('e', 'n'): 1, ('o', 'u'): 2, ('p', 'i'): 1, ('e', 's'): 2, ('l', 'i'): 1, ('r', 'a'): 1, ('t', 'p'): 1, ('t', 'i'): 3, ('o', 'p'): 1, ('e', 'p'): 2, ('m', 'p'): 2, ('b', 'a'): 1, ('s', 't'): 4, ('o', 't'): 2, ('v', 'a'): 1, ('u', 'n'): 3, ('a', 'o'): 2, ('o', 's'): 1, ('m', 't'): 3, ('u', 'q'): 3, ('d', 'q'): 1, ('m', 'o'): 4, ('r', 'u'): 1, ('t', 'a'): 4, ('c', 't'): 1, ('n', 's'): 3, ('o', 'a'): 2, ('m', 'a'): 4, ('s', 'a'): 2, ('q', 'd'): 1, ('a', 'l'): 1, ('a', 'm'): 4, ('n', 'a'): 2, ('m', 'e'): 4, ('m', 'c'): 1, ('v', 'o'): 1, ('u', 't'): 4, ('a', 'v'): 1, ('v', 't'): 1, ('o', 'n'): 1, ('c', 'i'): 1, ('i', 'l'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 3, ('p', 'e'): 2, ('d', 'm'): 1, ('l', 'e'): 2, ('i', 'p'): 1, ('i', 'e'): 3, ('p', 'r'): 1, ('d', 'e'): 3, ('u', 'e'): 5, ('s', 'u'): 2, ('u', 'm'): 3, ('n', 't'): 3, ('o', 'i'): 3, ('l', 'a'): 1, ('v', 'l'): 1, ('u', 'r'): 1, ('t', 'u'): 4, ('i', 't'): 4, ('d', 'r'): 1, ('e', 'q'): 3, ('r', 'o'): 3, ('m', 'u'): 3, ('p', 't'): 1, ('o', 'l'): 3, ('n', 'd'): 1, ('p', 'v'): 1, ('p', 'm'): 2, ('e', 'l'): 2, ('a', 'u'): 5, ('a', 'q'): 2, ('s', 'd'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('q', 'e'): 3, ('r', 'i'): 2, ('q', 'm'): 1, ('r', 'd'): 1, ('m', 's'): 2, ('e', 'i'): 3, ('t', 'm'): 3, ('l', 'm'): 2, ('r', 'm'): 3, ('e', 'm'): 4, ('c', 'm'): 1, ('e', 't'): 3, ('m', 'v'): 1, ('p', 'l'): 1, ('r', 't'): 1, ('o', 'v'): 2, ('n', 'i'): 3, ('l', 'd'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 2, ('v', 'r'): 1, ('n', 'o'): 2, ('m', 'l'): 2, ('n', 'r'): 1, ('i', 'r'): 2, ('v', 'i'): 1, ('m', 'i'): 3, ('u', 'i'): 1, ('s', 'i'): 4, ('t', 'r'): 1, ('t', 'l'): 1, ('u', 'l'): 2, ('q', 'a'): 2, ('o', 'e'): 4, ('m', 'r'): 3, ('t', 'o'): 3, ('o', 'd'): 1, ('l', 'o'): 3, ('o', 'm'): 4, ('o', 'r'): 3, ('q', 'u'): 3, ('l', 't'): 1, ('i', 'a'): 2, ('n', 'c'): 1, ('s', 'o'): 1, ('a', 'p'): 2, ('v', 'p'): 1, ('a', 't'): 4, ('q', 'o'): 1, ('n', 'm'): 2, ('a', 's'): 2, ('r', 'l'): 1, ('t', 'e'): 3, ('p', 'u'): 1, ('v', 'n'): 1, ('r', 'e'): 5, ('l', 'v'): 1, ('v', 'm'): 1, ('r', 'q'): 1, ('i', 'u'): 1, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 2, ('t', 'c'): 1, ('a', 'i'): 2, ('v', 'u'): 1, ('l', 'r'): 1, ('i', 's'): 4, ('l', 'q'): 1, ('d', 's'): 1, ('r', 'v'): 1, ('d', 'n'): 1, ('i', 'n'): 3, ('d', 'o'): 1, ('s', 'c'): 1, ('i', 'o'): 3, ('u', 'd'): 2, ('p', 'o'): 1, ('r', 'n'): 1, ('e', 'v'): 2, ('u', 'o'): 2, ('o', 'q'): 1, ('m', 'q'): 1, ('p', 'a'): 2, ('t', 'n'): 3, ('n', 'v'): 1, ('a', 'n'): 2, ('u', 's'): 2, ('c', 'a'): 1, ('m', 'n'): 2, ('i', 'c'): 1, ('n', 'e'): 2, ('s', 'n'): 3, ('q', 'r'): 1, ('d', 'l'): 1, ('a', 'r'): 1, ('u', 'p'): 1, ('v', 'e'): 2, ('e', 'r'): 5, ('r', 'p'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('a', 'c'): 1, ('n', 'u'): 3, ('l', 'u'): 2, ('e', 'a'): 4, ('e', 'u'): 5, ('u', 'a'): 5, ('a', 'b'): 1, ('e', 'o'): 4, ('a', 'e'): 4, ('c', 'n'): 1, ('t', 's'): 4, ('e', 'n'): 2, ('o', 'u'): 2, ('p', 'i'): 1, ('e', 's'): 2, ('l', 'i'): 1, ('r', 'a'): 1, ('t', 'p'): 1, ('t', 'i'): 4, ('o', 'p'): 1, ('e', 'p'): 2, ('m', 'p'): 2, ('b', 'a'): 1, ('s', 't'): 4, ('o', 't'): 3, ('v', 'a'): 1, ('u', 'n'): 3, ('a', 'o'): 2, ('o', 's'): 1, ('m', 't'): 3, ('u', 'q'): 3, ('d', 'q'): 1, ('m', 'o'): 4, ('r', 'u'): 1, ('t', 'a'): 4, ('c', 't'): 1, ('n', 's'): 3, ('o', 'a'): 2, ('m', 'a'): 4, ('i', 'v'): 1, ('s', 'a'): 2, ('q', 'd'): 1, ('a', 'l'): 1, ('a', 'm'): 4, ('n', 'a'): 2, ('m', 'e'): 4, ('m', 'c'): 1, ('v', 'o'): 2, ('u', 't'): 4, ('a', 'v'): 1, ('v', 't'): 2, ('o', 'n'): 2, ('c', 'i'): 1, ('i', 'l'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 3, ('p', 'e'): 2, ('d', 'm'): 1, ('l', 'e'): 2, ('i', 'p'): 1, ('i', 'e'): 4, ('p', 'r'): 1, ('d', 'e'): 3, ('u', 'e'): 5, ('s', 'u'): 2, ('u', 'm'): 3, ('n', 't'): 3, ('o', 'i'): 3, ('l', 'a'): 1, ('v', 'l'): 1, ('u', 'r'): 1, ('t', 'u'): 4, ('i', 't'): 5, ('d', 'r'): 1, ('e', 'q'): 3, ('r', 'o'): 3, ('m', 'u'): 3, ('p', 't'): 1, ('o', 'l'): 3, ('n', 'd'): 1, ('p', 'v'): 1, ('p', 'm'): 2, ('e', 'l'): 2, ('a', 'u'): 5, ('a', 'q'): 2, ('s', 'd'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('q', 'e'): 3, ('r', 'i'): 3, ('q', 'm'): 1, ('r', 'd'): 1, ('m', 's'): 2, ('e', 'i'): 4, ('s', 'v'): 1, ('t', 'm'): 3, ('l', 'm'): 2, ('r', 'm'): 3, ('e', 'm'): 4, ('c', 'm'): 1, ('e', 't'): 4, ('m', 'v'): 1, ('p', 'l'): 1, ('r', 't'): 2, ('o', 'v'): 2, ('n', 'i'): 3, ('l', 'd'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 3, ('v', 'r'): 2, ('n', 'o'): 2, ('m', 'l'): 2, ('n', 'r'): 1, ('i', 'r'): 3, ('v', 'i'): 2, ('m', 'i'): 3, ('u', 'i'): 1, ('s', 'i'): 5, ('t', 'r'): 2, ('t', 'l'): 1, ('u', 'l'): 2, ('q', 'a'): 2, ('o', 'e'): 4, ('m', 'r'): 3, ('t', 'o'): 3, ('o', 'd'): 1, ('l', 'o'): 3, ('o', 'm'): 4, ('o', 'r'): 3, ('q', 'u'): 3, ('l', 't'): 1, ('i', 'a'): 3, ('n', 'c'): 1, ('s', 'o'): 1, ('a', 'p'): 2, ('v', 'p'): 1, ('a', 't'): 5, ('q', 'o'): 1, ('n', 'm'): 2, ('a', 's'): 3, ('r', 'l'): 1, ('t', 'e'): 4, ('p', 'u'): 1, ('v', 'n'): 1, ('r', 'e'): 6, ('l', 'v'): 1, ('v', 'm'): 1, ('r', 'q'): 1, ('s', 'r'): 1, ('i', 'u'): 1, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 3, ('t', 'c'): 1, ('a', 'i'): 3, ('v', 'u'): 1, ('l', 'r'): 1, ('i', 's'): 5, ('l', 'q'): 1, ('d', 's'): 1, ('r', 'v'): 2, ('d', 'n'): 1, ('i', 'n'): 3, ('d', 'o'): 1, ('s', 'c'): 1, ('i', 'o'): 3, ('u', 'd'): 2, ('p', 'o'): 1, ('r', 'n'): 1, ('e', 'v'): 3, ('u', 'o'): 2, ('o', 'q'): 1, ('m', 'q'): 1, ('p', 'a'): 2, ('t', 'n'): 3, ('n', 'v'): 1, ('a', 'n'): 2, ('u', 's'): 2, ('c', 'a'): 1, ('m', 'n'): 2, ('i', 'c'): 1, ('n', 'e'): 2, ('s', 'n'): 3, ('q', 'r'): 1, ('d', 'l'): 1, ('a', 'r'): 2, ('u', 'p'): 1, ('v', 'e'): 3, ('e', 'r'): 6, ('r', 'p'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('a', 'c'): 1, ('n', 'u'): 3, ('l', 'u'): 2, ('e', 'a'): 5, ('e', 'u'): 5, ('r', 's'): 1, ('u', 'a'): 5, ('a', 'b'): 1, ('e', 'o'): 4, ('a', 'e'): 5, ('c', 'n'): 1, ('t', 's'): 5, ('e', 'n'): 2, ('o', 'u'): 2, ('p', 'i'): 1, ('e', 's'): 3, ('l', 'i'): 1, ('r', 'a'): 2, ('t', 'p'): 1, ('t', 'i'): 5, ('o', 'p'): 1, ('e', 'p'): 2, ('m', 'p'): 2, ('b', 'a'): 1, ('s', 't'): 5, ('o', 't'): 3, ('v', 'a'): 2, ('u', 'n'): 3, ('a', 'o'): 2, ('o', 's'): 1, ('m', 't'): 3, ('u', 'q'): 3, ('d', 'q'): 1, ('m', 'o'): 4, ('r', 'u'): 1, ('t', 'a'): 5, ('c', 't'): 1, ('n', 's'): 3, ('o', 'a'): 2, ('m', 'a'): 4, ('i', 'v'): 2, ('s', 'a'): 3, ('q', 'd'): 1, ('a', 'l'): 1, ('a', 'm'): 4, ('n', 'a'): 2, ('m', 'e'): 4, ('m', 'c'): 1, ('v', 'o'): 2, ('v', 's'): 1, ('u', 't'): 4, ('a', 'v'): 2, ('v', 't'): 3, ('o', 'n'): 2, ('c', 'i'): 1, ('i', 'l'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 3, ('p', 'e'): 2, ('d', 'm'): 1, ('l', 'e'): 2, ('i', 'p'): 1, ('i', 'e'): 4, ('p', 'r'): 1, ('d', 'e'): 3, ('u', 'e'): 5, ('s', 'u'): 2, ('u', 'm'): 3, ('n', 't'): 3, ('o', 'i'): 3, ('l', 'a'): 1, ('v', 'l'): 1, ('u', 'r'): 1, ('t', 'u'): 4, ('i', 't'): 5, ('d', 'r'): 1, ('e', 'q'): 3, ('r', 'o'): 3, ('m', 'u'): 3, ('p', 't'): 1, ('o', 'l'): 3, ('n', 'd'): 1, ('p', 'v'): 1, ('p', 'm'): 2, ('e', 'l'): 2, ('a', 'u'): 5, ('a', 'q'): 2, ('s', 'd'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('q', 'e'): 3, ('r', 'i'): 3, ('q', 'm'): 1, ('r', 'd'): 1, ('m', 's'): 2, ('e', 'i'): 4, ('s', 'v'): 1, ('t', 'm'): 3, ('l', 'm'): 2, ('r', 'm'): 3, ('e', 'm'): 4, ('c', 'm'): 1, ('e', 't'): 5, ('m', 'v'): 1, ('p', 'l'): 1, ('r', 't'): 2, ('o', 'v'): 2, ('n', 'i'): 3, ('l', 'd'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 3, ('v', 'r'): 2, ('n', 'o'): 2, ('m', 'l'): 2, ('n', 'r'): 1, ('i', 'r'): 3, ('v', 'i'): 2, ('m', 'i'): 3, ('u', 'i'): 1, ('s', 'i'): 5, ('t', 'r'): 2, ('t', 'l'): 1, ('u', 'l'): 2, ('q', 'a'): 2, ('o', 'e'): 4, ('m', 'r'): 3, ('t', 'o'): 3, ('o', 'd'): 1, ('l', 'o'): 3, ('o', 'm'): 4, ('o', 'r'): 3, ('q', 'u'): 3, ('l', 't'): 1, ('i', 'a'): 3, ('n', 'c'): 1, ('s', 'o'): 1, ('a', 'p'): 2, ('v', 'p'): 1, ('a', 't'): 5, ('q', 'o'): 1, ('n', 'm'): 2, ('a', 's'): 3, ('r', 'l'): 1, ('t', 'e'): 5, ('p', 'u'): 1, ('v', 'n'): 1, ('r', 'e'): 6, ('l', 'v'): 1, ('v', 'm'): 1, ('r', 'q'): 1, ('s', 'r'): 1, ('i', 'u'): 1, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 3, ('t', 'c'): 1, ('a', 'i'): 3, ('v', 'u'): 1, ('l', 'r'): 1, ('i', 's'): 5, ('l', 'q'): 1, ('d', 's'): 1, ('r', 'v'): 2, ('d', 'n'): 1, ('i', 'n'): 3, ('d', 'o'): 1, ('s', 'c'): 1, ('i', 'o'): 3, ('u', 'd'): 2, ('p', 'o'): 1, ('r', 'n'): 1, ('e', 'v'): 3, ('u', 'o'): 2, ('o', 'q'): 1, ('m', 'q'): 1, ('p', 'a'): 2, ('t', 'n'): 3, ('n', 'v'): 1, ('a', 'n'): 2, ('u', 's'): 2, ('c', 'a'): 1, ('m', 'n'): 2, ('i', 'c'): 1, ('n', 'e'): 2, ('s', 'n'): 3, ('q', 'r'): 1, ('d', 'l'): 1, ('a', 'r'): 2, ('u', 'p'): 1, ('v', 'e'): 3, ('e', 'r'): 6, ('r', 'p'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('a', 'c'): 1, ('n', 'u'): 3, ('l', 'u'): 2, ('e', 'a'): 5, ('e', 'u'): 5, ('r', 's'): 1, ('u', 'a'): 5, ('a', 'b'): 1, ('e', 'o'): 4, ('a', 'e'): 5, ('c', 'n'): 1, ('t', 's'): 5, ('e', 'n'): 2, ('o', 'u'): 2, ('p', 'i'): 1, ('e', 's'): 3, ('l', 'i'): 1, ('r', 'a'): 2, ('t', 'p'): 1, ('t', 'i'): 5, ('o', 'p'): 1, ('e', 'p'): 2, ('m', 'p'): 2, ('b', 'a'): 1, ('s', 't'): 5, ('o', 't'): 3, ('v', 'a'): 2, ('u', 'n'): 3, ('a', 'o'): 2, ('o', 's'): 1, ('m', 't'): 3, ('u', 'q'): 3, ('d', 'q'): 1, ('m', 'o'): 4, ('r', 'u'): 1, ('t', 'a'): 5, ('c', 't'): 1, ('n', 's'): 3, ('o', 'a'): 2, ('m', 'a'): 4, ('i', 'v'): 2, ('s', 'a'): 3, ('q', 'd'): 1, ('a', 'l'): 1, ('a', 'm'): 4, ('n', 'a'): 2, ('m', 'e'): 4, ('m', 'c'): 1, ('v', 'o'): 2, ('v', 's'): 1, ('u', 't'): 4, ('a', 'v'): 2, ('v', 't'): 3, ('o', 'n'): 2, ('c', 'i'): 1, ('i', 'l'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 3, ('p', 'e'): 2, ('d', 'm'): 1, ('l', 'e'): 2, ('i', 'p'): 1, ('i', 'e'): 4, ('p', 'r'): 1, ('d', 'e'): 3, ('u', 'e'): 5, ('s', 'q'): 1, ('s', 'u'): 3, ('u', 'm'): 3, ('n', 't'): 3, ('o', 'i'): 3, ('l', 'a'): 1, ('v', 'l'): 1, ('u', 'r'): 1, ('t', 'u'): 4, ('i', 't'): 5, ('d', 'r'): 1, ('e', 'q'): 3, ('r', 'o'): 3, ('m', 'u'): 3, ('p', 't'): 1, ('o', 'l'): 3, ('n', 'd'): 1, ('p', 'v'): 1, ('p', 'm'): 2, ('e', 'l'): 2, ('a', 'u'): 6, ('a', 'q'): 3, ('s', 'd'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('q', 'e'): 3, ('r', 'i'): 3, ('q', 'm'): 1, ('r', 'd'): 1, ('m', 's'): 2, ('e', 'i'): 4, ('s', 'v'): 1, ('t', 'm'): 3, ('l', 'm'): 2, ('i', 'q'): 1, ('r', 'm'): 3, ('e', 'm'): 4, ('c', 'm'): 1, ('e', 't'): 5, ('m', 'v'): 1, ('p', 'l'): 1, ('r', 't'): 2, ('o', 'v'): 2, ('n', 'i'): 3, ('l', 'd'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 3, ('v', 'r'): 2, ('n', 'o'): 2, ('m', 'l'): 2, ('n', 'r'): 1, ('i', 'r'): 3, ('v', 'i'): 2, ('m', 'i'): 3, ('u', 'i'): 2, ('s', 'i'): 6, ('t', 'r'): 2, ('t', 'l'): 1, ('u', 'l'): 2, ('q', 'a'): 3, ('o', 'e'): 4, ('m', 'r'): 3, ('t', 'o'): 3, ('o', 'd'): 1, ('l', 'o'): 3, ('o', 'm'): 4, ('o', 'r'): 3, ('q', 'u'): 4, ('l', 't'): 1, ('i', 'a'): 4, ('q', 's'): 1, ('n', 'c'): 1, ('s', 'o'): 1, ('a', 'p'): 2, ('v', 'p'): 1, ('a', 't'): 5, ('q', 'o'): 1, ('n', 'm'): 2, ('a', 's'): 4, ('r', 'l'): 1, ('t', 'e'): 5, ('p', 'u'): 1, ('v', 'n'): 1, ('r', 'e'): 6, ('l', 'v'): 1, ('v', 'm'): 1, ('r', 'q'): 1, ('s', 'r'): 1, ('i', 'u'): 2, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 3, ('t', 'c'): 1, ('a', 'i'): 4, ('v', 'u'): 1, ('l', 'r'): 1, ('i', 's'): 6, ('l', 'q'): 1, ('d', 's'): 1, ('r', 'v'): 2, ('d', 'n'): 1, ('i', 'n'): 3, ('d', 'o'): 1, ('s', 'c'): 1, ('i', 'o'): 3, ('u', 'd'): 2, ('p', 'o'): 1, ('r', 'n'): 1, ('e', 'v'): 3, ('u', 'o'): 2, ('o', 'q'): 1, ('m', 'q'): 1, ('p', 'a'): 2, ('t', 'n'): 3, ('n', 'v'): 1, ('a', 'n'): 2, ('u', 's'): 3, ('c', 'a'): 1, ('m', 'n'): 2, ('i', 'c'): 1, ('n', 'e'): 2, ('s', 'n'): 3, ('q', 'r'): 1, ('d', 'l'): 1, ('a', 'r'): 2, ('u', 'p'): 1, ('v', 'e'): 3, ('e', 'r'): 6, ('r', 'p'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('a', 'c'): 1, ('n', 'u'): 3, ('l', 'u'): 2, ('e', 'a'): 5, ('e', 'u'): 5, ('r', 's'): 1, ('u', 'a'): 6, ('a', 'b'): 1, ('e', 'o'): 4, ('a', 'e'): 5, ('c', 'n'): 1, ('t', 's'): 5, ('e', 'n'): 2, ('o', 'u'): 2, ('p', 'i'): 1, ('e', 's'): 3, ('l', 'i'): 1, ('r', 'a'): 2, ('t', 'p'): 1, ('t', 'i'): 5, ('o', 'p'): 1, ('e', 'p'): 2, ('m', 'p'): 2, ('b', 'a'): 1, ('s', 't'): 5, ('o', 't'): 3, ('v', 'a'): 2, ('u', 'n'): 3, ('a', 'o'): 2, ('o', 's'): 1, ('m', 't'): 3, ('u', 'q'): 4, ('d', 'q'): 1, ('m', 'o'): 4, ('r', 'u'): 1, ('t', 'a'): 5, ('c', 't'): 1, ('n', 's'): 3, ('o', 'a'): 2, ('m', 'a'): 4, ('i', 'v'): 2, ('s', 'a'): 4, ('q', 'd'): 1, ('q', 'i'): 1, ('a', 'l'): 1, ('a', 'm'): 4, ('n', 'a'): 2, ('m', 'e'): 4, ('m', 'c'): 1, ('v', 'o'): 2, ('v', 's'): 1, ('u', 't'): 4, ('a', 'v'): 2, ('v', 't'): 3, ('o', 'n'): 2, ('c', 'i'): 1, ('i', 'l'): 1})
# defaultdict(<class 'int'>, {('i', 'm'): 3, ('p', 'e'): 2, ('h', 'i'): 1, ('d', 'm'): 1, ('l', 'e'): 2, ('i', 'p'): 1, ('i', 'e'): 5, ('p', 'r'): 1, ('d', 'e'): 3, ('u', 'e'): 5, ('s', 'q'): 1, ('s', 'u'): 3, ('u', 'm'): 3, ('n', 't'): 3, ('o', 'i'): 4, ('l', 'a'): 1, ('v', 'l'): 1, ('u', 'r'): 1, ('o', 'c'): 1, ('t', 'u'): 4, ('i', 't'): 6, ('d', 'r'): 1, ('h', 't'): 1, ('e', 'q'): 3, ('r', 'o'): 4, ('m', 'u'): 3, ('p', 't'): 1, ('o', 'l'): 3, ('n', 'd'): 1, ('p', 'v'): 1, ('p', 'm'): 2, ('h', 'o'): 1, ('e', 'h'): 1, ('e', 'l'): 2, ('c', 'h'): 1, ('a', 'u'): 6, ('a', 'q'): 3, ('s', 'd'): 1, ('u', 'v'): 1, ('l', 'p'): 1, ('q', 'e'): 3, ('r', 'i'): 4, ('q', 'm'): 1, ('r', 'd'): 1, ('r', 'c'): 1, ('m', 's'): 2, ('e', 'i'): 5, ('s', 'v'): 1, ('t', 'm'): 3, ('l', 'm'): 2, ('i', 'q'): 1, ('r', 'm'): 3, ('e', 'm'): 4, ('h', 'r'): 1, ('c', 'm'): 1, ('e', 't'): 6, ('m', 'v'): 1, ('p', 'l'): 1, ('r', 't'): 3, ('o', 'v'): 2, ('n', 'i'): 3, ('l', 'd'): 1, ('s', 'm'): 2, ('c', 's'): 1, ('e', 'd'): 3, ('t', 'v'): 3, ('v', 'r'): 2, ('n', 'o'): 2, ('m', 'l'): 2, ('n', 'r'): 1, ('i', 'r'): 4, ('v', 'i'): 2, ('m', 'i'): 3, ('u', 'i'): 2, ('s', 'i'): 6, ('t', 'r'): 3, ('t', 'h'): 1, ('t', 'l'): 1, ('u', 'l'): 2, ('q', 'a'): 3, ('o', 'e'): 5, ('m', 'r'): 3, ('t', 'o'): 4, ('o', 'd'): 1, ('l', 'o'): 3, ('o', 'm'): 4, ('o', 'r'): 4, ('q', 'u'): 4, ('l', 't'): 1, ('i', 'a'): 5, ('q', 's'): 1, ('n', 'c'): 1, ('s', 'o'): 1, ('a', 'p'): 2, ('v', 'p'): 1, ('a', 't'): 6, ('q', 'o'): 1, ('n', 'm'): 2, ('c', 'o'): 1, ('a', 's'): 4, ('r', 'l'): 1, ('t', 'e'): 6, ('p', 'u'): 1, ('v', 'n'): 1, ('r', 'e'): 7, ('l', 'v'): 1, ('v', 'm'): 1, ('h', 'c'): 1, ('r', 'q'): 1, ('s', 'r'): 1, ('i', 'u'): 2, ('m', 'd'): 1, ('d', 'u'): 2, ('u', 'c'): 1, ('s', 'e'): 3, ('t', 'c'): 2, ('a', 'i'): 5, ('v', 'u'): 1, ('l', 'r'): 1, ('i', 's'): 6, ('l', 'q'): 1, ('d', 's'): 1, ('r', 'v'): 2, ('d', 'n'): 1, ('i', 'n'): 3, ('d', 'o'): 1, ('s', 'c'): 1, ('i', 'o'): 4, ('u', 'd'): 2, ('p', 'o'): 1, ('r', 'n'): 1, ('e', 'v'): 3, ('u', 'o'): 2, ('o', 'q'): 1, ('m', 'q'): 1, ('p', 'a'): 2, ('t', 'n'): 3, ('n', 'v'): 1, ('a', 'n'): 2, ('u', 's'): 3, ('c', 'a'): 2, ('m', 'n'): 2, ('h', 'a'): 1, ('i', 'c'): 2, ('n', 'e'): 2, ('s', 'n'): 3, ('q', 'r'): 1, ('d', 'l'): 1, ('a', 'r'): 3, ('e', 'c'): 1, ('u', 'p'): 1, ('v', 'e'): 3, ('e', 'r'): 7, ('h', 'e'): 1, ('r', 'p'): 1, ('q', 'l'): 1, ('c', 'u'): 1, ('a', 'c'): 2, ('n', 'u'): 3, ('l', 'u'): 2, ('e', 'a'): 6, ('e', 'u'): 5, ('r', 's'): 1, ('u', 'a'): 6, ('a', 'b'): 1, ('e', 'o'): 5, ('a', 'e'): 6, ('c', 'n'): 1, ('t', 's'): 5, ('e', 'n'): 2, ('c', 'r'): 1, ('o', 'u'): 2, ('p', 'i'): 1, ('e', 's'): 3, ('l', 'i'): 1, ('r', 'a'): 3, ('t', 'p'): 1, ('t', 'i'): 6, ('o', 'h'): 1, ('o', 'p'): 1, ('e', 'p'): 2, ('m', 'p'): 2, ('b', 'a'): 1, ('s', 't'): 5, ('o', 't'): 4, ('v', 'a'): 2, ('u', 'n'): 3, ('a', 'o'): 3, ('o', 's'): 1, ('m', 't'): 3, ('u', 'q'): 4, ('d', 'q'): 1, ('m', 'o'): 4, ('r', 'u'): 1, ('t', 'a'): 6, ('c', 't'): 2, ('n', 's'): 3, ('o', 'a'): 3, ('m', 'a'): 4, ('r', 'h'): 1, ('i', 'v'): 2, ('s', 'a'): 4, ('q', 'd'): 1, ('q', 'i'): 1, ('i', 'h'): 1, ('a', 'l'): 1, ('a', 'm'): 4, ('n', 'a'): 2, ('m', 'e'): 4, ('m', 'c'): 1, ('v', 'o'): 2, ('c', 'e'): 1, ('v', 's'): 1, ('u', 't'): 4, ('a', 'v'): 2, ('v', 't'): 3, ('o', 'n'): 2, ('c', 'i'): 2, ('a', 'h'): 1, ('i', 'l'): 1})
# ...
# defaultdict(<class 'int'>, {('i', 'm'): 28, ('p', 'm'): 8, ('p', 'r'): 10, ('v', 'a'): 11, ('s', 'u'): 33, ('n', 'x'): 1, ('u', 'm'): 32, ('o', 'i'): 27, ('c', 'x'): 2, ('d', 'p'): 4, ('l', 'a'): 23, ('v', 'l'): 12, ('u', 'r'): 21, ('t', 'u'): 44, ('i', 't'): 33, ('p', 'f'): 1, ('e', 'q'): 13, ('b', 'd'): 3, ('m', 'u'): 32, ('n', 'd'): 10, ('a', 'f'): 3, ('l', 'h'): 2, ('h', 'o'): 1, ('e', 'h'): 1, ('e', 'l'): 21, ('a', 'q'): 18, ('l', 'p'): 9, ('q', 'e'): 13, ('r', 'i'): 16, ('n', 'c'): 7, ('q', 'm'): 9, ('r', 'c'): 9, ('q', 't'): 5, ('m', 's'): 19, ('p', 'l'): 9, ('q', 's'): 11, ('g', 's'): 1, ('i', 'q'): 21, ('c', 'r'): 9, ('h', 'r'): 2, ('c', 'm'): 6, ('e', 't'): 53, ('m', 'v'): 3, ('g', 'm'): 3, ('v', 'p'): 9, ('c', 's'): 11, ('e', 'd'): 21, ('g', 'e'): 1, ('m', 'l'): 15, ('n', 'r'): 14, ('l', 'r'): 12, ('i', 'x'): 4, ('m', 'i'): 28, ('p', 'n'): 5, ('e', 'o'): 30, ('o', 'e'): 30, ('t', 'o'): 28, ('l', 'o'): 27, ('n', 'b'): 3, ('o', 'm'): 25, ('o', 'r'): 27, ('q', 'u'): 37, ('b', 'e'): 7, ('i', 'a'): 39, ('b', 'r'): 4, ('a', 'p'): 19, ('o', 'v'): 11, ('d', 'i'): 19, ('v', 'r'): 3, ('l', 'b'): 5, ('t', 'd'): 8, ('l', 'v'): 12, ('c', 'e'): 12, ('i', 'u'): 34, ('i', 'p'): 13, ('r', 'b'): 4, ('u', 'c'): 11, ('t', 'c'): 12, ('p', 'x'): 2, ('n', 'f'): 1, ('s', 'd'): 13, ('s', 'b'): 7, ('q', 'c'): 3, ('i', 's'): 41, ('b', 'i'): 9, ('n', 'h'): 2, ('r', 'v'): 3, ('s', 'c'): 11, ('f', 's'): 3, ('n', 'q'): 4, ('o', 'l'): 27, ('o', 'f'): 2, ('r', 'n'): 14, ('e', 'v'): 11, ('f', 'o'): 2, ('u', 'o'): 23, ('o', 'q'): 7, ('r', 'e'): 38, ('a', 'n'): 18, ('b', 'u'): 5, ('c', 'a'): 12, ('d', 'c'): 4, ('h', 'a'): 2, ('s', 'n'): 24, ('p', 'b'): 2, ('b', 'n'): 3, ('r', 'f'): 2, ('v', 'e'): 11, ('b', 'o'): 7, ('m', 'd'): 10, ('q', 'l'): 4, ('c', 'u'): 11, ('c', 'p'): 4, ('r', 't'): 17, ('e', 'a'): 41, ('g', 'o'): 1, ('r', 's'): 15, ('a', 'b'): 9, ('a', 'e'): 41, ('q', 'a'): 18, ('t', 's'): 34, ('l', 'n'): 6, ('e', 's'): 33, ('l', 'i'): 18, ('p', 'c'): 4, ('b', 't'): 7, ('o', 'p'): 13, ('e', 'p'): 16, ('i', 'd'): 19, ('b', 'a'): 9, ('s', 't'): 34, ('o', 't'): 28, ('x', 'o'): 1, ('b', 'm'): 3, ('d', 't'): 8, ('s', 'p'): 14, ('o', 's'): 27, ('h', 'u'): 1, ('l', 'g'): 1, ('a', 'h'): 2, ('a', 'o'): 25, ('m', 'o'): 25, ('d', 'r'): 13, ('h', 'n'): 2, ('b', 'l'): 5, ('n', 's'): 24, ('o', 'a'): 25, ('l', 'q'): 4, ('o', 'g'): 1, ('s', 'g'): 1, ('i', 'v'): 5, ('d', 's'): 13, ('s', 'a'): 29, ('i', 'h'): 4, ('x', 'm'): 2, ('m', 'e'): 32, ('x', 'e'): 5, ('q', 'r'): 4, ('e', 'x'): 5, ('b', 's'): 7, ('d', 'g'): 2, ('o', 'n'): 16, ('u', 's'): 33, ('f', 'c'): 4, ('a', 'x'): 3, ('c', 'i'): 16, ('h', 'l'): 2, ('p', 'e'): 16, ('h', 'i'): 4, ('d', 'm'): 10, ('l', 'e'): 21, ('f', 'r'): 2, ('d', 'q'): 5, ('i', 'e'): 37, ('d', 'e'): 21, ('u', 'e'): 39, ('s', 'q'): 11, ('d', 'f'): 1, ('i', 'f'): 4, ('s', 'f'): 3, ('o', 'c'): 10, ('t', 'q'): 5, ('g', 'a'): 2, ('e', 'r'): 38, ('l', 't'): 17, ('h', 't'): 1, ('r', 'o'): 27, ('p', 't'): 18, ('u', 'd'): 11, ('c', 'h'): 2, ('a', 'u'): 50, ('u', 'h'): 1, ('t', 'x'): 3, ('u', 'v'): 9, ('r', 'd'): 13, ('s', 'v'): 6, ('t', 'm'): 17, ('l', 'm'): 15, ('r', 'm'): 18, ('e', 'm'): 32, ('i', 'r'): 16, ('n', 'l'): 6, ('f', 'e'): 2, ('n', 'i'): 29, ('l', 'd'): 13, ('s', 'm'): 19, ('s', 'l'): 15, ('t', 'v'): 13, ('g', 'd'): 2, ('c', 'f'): 4, ('n', 'o'): 16, ('e', 'f'): 2, ('f', 'n'): 1, ('v', 'i'): 5, ('u', 'i'): 34, ('h', 'c'): 2, ('t', 'r'): 17, ('t', 'h'): 1, ('t', 'l'): 17, ('u', 'l'): 18, ('n', 'a'): 18, ('m', 'r'): 18, ('p', 'a'): 19, ('g', 'n'): 4, ('e', 'i'): 37, ('b', 'q'): 1, ('a', 't'): 47, ('o', 'x'): 1, ('n', 'm'): 18, ('x', 'r'): 2, ('c', 'b'): 2, ('a', 's'): 29, ('r', 'l'): 12, ('e', 'b'): 7, ('t', 'e'): 53, ('m', 'b'): 3, ('p', 'u'): 16, ('v', 'n'): 1, ('t', 'b'): 7, ('v', 'm'): 3, ('r', 'q'): 4, ('q', 'b'): 1, ('e', 'g'): 1, ('d', 'u'): 11, ('s', 'e'): 33, ('a', 'i'): 39, ('v', 'u'): 9, ('f', 'p'): 1, ('s', 'r'): 15, ('d', 'n'): 10, ('i', 'n'): 29, ('p', 's'): 14, ('d', 'o'): 15, ('r', 'x'): 2, ('i', 'o'): 27, ('p', 'o'): 1 ...
# defaultdict(<class 'int'>, {('i', 'm'): 28, ('p', 'm'): 8, ('p', 'r'): 10, ('v', 'a'): 11, ('s', 'u'): 34, ('n', 'x'): 1, ('u', 'm'): 32, ('o', 'i'): 28, ('c', 'x'): 2, ('d', 'p'): 4, ('l', 'a'): 23, ('v', 'l'): 12, ('u', 'r'): 22, ('t', 'u'): 44, ('i', 't'): 33, ('p', 'f'): 1, ('e', 'q'): 13, ('b', 'd'): 4, ('m', 'u'): 32, ('n', 'd'): 10, ('a', 'f'): 3, ('l', 'h'): 2, ('h', 'o'): 1, ('e', 'h'): 1, ('e', 'l'): 21, ('a', 'q'): 18, ('l', 'p'): 9, ('q', 'e'): 13, ('r', 'i'): 17, ('n', 'c'): 7, ('q', 'm'): 9, ('r', 'c'): 9, ('q', 't'): 5, ('m', 's'): 19, ('p', 'l'): 9, ('q', 's'): 11, ('g', 's'): 1, ('i', 'q'): 21, ('c', 'r'): 9, ('h', 'r'): 2, ('c', 'm'): 6, ('e', 't'): 53, ('m', 'v'): 3, ('g', 'm'): 3, ('v', 'p'): 9, ('c', 's'): 11, ('e', 'd'): 21, ('g', 'e'): 1, ('m', 'l'): 15, ('n', 'r'): 14, ('l', 'r'): 13, ('i', 'x'): 4, ('m', 'i'): 28, ('p', 'n'): 5, ('e', 'o'): 30, ('o', 'e'): 30, ('t', 'o'): 28, ('l', 'o'): 28, ('n', 'b'): 3, ('o', 'm'): 25, ('o', 'r'): 28, ('q', 'u'): 37, ('b', 'e'): 7, ('i', 'a'): 39, ('b', 'r'): 5, ('a', 'p'): 19, ('o', 'v'): 11, ('d', 'i'): 20, ('v', 'r'): 3, ('l', 'b'): 6, ('t', 'd'): 8, ('l', 'v'): 12, ('c', 'e'): 12, ('i', 'u'): 35, ('i', 'p'): 13, ('r', 'b'): 5, ('u', 'c'): 11, ('t', 'c'): 12, ('p', 'x'): 2, ('n', 'f'): 1, ('s', 'd'): 14, ('s', 'b'): 8, ('q', 'c'): 3, ('i', 's'): 42, ('b', 'i'): 10, ('n', 'h'): 2, ('r', 'v'): 3, ('s', 'c'): 11, ('f', 's'): 3, ('n', 'q'): 4, ('o', 'l'): 28, ('o', 'f'): 2, ('r', 'n'): 14, ('e', 'v'): 11, ('f', 'o'): 2, ('u', 'o'): 24, ('o', 'q'): 7, ('r', 'e'): 38, ('a', 'n'): 18, ('b', 'u'): 6, ('c', 'a'): 12, ('d', 'c'): 4, ('h', 'a'): 2, ('s', 'n'): 24, ('p', 'b'): 2, ('b', 'n'): 3, ('r', 'f'): 2, ('v', 'e'): 11, ('b', 'o'): 8, ('m', 'd'): 10, ('q', 'l'): 4, ('c', 'u'): 11, ('c', 'p'): 4, ('r', 't'): 17, ('e', 'a'): 41, ('g', 'o'): 1, ('r', 's'): 16, ('a', 'b'): 9, ('a', 'e'): 41, ('q', 'a'): 18, ('t', 's'): 34, ('l', 'n'): 6, ('e', 's'): 33, ('l', 'i'): 19, ('p', 'c'): 4, ('b', 't'): 7, ('o', 'p'): 13, ('e', 'p'): 16, ('i', 'd'): 20, ('b', 'a'): 9, ('s', 't'): 34, ('o', 't'): 28, ('x', 'o'): 1, ('b', 'm'): 3, ('d', 't'): 8, ('s', 'p'): 14, ('o', 's'): 28, ('h', 'u'): 1, ('l', 'g'): 1, ('a', 'h'): 2, ('a', 'o'): 25, ('m', 'o'): 25, ('d', 'r'): 14, ('h', 'n'): 2, ('b', 'l'): 6, ('n', 's'): 24, ('o', 'a'): 25, ('l', 'q'): 4, ('o', 'g'): 1, ('s', 'g'): 1, ('i', 'v'): 5, ('d', 's'): 14, ('s', 'a'): 29, ('i', 'h'): 4, ('x', 'm'): 2, ('m', 'e'): 32, ('x', 'e'): 5, ('q', 'r'): 4, ('e', 'x'): 5, ('b', 's'): 8, ('d', 'g'): 2, ('o', 'n'): 16, ('u', 's'): 34, ('f', 'c'): 4, ('a', 'x'): 3, ('c', 'i'): 16, ('h', 'l'): 2, ('p', 'e'): 16, ('h', 'i'): 4, ('d', 'm'): 10, ('l', 'e'): 21, ('f', 'r'): 2, ('d', 'q'): 5, ('i', 'e'): 37, ('d', 'e'): 21, ('u', 'e'): 39, ('s', 'q'): 11, ('d', 'f'): 1, ('i', 'f'): 4, ('s', 'f'): 3, ('o', 'c'): 10, ('t', 'q'): 5, ('g', 'a'): 2, ('e', 'r'): 38, ('l', 't'): 17, ('h', 't'): 1, ('r', 'o'): 28, ('p', 't'): 18, ('u', 'd'): 12, ('c', 'h'): 2, ('a', 'u'): 50, ('u', 'h'): 1, ('t', 'x'): 3, ('u', 'v'): 9, ('r', 'd'): 14, ('s', 'v'): 6, ('t', 'm'): 17, ('l', 'm'): 15, ('r', 'm'): 18, ('e', 'm'): 32, ('i', 'r'): 17, ('n', 'l'): 6, ('f', 'e'): 2, ('n', 'i'): 29, ('l', 'd'): 14, ('s', 'm'): 19, ('s', 'l'): 16, ('t', 'v'): 13, ('g', 'd'): 2, ('c', 'f'): 4, ('n', 'o'): 16, ('e', 'f'): 2, ('f', 'n'): 1, ('v', 'i'): 5, ('u', 'i'): 35, ('h', 'c'): 2, ('t', 'r'): 17, ('t', 'h'): 1, ('t', 'l'): 17, ('u', 'l'): 19, ('n', 'a'): 18, ('m', 'r'): 18, ('p', 'a'): 19, ('g', 'n'): 4, ('e', 'i'): 37, ('b', 'q'): 1, ('a', 't'): 47, ('o', 'x'): 1, ('n', 'm'): 18, ('x', 'r'): 2, ('c', 'b'): 2, ('a', 's'): 29, ('r', 'l'): 13, ('e', 'b'): 7, ('t', 'e'): 53, ('m', 'b'): 3, ('p', 'u'): 16, ('v', 'n'): 1, ('t', 'b'): 7, ('v', 'm'): 3, ('r', 'q'): 4, ('q', 'b'): 1, ('e', 'g'): 1, ('d', 'u'): 12, ('s', 'e'): 33, ('a', 'i'): 39, ('v', 'u'): 9, ('f', 'p'): 1, ('s', 'r'): 16, ('d', 'n'): 10, ('i', 'n'): 29, ('p', 's'): 14, ('d', 'o'): 16, ('r', 'x'): 2, ('i', 'o'): 28, ('p', 'o'):  ...
# defaultdict(<class 'int'>, {('i', 'm'): 28, ('p', 'm'): 8, ('p', 'r'): 11, ('v', 'a'): 11, ('s', 'u'): 34, ('n', 'x'): 1, ('u', 'm'): 32, ('o', 'i'): 29, ('c', 'x'): 2, ('d', 'p'): 4, ('l', 'a'): 23, ('v', 'l'): 12, ('u', 'r'): 22, ('t', 'u'): 44, ('i', 't'): 33, ('p', 'f'): 1, ('e', 'q'): 13, ('b', 'd'): 4, ('m', 'u'): 32, ('n', 'd'): 10, ('a', 'f'): 3, ('l', 'h'): 2, ('h', 'o'): 1, ('e', 'h'): 1, ('e', 'l'): 21, ('a', 'q'): 18, ('l', 'p'): 9, ('q', 'e'): 13, ('r', 'i'): 18, ('n', 'c'): 7, ('q', 'm'): 9, ('r', 'c'): 9, ('q', 't'): 5, ('m', 's'): 19, ('p', 'l'): 9, ('q', 's'): 11, ('g', 's'): 1, ('i', 'q'): 21, ('c', 'r'): 9, ('h', 'r'): 2, ('c', 'm'): 6, ('e', 't'): 53, ('m', 'v'): 3, ('g', 'm'): 3, ('v', 'p'): 9, ('c', 's'): 11, ('e', 'd'): 21, ('g', 'e'): 1, ('m', 'l'): 15, ('n', 'r'): 14, ('l', 'r'): 13, ('i', 'x'): 4, ('m', 'i'): 28, ('p', 'n'): 5, ('e', 'o'): 31, ('o', 'e'): 31, ('t', 'o'): 28, ('l', 'o'): 28, ('n', 'b'): 3, ('o', 'm'): 25, ('o', 'r'): 29, ('q', 'u'): 37, ('b', 'e'): 7, ('i', 'a'): 40, ('b', 'r'): 5, ('a', 'p'): 20, ('o', 'v'): 11, ('d', 'i'): 20, ('v', 'r'): 3, ('l', 'b'): 6, ('t', 'd'): 8, ('l', 'v'): 12, ('c', 'e'): 12, ('i', 'u'): 35, ('i', 'p'): 14, ('r', 'b'): 5, ('u', 'c'): 11, ('t', 'c'): 12, ('p', 'x'): 2, ('n', 'f'): 1, ('s', 'd'): 14, ('s', 'b'): 8, ('q', 'c'): 3, ('i', 's'): 43, ('b', 'i'): 10, ('n', 'h'): 2, ('r', 'v'): 3, ('s', 'c'): 11, ('f', 's'): 3, ('n', 'q'): 4, ('o', 'l'): 28, ('o', 'f'): 2, ('r', 'n'): 14, ('e', 'v'): 11, ('f', 'o'): 2, ('u', 'o'): 24, ('o', 'q'): 7, ('r', 'e'): 39, ('a', 'n'): 18, ('b', 'u'): 6, ('c', 'a'): 12, ('d', 'c'): 4, ('h', 'a'): 2, ('s', 'n'): 24, ('p', 'b'): 2, ('b', 'n'): 3, ('r', 'f'): 2, ('v', 'e'): 11, ('b', 'o'): 8, ('m', 'd'): 10, ('q', 'l'): 4, ('c', 'u'): 11, ('c', 'p'): 4, ('r', 't'): 17, ('e', 'a'): 42, ('g', 'o'): 1, ('r', 's'): 17, ('a', 'b'): 9, ('a', 'e'): 42, ('q', 'a'): 18, ('t', 's'): 34, ('l', 'n'): 6, ('e', 's'): 34, ('l', 'i'): 19, ('p', 'c'): 4, ('b', 't'): 7, ('o', 'p'): 14, ('e', 'p'): 17, ('i', 'd'): 20, ('b', 'a'): 9, ('s', 't'): 34, ('o', 't'): 28, ('x', 'o'): 1, ('b', 'm'): 3, ('d', 't'): 8, ('s', 'p'): 15, ('o', 's'): 29, ('h', 'u'): 1, ('l', 'g'): 1, ('a', 'h'): 2, ('a', 'o'): 26, ('m', 'o'): 25, ('d', 'r'): 14, ('h', 'n'): 2, ('b', 'l'): 6, ('n', 's'): 24, ('o', 'a'): 26, ('l', 'q'): 4, ('o', 'g'): 1, ('s', 'g'): 1, ('i', 'v'): 5, ('d', 's'): 14, ('s', 'a'): 30, ('i', 'h'): 4, ('x', 'm'): 2, ('m', 'e'): 32, ('x', 'e'): 5, ('q', 'r'): 4, ('e', 'x'): 5, ('b', 's'): 8, ('d', 'g'): 2, ('o', 'n'): 16, ('u', 's'): 34, ('f', 'c'): 4, ('a', 'x'): 3, ('c', 'i'): 16, ('h', 'l'): 2, ('p', 'e'): 17, ('h', 'i'): 4, ('d', 'm'): 10, ('l', 'e'): 21, ('f', 'r'): 2, ('d', 'q'): 5, ('i', 'e'): 38, ('d', 'e'): 21, ('u', 'e'): 39, ('s', 'q'): 11, ('d', 'f'): 1, ('i', 'f'): 4, ('s', 'f'): 3, ('o', 'c'): 10, ('t', 'q'): 5, ('g', 'a'): 2, ('e', 'r'): 39, ('l', 't'): 17, ('h', 't'): 1, ('r', 'o'): 29, ('p', 't'): 18, ('u', 'd'): 12, ('c', 'h'): 2, ('a', 'u'): 50, ('u', 'h'): 1, ('t', 'x'): 3, ('u', 'v'): 9, ('r', 'd'): 14, ('s', 'v'): 6, ('t', 'm'): 17, ('l', 'm'): 15, ('r', 'm'): 18, ('e', 'm'): 32, ('i', 'r'): 18, ('n', 'l'): 6, ('f', 'e'): 2, ('n', 'i'): 29, ('l', 'd'): 14, ('s', 'm'): 19, ('s', 'l'): 16, ('t', 'v'): 13, ('g', 'd'): 2, ('c', 'f'): 4, ('n', 'o'): 16, ('e', 'f'): 2, ('f', 'n'): 1, ('v', 'i'): 5, ('u', 'i'): 35, ('h', 'c'): 2, ('t', 'r'): 17, ('t', 'h'): 1, ('t', 'l'): 17, ('u', 'l'): 19, ('n', 'a'): 18, ('m', 'r'): 18, ('p', 'a'): 20, ('g', 'n'): 4, ('e', 'i'): 38, ('b', 'q'): 1, ('a', 't'): 47, ('o', 'x'): 1, ('n', 'm'): 18, ('x', 'r'): 2, ('c', 'b'): 2, ('a', 's'): 30, ('r', 'l'): 13, ('e', 'b'): 7, ('t', 'e'): 53, ('m', 'b'): 3, ('p', 'u'): 16, ('v', 'n'): 1, ('t', 'b'): 7, ('v', 'm'): 3, ('r', 'q'): 4, ('q', 'b'): 1, ('e', 'g'): 1, ('d', 'u'): 12, ('s', 'e'): 34, ('a', 'i'): 40, ('v', 'u'): 9, ('f', 'p'): 1, ('s', 'r'): 17, ('d', 'n'): 10, ('i', 'n'): 29, ('p', 's'): 15, ('d', 'o'): 16, ('r', 'x'): 2, ('i', 'o'): 29, ('p', 'o'):  ...
# conf(g => n) = 1.000
# conf(q => u) = 1.000
# conf(x => e) = 1.000
# conf(v => t) = 0.812
# conf(r => e) = 0.812
# conf(f => c) = 0.800
# conf(h => i) = 0.800
# conf(x => i) = 0.800
# conf(f => i) = 0.800
# conf(p => a) = 0.769

# %%
# `latin_rules_test`: Test cell
assert len(latin_rules) == 10
assert all([0.75 <= v <= 1.0 for v in latin_rules.values()])
for ab in ['xe', 'qu', 'hi', 'xi', 'vt', 're', 've', 'fi', 'gi', 'bi']:
    assert (ab[0], ab[1]) in latin_rules
print("\n(Passed!)")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-142-e1c34b7d584a> in <module>()
#       3 assert all([0.75 <= v <= 1.0 for v in latin_rules.values()])
#       4 for ab in ['xe', 'qu', 'hi', 'xi', 'vt', 're', 've', 'fi', 'gi', 'bi']:
# ----> 5     assert (ab[0], ab[1]) in latin_rules
#       6 print("\n(Passed!)")
#
# AssertionError:

# %% [markdown]
# As a final exercise, let's look at rules common to Latin text _and_ English text. You'll need the English translation of the _lorem ipsum_ text, encoded as the variable `english_text` in the next code cell:

# %%
english_text = """
But I must explain to you how all this mistaken idea
of denouncing of a pleasure and praising pain was
born and I will give you a complete account of the
system, and expound the actual teachings of the great
explorer of the truth, the master-builder of human
happiness. No one rejects, dislikes, or avoids
pleasure itself, because it is pleasure, but because
those who do not know how to pursue pleasure
rationally encounter consequences that are extremely
painful. Nor again is there anyone who loves or
pursues or desires to obtain pain of itself, because
it is pain, but occasionally circumstances occur in
which toil and pain can procure him some great
pleasure. To take a trivial example, which of us
ever undertakes laborious physical exercise, except
to obtain some advantage from it? But who has any
right to find fault with a man who chooses to enjoy
a pleasure that has no annoying consequences, or
one who avoids a pain that produces no resultant
pleasure?

On the other hand, we denounce with righteous
indignation and dislike men who are so beguiled and
demoralized by the charms of pleasure of the moment,
so blinded by desire, that they cannot foresee the
pain and trouble that are bound to ensue; and equal
blame belongs to those who fail in their duty
through weakness of will, which is the same as
saying through shrinking from toil and pain. These
cases are perfectly simple and easy to distinguish.
In a free hour, when our power of choice is
untrammeled and when nothing prevents our being
able to do what we like best, every pleasure is to
be welcomed and every pain avoided. But in certain
circumstances and owing to the claims of duty or
the obligations of business it will frequently
occur that pleasures have to be repudiated and
annoyances accepted. The wise man therefore always
holds in these matters to this principle of
selection: he rejects pleasures to secure other
greater pleasures, or else he endures pains to
avoid worse pains.
"""

# %% [markdown]
# **Exercise 9** (`intersect_keys_test`: 2 points). Write a function that, given two dictionaries, finds the intersection of their keys.

# %%
def intersect_keys(d1, d2):
    assert type(d1) is dict or type(d1) is defaultdict
    assert type(d2) is dict or type(d2) is defaultdict
#
# YOUR CODE HERE
#
    '''a=set(d1.keys())
    b=set(d2.keys())
    return(a-(a-b))'''
    a=list(d1.keys())
    b=list(d2.keys())
    return [element for element in a if element in b]

d1={'s': 1, 'e': 1, 'd': 1}
d2={('c', 'b'): 1, ('a', 'b'): 1, ('c', 'a'): 2, ('b', 'a'): 1, ('a', 'c'): 2, ('b', 'c'): 1}
print(intersect_keys(d1,d2))
# Out:
# []

# %%
# `intersect_keys_test`: Test cell
from random import sample

key_space = {'ape', 'baboon', 'bonobo', 'chimp', 'gorilla', 'monkey', 'orangutan'}
val_space = range(100)

for trial in range(10): # Try 10 random tests
    d1 = {k: v for k, v in zip(sample(key_space, 4), sample(val_space, 4))}
    d2 = {k: v for k, v in zip(sample(key_space, 3), sample(val_space, 3))}
    k_common = intersect_keys(d1, d2)
    for k in key_space:
        is_common = (k in k_common) and (k in d1) and (k in d2)
        is_not_common = (k not in k_common) and ((k not in d1) or (k not in d2))
        assert is_common or is_not_common
        
print("\n(Passed!)")
# Out:
# (Passed!)

# %% [markdown]
# **Exercise 10** (`common_high_conf_rules_test`: 1 points). Let's consider any rules with a confidence of at least 0.75 to be a "high-confidence rule."
#
# Write some code that finds all high-confidence rules appearing in _both_ the Latin text _and_ the English text. Store your result in a list named `common_high_conf_rules` whose elements are $(a, b)$ pairs corresponding to the rules $a \Rightarrow b$.

# %%
#
# YOUR CODE HERE
#
'''a=get_normalized_words(english_text)
b=make_itemsets(a)
english_rules=find_assoc_rules(b,.75)
common_high_conf_rules=intersect_keys(english_rules,latin_rules)'''

a=get_normalized_words(english_text)
b=make_itemsets(a)
englist_rules=find_assoc_rules(b,.75)
common_high_conf_rules=intersect_keys(english_rules,latin_rules)

print("High-confidence rules common to _lorem ipsum_ in Latin and English:")
print_rules(common_high_conf_rules)
# Out:
# defaultdict(<class 'int'>, {('b', 't'): 1, ('b', 'u'): 1, ('u', 'b'): 1, ('t', 'u'): 1, ('t', 'b'): 1, ('u', 't'): 1})
# defaultdict(<class 'int'>, {('b', 't'): 1, ('b', 'u'): 1, ('u', 'b'): 1, ('t', 'u'): 1, ('t', 'b'): 1, ('u', 't'): 1})
# defaultdict(<class 'int'>, {('u', 's'): 1, ('b', 'u'): 1, ('m', 's'): 1, ('b', 't'): 1, ('t', 'u'): 2, ('t', 'm'): 1, ('u', 't'): 2, ('t', 's'): 1, ('s', 'u'): 1, ('s', 't'): 1, ('m', 'u'): 1, ('u', 'b'): 1, ('u', 'm'): 1, ('t', 'b'): 1, ('s', 'm'): 1, ('m', 't'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 1, ('x', 'l'): 1, ('l', 'e'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('i', 'e'): 1, ('i', 'a'): 1, ('e', 'p'): 1, ('i', 'l'): 1, ('s', 'u'): 1, ('s', 't'): 1, ('e', 'a'): 1, ('x', 'i'): 1, ('u', 'm'): 1, ('p', 'a'): 1, ('m', 't'): 1, ('l', 'a'): 1, ('a', 'i'): 1, ('l', 'x'): 1, ('u', 's'): 1, ('l', 'i'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('n', 'p'): 1, ('n', 'e'): 1, ('t', 's'): 1, ('m', 'u'): 1, ('x', 'p'): 1, ('e', 'i'): 1, ('a', 'p'): 1, ('e', 'l'): 1, ('a', 'x'): 1, ('i', 'x'): 1, ('l', 'n'): 1, ('l', 'p'): 1, ('a', 'n'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('t', 'b'): 1, ('n', 'a'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('i', 'p'): 1, ('x', 'n'): 1, ('t', 'm'): 1, ('p', 'l'): 1, ('m', 's'): 1, ('u', 't'): 2, ('n', 'i'): 1, ('a', 'e'): 1, ('a', 'l'): 1, ('p', 'n'): 1, ('e', 'n'): 1, ('n', 'l'): 1, ('p', 'i'): 1, ('i', 'n'): 1, ('s', 'm'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 1, ('x', 'l'): 1, ('l', 'e'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('i', 'e'): 1, ('i', 'a'): 1, ('e', 'p'): 1, ('i', 'l'): 1, ('s', 'u'): 1, ('s', 't'): 1, ('e', 'a'): 1, ('o', 't'): 1, ('x', 'i'): 1, ('u', 'm'): 1, ('p', 'a'): 1, ('m', 't'): 1, ('l', 'a'): 1, ('a', 'i'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('u', 's'): 1, ('l', 'i'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('n', 'p'): 1, ('n', 'e'): 1, ('t', 's'): 1, ('m', 'u'): 1, ('x', 'p'): 1, ('e', 'i'): 1, ('a', 'p'): 1, ('e', 'l'): 1, ('a', 'x'): 1, ('i', 'x'): 1, ('l', 'n'): 1, ('l', 'p'): 1, ('a', 'n'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('t', 'b'): 1, ('n', 'a'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('i', 'p'): 1, ('x', 'n'): 1, ('t', 'm'): 1, ('p', 'l'): 1, ('m', 's'): 1, ('u', 't'): 2, ('n', 'i'): 1, ('a', 'e'): 1, ('a', 'l'): 1, ('p', 'n'): 1, ('e', 'n'): 1, ('n', 'l'): 1, ('p', 'i'): 1, ('i', 'n'): 1, ('s', 'm'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 1, ('x', 'l'): 1, ('l', 'e'): 1, ('y', 'o'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('i', 'e'): 1, ('i', 'a'): 1, ('e', 'p'): 1, ('i', 'l'): 1, ('s', 'u'): 1, ('s', 't'): 1, ('e', 'a'): 1, ('o', 't'): 1, ('x', 'i'): 1, ('u', 'm'): 1, ('p', 'a'): 1, ('m', 't'): 1, ('l', 'a'): 1, ('a', 'i'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('u', 's'): 1, ('l', 'i'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('n', 'p'): 1, ('n', 'e'): 1, ('t', 's'): 1, ('m', 'u'): 1, ('x', 'p'): 1, ('e', 'i'): 1, ('a', 'p'): 1, ('y', 'u'): 1, ('e', 'l'): 1, ('a', 'x'): 1, ('i', 'x'): 1, ('l', 'n'): 1, ('u', 'y'): 1, ('l', 'p'): 1, ('a', 'n'): 1, ('o', 'y'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('t', 'b'): 1, ('n', 'a'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('i', 'p'): 1, ('x', 'n'): 1, ('t', 'm'): 1, ('p', 'l'): 1, ('m', 's'): 1, ('u', 'o'): 1, ('u', 't'): 2, ('n', 'i'): 1, ('a', 'e'): 1, ('a', 'l'): 1, ('p', 'n'): 1, ('e', 'n'): 1, ('n', 'l'): 1, ('o', 'u'): 1, ('p', 'i'): 1, ('i', 'n'): 1, ('s', 'm'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 1, ('x', 'l'): 1, ('l', 'e'): 1, ('y', 'o'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('w', 'o'): 1, ('i', 'e'): 1, ('i', 'a'): 1, ('e', 'p'): 1, ('i', 'l'): 1, ('s', 'u'): 1, ('o', 'h'): 1, ('s', 't'): 1, ('e', 'a'): 1, ('o', 't'): 1, ('x', 'i'): 1, ('u', 'm'): 1, ('p', 'a'): 1, ('m', 't'): 1, ('l', 'a'): 1, ('a', 'i'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('u', 's'): 1, ('l', 'i'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('n', 'p'): 1, ('w', 'h'): 1, ('n', 'e'): 1, ('t', 's'): 1, ('m', 'u'): 1, ('x', 'p'): 1, ('h', 'w'): 1, ('e', 'i'): 1, ('a', 'p'): 1, ('h', 'o'): 1, ('y', 'u'): 1, ('e', 'l'): 1, ('a', 'x'): 1, ('i', 'x'): 1, ('l', 'n'): 1, ('u', 'y'): 1, ('l', 'p'): 1, ('a', 'n'): 1, ('o', 'y'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('t', 'b'): 1, ('n', 'a'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('i', 'p'): 1, ('x', 'n'): 1, ('t', 'm'): 1, ('p', 'l'): 1, ('m', 's'): 1, ('u', 'o'): 1, ('u', 't'): 2, ('o', 'w'): 1, ('n', 'i'): 1, ('a', 'e'): 1, ('a', 'l'): 1, ('p', 'n'): 1, ('e', 'n'): 1, ('n', 'l'): 1, ('o', 'u'): 1, ('p', 'i'): 1, ('i', 'n'): 1, ('s', 'm'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 1, ('x', 'l'): 1, ('l', 'e'): 1, ('y', 'o'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('w', 'o'): 1, ('i', 'e'): 1, ('i', 'a'): 1, ('e', 'p'): 1, ('i', 'l'): 1, ('s', 'u'): 1, ('o', 'h'): 1, ('s', 't'): 1, ('e', 'a'): 1, ('o', 't'): 1, ('x', 'i'): 1, ('u', 'm'): 1, ('p', 'a'): 1, ('m', 't'): 1, ('l', 'a'): 2, ('a', 'i'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('u', 's'): 1, ('l', 'i'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('n', 'p'): 1, ('w', 'h'): 1, ('n', 'e'): 1, ('t', 's'): 1, ('m', 'u'): 1, ('x', 'p'): 1, ('h', 'w'): 1, ('e', 'i'): 1, ('a', 'p'): 1, ('h', 'o'): 1, ('y', 'u'): 1, ('e', 'l'): 1, ('a', 'x'): 1, ('i', 'x'): 1, ('l', 'n'): 1, ('u', 'y'): 1, ('l', 'p'): 1, ('a', 'n'): 1, ('o', 'y'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('t', 'b'): 1, ('n', 'a'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('i', 'p'): 1, ('x', 'n'): 1, ('t', 'm'): 1, ('p', 'l'): 1, ('m', 's'): 1, ('u', 'o'): 1, ('u', 't'): 2, ('o', 'w'): 1, ('n', 'i'): 1, ('a', 'e'): 1, ('a', 'l'): 2, ('p', 'n'): 1, ('e', 'n'): 1, ('n', 'l'): 1, ('o', 'u'): 1, ('p', 'i'): 1, ('i', 'n'): 1, ('s', 'm'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 1, ('h', 's'): 1, ('h', 'i'): 1, ('x', 'l'): 1, ('l', 'e'): 1, ('y', 'o'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('w', 'o'): 1, ('i', 'e'): 1, ('i', 'a'): 1, ('t', 'h'): 1, ('e', 'p'): 1, ('i', 'l'): 1, ('s', 'u'): 1, ('o', 'h'): 1, ('s', 't'): 2, ('e', 'a'): 1, ('s', 'i'): 1, ('o', 't'): 1, ('x', 'i'): 1, ('u', 'm'): 1, ('h', 't'): 1, ('p', 'a'): 1, ('m', 't'): 1, ('l', 'a'): 2, ('a', 'i'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('u', 's'): 1, ('l', 'i'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('n', 'p'): 1, ('i', 't'): 1, ('s', 'h'): 1, ('w', 'h'): 1, ('n', 'e'): 1, ('t', 's'): 2, ('m', 'u'): 1, ('x', 'p'): 1, ('i', 's'): 1, ('h', 'w'): 1, ('e', 'i'): 1, ('a', 'p'): 1, ('h', 'o'): 1, ('y', 'u'): 1, ('e', 'l'): 1, ('a', 'x'): 1, ('i', 'x'): 1, ('l', 'n'): 1, ('u', 'y'): 1, ('i', 'h'): 1, ('l', 'p'): 1, ('a', 'n'): 1, ('o', 'y'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('t', 'b'): 1, ('n', 'a'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('i', 'p'): 1, ('x', 'n'): 1, ('t', 'm'): 1, ('p', 'l'): 1, ('m', 's'): 1, ('u', 'o'): 1, ('u', 't'): 2, ('o', 'w'): 1, ('n', 'i'): 1, ('a', 'e'): 1, ('a', 'l'): 2, ('p', 'n'): 1, ('e', 'n'): 1, ('t', 'i'): 1, ('n', 'l'): 1, ('o', 'u'): 1, ('p', 'i'): 1, ('i', 'n'): 1, ('s', 'm'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 1, ('i', 'm'): 1, ('h', 'i'): 1, ('l', 'e'): 1, ('y', 'o'): 1, ('i', 'e'): 2, ('i', 'k'): 1, ('k', 'm'): 1, ('s', 'u'): 1, ('p', 'i'): 1, ('k', 'a'): 1, ('u', 'o'): 1, ('n', 'x'): 1, ('u', 'm'): 1, ('m', 's'): 2, ('p', 'a'): 1, ('t', 'n'): 1, ('l', 'a'): 2, ('a', 'n'): 2, ('u', 's'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('m', 'n'): 1, ('i', 't'): 2, ('h', 't'): 1, ('n', 'e'): 2, ('m', 'u'): 1, ('s', 'n'): 1, ('h', 's'): 1, ('n', 's'): 1, ('h', 'o'): 1, ('e', 'x'): 1, ('e', 'l'): 1, ('k', 'i'): 1, ('e', 'k'): 1, ('l', 'p'): 1, ('o', 'y'): 1, ('u', 'b'): 1, ('x', 'i'): 1, ('s', 'm'): 2, ('e', 'a'): 2, ('p', 'n'): 1, ('x', 'n'): 1, ('p', 'l'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('s', 'i'): 2, ('a', 'e'): 2, ('e', 'm'): 1, ('t', 's'): 3, ('e', 'n'): 2, ('e', 't'): 1, ('l', 'n'): 1, ('o', 'u'): 1, ('t', 'm'): 2, ('n', 'i'): 2, ('l', 'i'): 1, ('n', 'k'): 1, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('t', 'k'): 1, ('e', 'p'): 1, ('i', 'x'): 1, ('m', 'i'): 1, ('s', 't'): 3, ('o', 'w'): 1, ('o', 't'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('m', 't'): 2, ('l', 'x'): 1, ('t', 'o'): 1, ('t', 'b'): 1, ('n', 'p'): 1, ('s', 'h'): 1, ('i', 'a'): 2, ('t', 'a'): 1, ('x', 'p'): 1, ('s', 'k'): 1, ('e', 'i'): 2, ('a', 'p'): 1, ('k', 't'): 1, ('m', 'a'): 1, ('k', 'n'): 1, ('k', 's'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('n', 'l'): 1, ('s', 'a'): 1, ('u', 'y'): 1, ('i', 'h'): 1, ('h', 'w'): 1, ('a', 's'): 1, ('a', 'l'): 2, ('o', 'h'): 1, ('n', 'a'): 2, ('m', 'e'): 1, ('x', 'e'): 1, ('y', 'u'): 1, ('i', 'p'): 1, ('a', 'k'): 1, ('t', 'e'): 1, ('s', 'e'): 1, ('a', 'i'): 2, ('u', 't'): 2, ('e', 's'): 1, ('a', 'm'): 1, ('i', 's'): 2, ('t', 'i'): 2, ('a', 'x'): 1, ('k', 'e'): 1, ('w', 'h'): 1, ('i', 'n'): 2, ('i', 'l'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 1, ('i', 'm'): 1, ('h', 'i'): 1, ('l', 'e'): 1, ('y', 'o'): 1, ('i', 'e'): 3, ('i', 'k'): 1, ('k', 'm'): 1, ('s', 'u'): 1, ('p', 'i'): 1, ('k', 'a'): 1, ('u', 'o'): 1, ('n', 'x'): 1, ('u', 'm'): 1, ('m', 's'): 2, ('p', 'a'): 1, ('t', 'n'): 1, ('l', 'a'): 2, ('a', 'n'): 2, ('u', 's'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('m', 'n'): 1, ('i', 't'): 2, ('h', 't'): 1, ('n', 'e'): 2, ('m', 'u'): 1, ('s', 'n'): 1, ('h', 's'): 1, ('n', 's'): 1, ('h', 'o'): 1, ('e', 'x'): 1, ('e', 'l'): 1, ('k', 'i'): 1, ('e', 'k'): 1, ('d', 'e'): 1, ('l', 'p'): 1, ('o', 'y'): 1, ('u', 'b'): 1, ('x', 'i'): 1, ('s', 'm'): 2, ('e', 'a'): 3, ('p', 'n'): 1, ('x', 'n'): 1, ('p', 'l'): 1, ('a', 'd'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('s', 'i'): 2, ('a', 'e'): 3, ('e', 'm'): 1, ('t', 's'): 3, ('e', 'n'): 2, ('e', 't'): 1, ('l', 'n'): 1, ('o', 'u'): 1, ('t', 'm'): 2, ('n', 'i'): 2, ('l', 'i'): 1, ('e', 'd'): 1, ('n', 'k'): 1, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('t', 'k'): 1, ('e', 'p'): 1, ('i', 'd'): 1, ('i', 'x'): 1, ('m', 'i'): 1, ('s', 't'): 3, ('o', 'w'): 1, ('o', 't'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('m', 't'): 2, ('l', 'x'): 1, ('t', 'o'): 1, ('t', 'b'): 1, ('n', 'p'): 1, ('s', 'h'): 1, ('i', 'a'): 3, ('t', 'a'): 1, ('x', 'p'): 1, ('s', 'k'): 1, ('e', 'i'): 3, ('a', 'p'): 1, ('k', 't'): 1, ('m', 'a'): 1, ('d', 'i'): 1, ('k', 'n'): 1, ('k', 's'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('n', 'l'): 1, ('s', 'a'): 1, ('u', 'y'): 1, ('i', 'h'): 1, ('h', 'w'): 1, ('a', 's'): 1, ('a', 'l'): 2, ('o', 'h'): 1, ('n', 'a'): 2, ('m', 'e'): 1, ('x', 'e'): 1, ('y', 'u'): 1, ('i', 'p'): 1, ('a', 'k'): 1, ('t', 'e'): 1, ('s', 'e'): 1, ('a', 'i'): 3, ('u', 't'): 2, ('e', 's'): 1, ('d', 'a'): 1, ('a', 'm'): 1, ('i', 's'): 2, ('t', 'i'): 2, ('a', 'x'): 1, ('k', 'e'): 1, ('w', 'h'): 1, ('i', 'n'): 2, ('i', 'l'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 1, ('i', 'm'): 1, ('h', 'i'): 1, ('l', 'e'): 1, ('y', 'o'): 1, ('i', 'e'): 3, ('i', 'k'): 1, ('k', 'm'): 1, ('s', 'u'): 1, ('p', 'i'): 1, ('k', 'a'): 1, ('u', 'o'): 1, ('n', 'x'): 1, ('u', 'm'): 1, ('m', 's'): 2, ('p', 'a'): 1, ('t', 'n'): 1, ('l', 'a'): 2, ('a', 'n'): 2, ('u', 's'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('m', 'n'): 1, ('i', 't'): 2, ('h', 't'): 1, ('n', 'e'): 2, ('m', 'u'): 1, ('s', 'n'): 1, ('h', 's'): 1, ('o', 'f'): 1, ('n', 's'): 1, ('h', 'o'): 1, ('e', 'x'): 1, ('e', 'l'): 1, ('k', 'i'): 1, ('e', 'k'): 1, ('d', 'e'): 1, ('l', 'p'): 1, ('o', 'y'): 1, ('u', 'b'): 1, ('x', 'i'): 1, ('s', 'm'): 2, ('e', 'a'): 3, ('p', 'n'): 1, ('x', 'n'): 1, ('f', 'o'): 1, ('p', 'l'): 1, ('a', 'd'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('s', 'i'): 2, ('a', 'e'): 3, ('e', 'm'): 1, ('t', 's'): 3, ('e', 'n'): 2, ('e', 't'): 1, ('l', 'n'): 1, ('o', 'u'): 1, ('t', 'm'): 2, ('n', 'i'): 2, ('l', 'i'): 1, ('e', 'd'): 1, ('n', 'k'): 1, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('t', 'k'): 1, ('e', 'p'): 1, ('i', 'd'): 1, ('i', 'x'): 1, ('m', 'i'): 1, ('s', 't'): 3, ('o', 'w'): 1, ('o', 't'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('m', 't'): 2, ('l', 'x'): 1, ('t', 'o'): 1, ('t', 'b'): 1, ('n', 'p'): 1, ('s', 'h'): 1, ('i', 'a'): 3, ('t', 'a'): 1, ('x', 'p'): 1, ('s', 'k'): 1, ('e', 'i'): 3, ('a', 'p'): 1, ('k', 't'): 1, ('m', 'a'): 1, ('d', 'i'): 1, ('k', 'n'): 1, ('k', 's'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('n', 'l'): 1, ('s', 'a'): 1, ('u', 'y'): 1, ('i', 'h'): 1, ('h', 'w'): 1, ('a', 's'): 1, ('a', 'l'): 2, ('o', 'h'): 1, ('n', 'a'): 2, ('m', 'e'): 1, ('x', 'e'): 1, ('y', 'u'): 1, ('i', 'p'): 1, ('a', 'k'): 1, ('t', 'e'): 1, ('s', 'e'): 1, ('a', 'i'): 3, ('u', 't'): 2, ('e', 's'): 1, ('d', 'a'): 1, ('a', 'm'): 1, ('i', 's'): 2, ('t', 'i'): 2, ('a', 'x'): 1, ('k', 'e'): 1, ('w', 'h'): 1, ('i', 'n'): 2, ('i', 'l'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 1, ('i', 'm'): 1, ('h', 'i'): 1, ('i', 'o'): 1, ('l', 'e'): 1, ('y', 'o'): 1, ('u', 'd'): 1, ('i', 'e'): 4, ('i', 'k'): 1, ('k', 'm'): 1, ('u', 'e'): 1, ('e', 'u'): 1, ('s', 'u'): 1, ('p', 'i'): 1, ('k', 'a'): 1, ('u', 'o'): 2, ('n', 'x'): 1, ('u', 'm'): 1, ('m', 's'): 2, ('p', 'a'): 1, ('t', 'n'): 1, ('l', 'a'): 2, ('a', 'n'): 2, ('u', 's'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('m', 'n'): 1, ('i', 't'): 2, ('i', 'g'): 1, ('d', 'c'): 1, ('h', 't'): 1, ('i', 'c'): 1, ('n', 'e'): 3, ('m', 'u'): 1, ('s', 'n'): 1, ('h', 's'): 1, ('o', 'f'): 1, ('n', 's'): 1, ('h', 'o'): 1, ('e', 'x'): 1, ('e', 'l'): 1, ('k', 'i'): 1, ('e', 'k'): 1, ('o', 'c'): 1, ('d', 'e'): 2, ('l', 'p'): 1, ('o', 'y'): 1, ('c', 'u'): 1, ('n', 'c'): 1, ('u', 'b'): 1, ('x', 'i'): 1, ('n', 'u'): 1, ('s', 'm'): 2, ('e', 'a'): 3, ('d', 'u'): 1, ('c', 'o'): 1, ('g', 'o'): 1, ('p', 'n'): 1, ('x', 'n'): 1, ('f', 'o'): 1, ('p', 'l'): 1, ('a', 'd'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('s', 'i'): 2, ('g', 'c'): 1, ('a', 'e'): 3, ('e', 'm'): 1, ('o', 'g'): 1, ('t', 's'): 3, ('e', 'n'): 3, ('e', 't'): 1, ('l', 'n'): 1, ('o', 'u'): 2, ('n', 'g'): 1, ('t', 'm'): 2, ('n', 'i'): 3, ('c', 'e'): 1, ('l', 'i'): 1, ('e', 'c'): 1, ('e', 'd'): 2, ('g', 'e'): 1, ('n', 'k'): 1, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('u', 'g'): 1, ('n', 'o'): 1, ('t', 'k'): 1, ('e', 'p'): 1, ('d', 'o'): 1, ('i', 'd'): 2, ('i', 'x'): 1, ('m', 'i'): 1, ('s', 't'): 3, ('u', 'i'): 1, ('o', 'w'): 1, ('o', 't'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('o', 'd'): 1, ('u', 'n'): 1, ('m', 't'): 2, ('o', 'e'): 1, ('c', 'g'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('c', 'n'): 1, ('t', 'b'): 1, ('g', 'u'): 1, ('n', 'p'): 1, ('c', 'd'): 1, ('s', 'h'): 1, ('o', 'i'): 1, ('d', 'g'): 1, ('i', 'a'): 3, ('t', 'a'): 1, ('g', 'n'): 1, ('g', 'd'): 1, ('x', 'p'): 1, ('s', 'k'): 1, ('e', 'o'): 1, ('e', 'i'): 4, ('a', 'p'): 1, ('k', 't'): 1, ('m', 'a'): 1, ('d', 'i'): 2, ('k', 'n'): 1, ('k', 's'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('n', 'l'): 1, ('s', 'a'): 1, ('g', 'i'): 1, ('u', 'y'): 1, ('i', 'h'): 1, ('h', 'w'): 1, ('a', 's'): 1, ('n', 'd'): 1, ('a', 'l'): 2, ('o', 'h'): 1, ('n', 'a'): 2, ('m', 'e'): 1, ('x', 'e'): 1, ('y', 'u'): 1, ('i', 'u'): 1, ('i', 'p'): 1, ('e', 'g'): 1, ('a', 'k'): 1, ('t', 'e'): 1, ('u', 'c'): 1, ('s', 'e'): 1, ('a', 'i'): 3, ('u', 't'): 2, ('e', 's'): 1, ('d', 'a'): 1, ('a', 'm'): 1, ('o', 'n'): 1, ('i', 's'): 2, ('t', 'i'): 2, ('a', 'x'): 1, ('k', 'e'): 1, ('c', 'i'): 1, ('d', 'n'): 1, ('w', 'h'): 1, ('i', 'n'): 3, ('i', 'l'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 1, ('i', 'm'): 1, ('h', 'i'): 1, ('i', 'o'): 1, ('l', 'e'): 1, ('y', 'o'): 1, ('u', 'd'): 1, ('i', 'e'): 4, ('i', 'k'): 1, ('k', 'm'): 1, ('u', 'e'): 1, ('e', 'u'): 1, ('s', 'u'): 1, ('p', 'i'): 1, ('k', 'a'): 1, ('u', 'o'): 2, ('n', 'x'): 1, ('u', 'm'): 1, ('m', 's'): 2, ('p', 'a'): 1, ('t', 'n'): 1, ('l', 'a'): 2, ('a', 'n'): 2, ('u', 's'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('m', 'n'): 1, ('i', 't'): 2, ('i', 'g'): 1, ('d', 'c'): 1, ('h', 't'): 1, ('i', 'c'): 1, ('n', 'e'): 3, ('m', 'u'): 1, ('s', 'n'): 1, ('h', 's'): 1, ('o', 'f'): 2, ('n', 's'): 1, ('h', 'o'): 1, ('e', 'x'): 1, ('e', 'l'): 1, ('k', 'i'): 1, ('e', 'k'): 1, ('o', 'c'): 1, ('d', 'e'): 2, ('l', 'p'): 1, ('o', 'y'): 1, ('c', 'u'): 1, ('n', 'c'): 1, ('u', 'b'): 1, ('x', 'i'): 1, ('n', 'u'): 1, ('s', 'm'): 2, ('e', 'a'): 3, ('d', 'u'): 1, ('c', 'o'): 1, ('g', 'o'): 1, ('p', 'n'): 1, ('x', 'n'): 1, ('f', 'o'): 2, ('p', 'l'): 1, ('a', 'd'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('s', 'i'): 2, ('g', 'c'): 1, ('a', 'e'): 3, ('e', 'm'): 1, ('o', 'g'): 1, ('t', 's'): 3, ('e', 'n'): 3, ('e', 't'): 1, ('l', 'n'): 1, ('o', 'u'): 2, ('n', 'g'): 1, ('t', 'm'): 2, ('n', 'i'): 3, ('c', 'e'): 1, ('l', 'i'): 1, ('e', 'c'): 1, ('e', 'd'): 2, ('g', 'e'): 1, ('n', 'k'): 1, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('u', 'g'): 1, ('n', 'o'): 1, ('t', 'k'): 1, ('e', 'p'): 1, ('d', 'o'): 1, ('i', 'd'): 2, ('i', 'x'): 1, ('m', 'i'): 1, ('s', 't'): 3, ('u', 'i'): 1, ('o', 'w'): 1, ('o', 't'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('o', 'd'): 1, ('u', 'n'): 1, ('m', 't'): 2, ('o', 'e'): 1, ('c', 'g'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('c', 'n'): 1, ('t', 'b'): 1, ('g', 'u'): 1, ('n', 'p'): 1, ('c', 'd'): 1, ('s', 'h'): 1, ('o', 'i'): 1, ('d', 'g'): 1, ('i', 'a'): 3, ('t', 'a'): 1, ('g', 'n'): 1, ('g', 'd'): 1, ('x', 'p'): 1, ('s', 'k'): 1, ('e', 'o'): 1, ('e', 'i'): 4, ('a', 'p'): 1, ('k', 't'): 1, ('m', 'a'): 1, ('d', 'i'): 2, ('k', 'n'): 1, ('k', 's'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('n', 'l'): 1, ('s', 'a'): 1, ('g', 'i'): 1, ('u', 'y'): 1, ('i', 'h'): 1, ('h', 'w'): 1, ('a', 's'): 1, ('n', 'd'): 1, ('a', 'l'): 2, ('o', 'h'): 1, ('n', 'a'): 2, ('m', 'e'): 1, ('x', 'e'): 1, ('y', 'u'): 1, ('i', 'u'): 1, ('i', 'p'): 1, ('e', 'g'): 1, ('a', 'k'): 1, ('t', 'e'): 1, ('u', 'c'): 1, ('s', 'e'): 1, ('a', 'i'): 3, ('u', 't'): 2, ('e', 's'): 1, ('d', 'a'): 1, ('a', 'm'): 1, ('o', 'n'): 1, ('i', 's'): 2, ('t', 'i'): 2, ('a', 'x'): 1, ('k', 'e'): 1, ('c', 'i'): 1, ('d', 'n'): 1, ('w', 'h'): 1, ('i', 'n'): 3, ('i', 'l'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 1, ('i', 'm'): 1, ('h', 'i'): 1, ('i', 'o'): 1, ('l', 'e'): 1, ('y', 'o'): 1, ('u', 'd'): 1, ('i', 'e'): 4, ('i', 'k'): 1, ('k', 'm'): 1, ('u', 'e'): 1, ('e', 'u'): 1, ('s', 'u'): 1, ('p', 'i'): 1, ('k', 'a'): 1, ('u', 'o'): 2, ('n', 'x'): 1, ('u', 'm'): 1, ('m', 's'): 2, ('p', 'a'): 1, ('t', 'n'): 1, ('l', 'a'): 2, ('a', 'n'): 2, ('u', 's'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('m', 'n'): 1, ('i', 't'): 2, ('i', 'g'): 1, ('d', 'c'): 1, ('h', 't'): 1, ('i', 'c'): 1, ('n', 'e'): 3, ('m', 'u'): 1, ('s', 'n'): 1, ('h', 's'): 1, ('o', 'f'): 2, ('n', 's'): 1, ('h', 'o'): 1, ('e', 'x'): 1, ('e', 'l'): 1, ('k', 'i'): 1, ('e', 'k'): 1, ('o', 'c'): 1, ('d', 'e'): 2, ('l', 'p'): 1, ('o', 'y'): 1, ('c', 'u'): 1, ('n', 'c'): 1, ('u', 'b'): 1, ('x', 'i'): 1, ('n', 'u'): 1, ('s', 'm'): 2, ('e', 'a'): 3, ('d', 'u'): 1, ('c', 'o'): 1, ('g', 'o'): 1, ('p', 'n'): 1, ('x', 'n'): 1, ('f', 'o'): 2, ('p', 'l'): 1, ('a', 'd'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('s', 'i'): 2, ('g', 'c'): 1, ('a', 'e'): 3, ('e', 'm'): 1, ('o', 'g'): 1, ('t', 's'): 3, ('e', 'n'): 3, ('e', 't'): 1, ('l', 'n'): 1, ('o', 'u'): 2, ('n', 'g'): 1, ('t', 'm'): 2, ('n', 'i'): 3, ('c', 'e'): 1, ('l', 'i'): 1, ('e', 'c'): 1, ('e', 'd'): 2, ('g', 'e'): 1, ('n', 'k'): 1, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('u', 'g'): 1, ('n', 'o'): 1, ('t', 'k'): 1, ('e', 'p'): 1, ('d', 'o'): 1, ('i', 'd'): 2, ('i', 'x'): 1, ('m', 'i'): 1, ('s', 't'): 3, ('u', 'i'): 1, ('o', 'w'): 1, ('o', 't'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('o', 'd'): 1, ('u', 'n'): 1, ('m', 't'): 2, ('o', 'e'): 1, ('c', 'g'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('c', 'n'): 1, ('t', 'b'): 1, ('g', 'u'): 1, ('n', 'p'): 1, ('c', 'd'): 1, ('s', 'h'): 1, ('o', 'i'): 1, ('d', 'g'): 1, ('i', 'a'): 3, ('t', 'a'): 1, ('g', 'n'): 1, ('g', 'd'): 1, ('x', 'p'): 1, ('s', 'k'): 1, ('e', 'o'): 1, ('e', 'i'): 4, ('a', 'p'): 1, ('k', 't'): 1, ('m', 'a'): 1, ('d', 'i'): 2, ('k', 'n'): 1, ('k', 's'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('n', 'l'): 1, ('s', 'a'): 1, ('g', 'i'): 1, ('u', 'y'): 1, ('i', 'h'): 1, ('h', 'w'): 1, ('a', 's'): 1, ('n', 'd'): 1, ('a', 'l'): 2, ('o', 'h'): 1, ('n', 'a'): 2, ('m', 'e'): 1, ('x', 'e'): 1, ('y', 'u'): 1, ('i', 'u'): 1, ('i', 'p'): 1, ('e', 'g'): 1, ('a', 'k'): 1, ('t', 'e'): 1, ('u', 'c'): 1, ('s', 'e'): 1, ('a', 'i'): 3, ('u', 't'): 2, ('e', 's'): 1, ('d', 'a'): 1, ('a', 'm'): 1, ('o', 'n'): 1, ('i', 's'): 2, ('t', 'i'): 2, ('a', 'x'): 1, ('k', 'e'): 1, ('c', 'i'): 1, ('d', 'n'): 1, ('w', 'h'): 1, ('i', 'n'): 3, ('i', 'l'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 2, ('i', 'm'): 1, ('h', 'i'): 1, ('t', 'm'): 2, ('l', 'e'): 2, ('r', 'e'): 1, ('i', 'e'): 4, ('i', 'k'): 1, ('k', 'm'): 1, ('u', 'e'): 2, ('s', 'u'): 2, ('x', 'i'): 1, ('t', 'i'): 2, ('u', 'm'): 1, ('o', 'i'): 1, ('l', 'a'): 3, ('u', 'r'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('i', 't'): 2, ('h', 't'): 1, ('m', 'u'): 1, ('e', 'k'): 1, ('h', 's'): 1, ('n', 'd'): 1, ('g', 'o'): 1, ('h', 'o'): 1, ('e', 'l'): 2, ('p', 'r'): 1, ('a', 'u'): 1, ('d', 'e'): 2, ('l', 'p'): 2, ('m', 's'): 2, ('p', 'l'): 2, ('d', 'g'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('e', 'm'): 1, ('s', 'k'): 1, ('e', 't'): 1, ('n', 'l'): 1, ('n', 'i'): 3, ('c', 'e'): 1, ('s', 'm'): 2, ('s', 'l'): 1, ('e', 'd'): 2, ('g', 'e'): 1, ('n', 'k'): 1, ('g', 'd'): 1, ('n', 'o'): 1, ('t', 'k'): 1, ('i', 'x'): 1, ('m', 'i'): 1, ('p', 'n'): 1, ('u', 'i'): 1, ('o', 'w'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('o', 'd'): 1, ('o', 'e'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('s', 'h'): 1, ('i', 'a'): 3, ('g', 'n'): 1, ('n', 'c'): 1, ('e', 'i'): 4, ('a', 'p'): 2, ('k', 't'): 1, ('d', 'i'): 2, ('k', 'n'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('l', 'n'): 1, ('a', 's'): 2, ('r', 'l'): 1, ('t', 'e'): 1, ('p', 'u'): 1, ('t', 'b'): 1, ('e', 'r'): 1, ('y', 'u'): 1, ('i', 'u'): 1, ('i', 'p'): 1, ('e', 'g'): 1, ('d', 'u'): 1, ('u', 'c'): 1, ('s', 'e'): 2, ('o', 'c'): 1, ('l', 'r'): 1, ('i', 's'): 2, ('s', 'r'): 1, ('k', 's'): 1, ('d', 'n'): 1, ('i', 'n'): 3, ('p', 's'): 1, ('d', 'o'): 1, ('i', 'o'): 1, ('y', 'o'): 1, ('u', 'd'): 1, ('o', 'f'): 2, ('f', 'o'): 2, ('k', 'a'): 1, ('u', 'o'): 2, ('r', 'a'): 1, ('p', 'a'): 2, ('t', 'n'): 1, ('a', 'n'): 2, ('u', 's'): 2, ('h', 'w'): 1, ('m', 'n'): 1, ('i', 'g'): 1, ('d', 'c'): 1, ('i', 'c'): 1, ('n', 'e'): 3, ('s', 'n'): 1, ('a', 'r'): 1, ('e', 'c'): 1, ('k', 'i'): 1, ('u', 'p'): 1, ('o', 'h'): 1, ('r', 'p'): 1, ('o', 'y'): 1, ('c', 'u'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('n', 'u'): 1, ('l', 'u'): 1, ('e', 'a'): 4, ('e', 'u'): 2, ('r', 's'): 1, ('u', 'a'): 1, ('g', 'c'): 1, ('a', 'd'): 1, ('u', 'g'): 1, ('s', 'i'): 2, ('a', 'e'): 4, ('c', 'n'): 1, ('t', 's'): 3, ('e', 'n'): 3, ('c', 'o'): 1, ('o', 'u'): 2, ('l', 's'): 1, ('p', 'i'): 1, ('e', 's'): 2, ('l', 'i'): 1, ('x', 'n'): 1, ('a', 'i'): 3, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('e', 'p'): 2, ('i', 'd'): 2, ('s', 't'): 3, ('o', 't'): 1, ('u', 'n'): 1, ('u', 'l'): 1, ('m', 't'): 2, ('c', 'g'): 1, ('s', 'p'): 1, ('g', 'u'): 1, ('n', 'p'): 1, ('c', 'd'): 1, ('r', 'u'): 1, ('t', 'a'): 1, ('x', 'p'): 1, ('e', 'o'): 1, ('n', 's'): 1, ('m', 'a'): 1, ('o', 'g'): 1, ('s', 'a'): 2, ('g', 'i'): 1, ('u', 'y'): 1, ('i', 'h'): 1, ('n', 'g'): 1, ('a', 'l'): 3, ('a', 'm'): 1, ('n', 'a'): 2, ('m', 'e'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('a', 'k'): 1, ('u', 't'): 2, ('d', 'a'): 1, ('o', 'n'): 1, ('a', 'x'): 1, ('k', 'e'): 1, ('c', 'i'): 1, ('i', 'l'): 1, ('w', 'h'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 2, ('i', 'm'): 1, ('h', 'i'): 1, ('t', 'm'): 2, ('l', 'e'): 2, ('r', 'e'): 1, ('i', 'e'): 4, ('i', 'k'): 1, ('k', 'm'): 1, ('u', 'e'): 2, ('s', 'u'): 2, ('x', 'i'): 1, ('t', 'i'): 2, ('u', 'm'): 1, ('o', 'i'): 1, ('l', 'a'): 3, ('u', 'r'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('i', 't'): 2, ('h', 't'): 1, ('m', 'u'): 1, ('e', 'k'): 1, ('h', 's'): 1, ('n', 'd'): 2, ('g', 'o'): 1, ('h', 'o'): 1, ('e', 'l'): 2, ('p', 'r'): 1, ('a', 'u'): 1, ('d', 'e'): 2, ('l', 'p'): 2, ('m', 's'): 2, ('p', 'l'): 2, ('d', 'g'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('e', 'm'): 1, ('s', 'k'): 1, ('e', 't'): 1, ('n', 'l'): 1, ('n', 'i'): 3, ('c', 'e'): 1, ('s', 'm'): 2, ('s', 'l'): 1, ('e', 'd'): 2, ('g', 'e'): 1, ('n', 'k'): 1, ('g', 'd'): 1, ('n', 'o'): 1, ('t', 'k'): 1, ('i', 'x'): 1, ('m', 'i'): 1, ('p', 'n'): 1, ('u', 'i'): 1, ('o', 'w'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('o', 'd'): 1, ('o', 'e'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('s', 'h'): 1, ('i', 'a'): 3, ('g', 'n'): 1, ('n', 'c'): 1, ('e', 'i'): 4, ('a', 'p'): 2, ('k', 't'): 1, ('d', 'i'): 2, ('k', 'n'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('l', 'n'): 1, ('a', 's'): 2, ('r', 'l'): 1, ('t', 'e'): 1, ('p', 'u'): 1, ('t', 'b'): 1, ('e', 'r'): 1, ('y', 'u'): 1, ('i', 'u'): 1, ('i', 'p'): 1, ('e', 'g'): 1, ('d', 'u'): 1, ('u', 'c'): 1, ('s', 'e'): 2, ('o', 'c'): 1, ('l', 'r'): 1, ('i', 's'): 2, ('s', 'r'): 1, ('k', 's'): 1, ('d', 'n'): 2, ('i', 'n'): 3, ('p', 's'): 1, ('d', 'o'): 1, ('i', 'o'): 1, ('y', 'o'): 1, ('u', 'd'): 1, ('o', 'f'): 2, ('f', 'o'): 2, ('k', 'a'): 1, ('u', 'o'): 2, ('r', 'a'): 1, ('p', 'a'): 2, ('t', 'n'): 1, ('a', 'n'): 3, ('u', 's'): 2, ('h', 'w'): 1, ('m', 'n'): 1, ('i', 'g'): 1, ('d', 'c'): 1, ('i', 'c'): 1, ('n', 'e'): 3, ('s', 'n'): 1, ('a', 'r'): 1, ('e', 'c'): 1, ('k', 'i'): 1, ('u', 'p'): 1, ('o', 'h'): 1, ('r', 'p'): 1, ('o', 'y'): 1, ('c', 'u'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('n', 'u'): 1, ('l', 'u'): 1, ('e', 'a'): 4, ('e', 'u'): 2, ('r', 's'): 1, ('u', 'a'): 1, ('g', 'c'): 1, ('a', 'd'): 2, ('u', 'g'): 1, ('s', 'i'): 2, ('a', 'e'): 4, ('c', 'n'): 1, ('t', 's'): 3, ('e', 'n'): 3, ('c', 'o'): 1, ('o', 'u'): 2, ('l', 's'): 1, ('p', 'i'): 1, ('e', 's'): 2, ('l', 'i'): 1, ('x', 'n'): 1, ('a', 'i'): 3, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('e', 'p'): 2, ('i', 'd'): 2, ('s', 't'): 3, ('o', 't'): 1, ('u', 'n'): 1, ('u', 'l'): 1, ('m', 't'): 2, ('c', 'g'): 1, ('s', 'p'): 1, ('g', 'u'): 1, ('n', 'p'): 1, ('c', 'd'): 1, ('r', 'u'): 1, ('t', 'a'): 1, ('x', 'p'): 1, ('e', 'o'): 1, ('n', 's'): 1, ('m', 'a'): 1, ('o', 'g'): 1, ('s', 'a'): 2, ('g', 'i'): 1, ('u', 'y'): 1, ('i', 'h'): 1, ('n', 'g'): 1, ('a', 'l'): 3, ('a', 'm'): 1, ('n', 'a'): 3, ('m', 'e'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('a', 'k'): 1, ('u', 't'): 2, ('d', 'a'): 2, ('o', 'n'): 1, ('a', 'x'): 1, ('k', 'e'): 1, ('c', 'i'): 1, ('i', 'l'): 1, ('w', 'h'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 2, ('i', 'm'): 1, ('h', 'i'): 1, ('t', 'm'): 2, ('l', 'e'): 2, ('r', 'e'): 1, ('i', 'e'): 4, ('i', 'k'): 1, ('k', 'm'): 1, ('u', 'e'): 2, ('s', 'u'): 2, ('x', 'i'): 1, ('t', 'i'): 2, ('u', 'm'): 1, ('o', 'i'): 1, ('l', 'a'): 3, ('u', 'r'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('g', 'a'): 1, ('i', 't'): 2, ('r', 'n'): 1, ('h', 't'): 1, ('m', 'u'): 1, ('e', 'k'): 1, ('h', 's'): 1, ('n', 'd'): 2, ('g', 'o'): 1, ('h', 'o'): 1, ('e', 'l'): 2, ('p', 'r'): 2, ('a', 'u'): 1, ('d', 'e'): 2, ('l', 'p'): 2, ('r', 'i'): 1, ('g', 'p'): 1, ('m', 's'): 2, ('p', 'l'): 2, ('d', 'g'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('e', 'm'): 1, ('s', 'k'): 1, ('e', 't'): 1, ('n', 'l'): 1, ('n', 'i'): 4, ('c', 'e'): 1, ('s', 'm'): 2, ('s', 'l'): 1, ('e', 'd'): 2, ('g', 'e'): 1, ('n', 'k'): 1, ('g', 'd'): 1, ('g', 's'): 1, ('n', 'o'): 1, ('t', 'k'): 1, ('n', 'r'): 1, ('i', 'x'): 1, ('m', 'i'): 1, ('p', 'n'): 2, ('u', 'i'): 1, ('o', 'w'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('o', 'd'): 1, ('o', 'e'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('s', 'h'): 1, ('i', 'a'): 4, ('g', 'n'): 2, ('n', 'c'): 1, ('e', 'i'): 4, ('a', 'p'): 3, ('k', 't'): 1, ('i', 'r'): 1, ('d', 'i'): 2, ('k', 'n'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('l', 'n'): 1, ('a', 's'): 3, ('r', 'l'): 1, ('t', 'e'): 1, ('p', 'g'): 1, ('p', 'u'): 1, ('t', 'b'): 1, ('e', 'r'): 1, ('y', 'u'): 1, ('i', 'u'): 1, ('i', 'p'): 2, ('e', 'g'): 1, ('d', 'u'): 1, ('u', 'c'): 1, ('s', 'e'): 2, ('o', 'c'): 1, ('l', 'r'): 1, ('i', 's'): 3, ('s', 'r'): 2, ('k', 's'): 1, ('d', 'n'): 2, ('i', 'n'): 4, ('p', 's'): 2, ('d', 'o'): 1, ('i', 'o'): 1, ('y', 'o'): 1, ('u', 'd'): 1, ('o', 'f'): 2, ('f', 'o'): 2, ('k', 'a'): 1, ('u', 'o'): 2, ('r', 'a'): 2, ('p', 'a'): 3, ('t', 'n'): 1, ('a', 'n'): 4, ('u', 's'): 2, ('h', 'w'): 1, ('m', 'n'): 1, ('i', 'g'): 2, ('d', 'c'): 1, ('i', 'c'): 1, ('n', 'e'): 3, ('s', 'n'): 2, ('a', 'r'): 2, ('e', 'c'): 1, ('k', 'i'): 1, ('u', 'p'): 1, ('o', 'h'): 1, ('r', 'p'): 2, ('o', 'y'): 1, ('c', 'u'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('n', 'u'): 1, ('l', 'u'): 1, ('e', 'a'): 4, ('e', 'u'): 2, ('r', 's'): 2, ('u', 'a'): 1, ('g', 'c'): 1, ('a', 'd'): 2, ('u', 'g'): 1, ('s', 'i'): 3, ('g', 'r'): 1, ('a', 'e'): 4, ('c', 'n'): 1, ('t', 's'): 3, ('e', 'n'): 3, ('c', 'o'): 1, ('o', 'u'): 2, ('l', 's'): 1, ('p', 'i'): 2, ('e', 's'): 2, ('l', 'i'): 1, ('x', 'n'): 1, ('a', 'i'): 4, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('e', 'p'): 2, ('i', 'd'): 2, ('s', 't'): 3, ('o', 't'): 1, ('u', 'n'): 1, ('u', 'l'): 1, ('m', 't'): 2, ('c', 'g'): 1, ('a', 'g'): 1, ('s', 'p'): 2, ('g', 'u'): 1, ('n', 'p'): 2, ('c', 'd'): 1, ('r', 'u'): 1, ('t', 'a'): 1, ('x', 'p'): 1, ('e', 'o'): 1, ('n', 's'): 2, ('m', 'a'): 1, ('o', 'g'): 1, ('s', 'g'): 1, ('s', 'a'): 3, ('g', 'i'): 2, ('u', 'y'): 1, ('i', 'h'): 1, ('n', 'g'): 2, ('a', 'l'): 3, ('a', 'm'): 1, ('n', 'a'): 4, ('m', 'e'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('a', 'k'): 1, ('u', 't'): 2, ('d', 'a'): 2, ('o', 'n'): 1, ('a', 'x'): 1, ('k', 'e'): 1, ('c', 'i'): 1, ('i', 'l'): 1, ('r', 'g'): 1, ('w', 'h'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 2, ('i', 'm'): 1, ('h', 'i'): 1, ('t', 'm'): 2, ('l', 'e'): 2, ('r', 'e'): 1, ('i', 'e'): 4, ('i', 'k'): 1, ('k', 'm'): 1, ('u', 'e'): 2, ('s', 'u'): 2, ('x', 'i'): 1, ('t', 'i'): 2, ('u', 'm'): 1, ('o', 'i'): 1, ('l', 'a'): 3, ('u', 'r'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('g', 'a'): 1, ('i', 't'): 2, ('r', 'n'): 1, ('h', 't'): 1, ('m', 'u'): 1, ('e', 'k'): 1, ('h', 's'): 1, ('n', 'd'): 2, ('g', 'o'): 1, ('h', 'o'): 1, ('e', 'l'): 2, ('p', 'r'): 2, ('a', 'u'): 1, ('d', 'e'): 2, ('l', 'p'): 2, ('r', 'i'): 1, ('g', 'p'): 1, ('m', 's'): 2, ('p', 'l'): 2, ('d', 'g'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('e', 'm'): 1, ('s', 'k'): 1, ('e', 't'): 1, ('n', 'l'): 1, ('n', 'i'): 5, ('c', 'e'): 1, ('s', 'm'): 2, ('s', 'l'): 1, ('e', 'd'): 2, ('g', 'e'): 1, ('n', 'k'): 1, ('g', 'd'): 1, ('g', 's'): 1, ('n', 'o'): 1, ('t', 'k'): 1, ('n', 'r'): 1, ('i', 'x'): 1, ('m', 'i'): 1, ('p', 'n'): 3, ('u', 'i'): 1, ('o', 'w'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('o', 'd'): 1, ('o', 'e'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('s', 'h'): 1, ('i', 'a'): 5, ('g', 'n'): 2, ('n', 'c'): 1, ('e', 'i'): 4, ('a', 'p'): 4, ('k', 't'): 1, ('i', 'r'): 1, ('d', 'i'): 2, ('k', 'n'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('l', 'n'): 1, ('a', 's'): 3, ('r', 'l'): 1, ('t', 'e'): 1, ('p', 'g'): 1, ('p', 'u'): 1, ('t', 'b'): 1, ('e', 'r'): 1, ('y', 'u'): 1, ('i', 'u'): 1, ('i', 'p'): 3, ('e', 'g'): 1, ('d', 'u'): 1, ('u', 'c'): 1, ('s', 'e'): 2, ('o', 'c'): 1, ('l', 'r'): 1, ('i', 's'): 3, ('s', 'r'): 2, ('k', 's'): 1, ('d', 'n'): 2, ('i', 'n'): 5, ('p', 's'): 2, ('d', 'o'): 1, ('i', 'o'): 1, ('y', 'o'): 1, ('u', 'd'): 1, ('o', 'f'): 2, ('f', 'o'): 2, ('k', 'a'): 1, ('u', 'o'): 2, ('r', 'a'): 2, ('p', 'a'): 4, ('t', 'n'): 1, ('a', 'n'): 5, ('u', 's'): 2, ('h', 'w'): 1, ('m', 'n'): 1, ('i', 'g'): 2, ('d', 'c'): 1, ('i', 'c'): 1, ('n', 'e'): 3, ('s', 'n'): 2, ('a', 'r'): 2, ('e', 'c'): 1, ('k', 'i'): 1, ('u', 'p'): 1, ('o', 'h'): 1, ('r', 'p'): 2, ('o', 'y'): 1, ('c', 'u'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('n', 'u'): 1, ('l', 'u'): 1, ('e', 'a'): 4, ('e', 'u'): 2, ('r', 's'): 2, ('u', 'a'): 1, ('g', 'c'): 1, ('a', 'd'): 2, ('u', 'g'): 1, ('s', 'i'): 3, ('g', 'r'): 1, ('a', 'e'): 4, ('c', 'n'): 1, ('t', 's'): 3, ('e', 'n'): 3, ('c', 'o'): 1, ('o', 'u'): 2, ('l', 's'): 1, ('p', 'i'): 3, ('e', 's'): 2, ('l', 'i'): 1, ('x', 'n'): 1, ('a', 'i'): 5, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('e', 'p'): 2, ('i', 'd'): 2, ('s', 't'): 3, ('o', 't'): 1, ('u', 'n'): 1, ('u', 'l'): 1, ('m', 't'): 2, ('c', 'g'): 1, ('a', 'g'): 1, ('s', 'p'): 2, ('g', 'u'): 1, ('n', 'p'): 3, ('c', 'd'): 1, ('r', 'u'): 1, ('t', 'a'): 1, ('x', 'p'): 1, ('e', 'o'): 1, ('n', 's'): 2, ('m', 'a'): 1, ('o', 'g'): 1, ('s', 'g'): 1, ('s', 'a'): 3, ('g', 'i'): 2, ('u', 'y'): 1, ('i', 'h'): 1, ('n', 'g'): 2, ('a', 'l'): 3, ('a', 'm'): 1, ('n', 'a'): 5, ('m', 'e'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('a', 'k'): 1, ('u', 't'): 2, ('d', 'a'): 2, ('o', 'n'): 1, ('a', 'x'): 1, ('k', 'e'): 1, ('c', 'i'): 1, ('i', 'l'): 1, ('r', 'g'): 1, ('w', 'h'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 2, ('i', 'm'): 1, ('h', 'i'): 1, ('t', 'm'): 2, ('l', 'e'): 2, ('r', 'e'): 1, ('i', 'e'): 4, ('i', 'k'): 1, ('k', 'm'): 1, ('u', 'e'): 2, ('s', 'u'): 2, ('x', 'i'): 1, ('t', 'i'): 2, ('u', 'm'): 1, ('o', 'i'): 1, ('w', 'a'): 1, ('l', 'a'): 3, ('u', 'r'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('g', 'a'): 1, ('i', 't'): 2, ('r', 'n'): 1, ('h', 't'): 1, ('m', 'u'): 1, ('e', 'k'): 1, ('h', 's'): 1, ('n', 'd'): 2, ('g', 'o'): 1, ('a', 'w'): 1, ('h', 'o'): 1, ('e', 'l'): 2, ('p', 'r'): 2, ('a', 'u'): 1, ('d', 'e'): 2, ('l', 'p'): 2, ('r', 'i'): 1, ('g', 'p'): 1, ('m', 's'): 2, ('p', 'l'): 2, ('d', 'g'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('e', 'm'): 1, ('s', 'k'): 1, ('e', 't'): 1, ('n', 'l'): 1, ('n', 'i'): 5, ('c', 'e'): 1, ('s', 'm'): 2, ('s', 'l'): 1, ('e', 'd'): 2, ('g', 'e'): 1, ('n', 'k'): 1, ('g', 'd'): 1, ('g', 's'): 1, ('n', 'o'): 1, ('t', 'k'): 1, ('n', 'r'): 1, ('i', 'x'): 1, ('m', 'i'): 1, ('p', 'n'): 3, ('u', 'i'): 1, ('o', 'w'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('o', 'd'): 1, ('o', 'e'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('s', 'w'): 1, ('s', 'h'): 1, ('i', 'a'): 5, ('g', 'n'): 2, ('n', 'c'): 1, ('e', 'i'): 4, ('a', 'p'): 4, ('k', 't'): 1, ('i', 'r'): 1, ('d', 'i'): 2, ('k', 'n'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('l', 'n'): 1, ('a', 's'): 4, ('r', 'l'): 1, ('t', 'e'): 1, ('p', 'g'): 1, ('p', 'u'): 1, ('t', 'b'): 1, ('e', 'r'): 1, ('y', 'u'): 1, ('i', 'u'): 1, ('i', 'p'): 3, ('e', 'g'): 1, ('d', 'u'): 1, ('u', 'c'): 1, ('s', 'e'): 2, ('o', 'c'): 1, ('l', 'r'): 1, ('i', 's'): 3, ('s', 'r'): 2, ('k', 's'): 1, ('d', 'n'): 2, ('i', 'n'): 5, ('p', 's'): 2, ('d', 'o'): 1, ('i', 'o'): 1, ('y', 'o'): 1, ('u', 'd'): 1, ('o', 'f'): 2, ('f', 'o'): 2, ('k', 'a'): 1, ('u', 'o'): 2, ('r', 'a'): 2, ('p', 'a'): 4, ('t', 'n'): 1, ('a', 'n'): 5, ('u', 's'): 2, ('h', 'w'): 1, ('m', 'n'): 1, ('i', 'g'): 2, ('d', 'c'): 1, ('i', 'c'): 1, ('n', 'e'): 3, ('s', 'n'): 2, ('a', 'r'): 2, ('e', 'c'): 1, ('k', 'i'): 1, ('u', 'p'): 1, ('o', 'h'): 1, ('r', 'p'): 2, ('o', 'y'): 1, ('c', 'u'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('n', 'u'): 1, ('l', 'u'): 1, ('e', 'a'): 4, ('e', 'u'): 2, ('w', 's'): 1, ('r', 's'): 2, ('u', 'a'): 1, ('g', 'c'): 1, ('a', 'd'): 2, ('u', 'g'): 1, ('s', 'i'): 3, ('g', 'r'): 1, ('a', 'e'): 4, ('c', 'n'): 1, ('t', 's'): 3, ('e', 'n'): 3, ('c', 'o'): 1, ('o', 'u'): 2, ('l', 's'): 1, ('p', 'i'): 3, ('e', 's'): 2, ('l', 'i'): 1, ('x', 'n'): 1, ('a', 'i'): 5, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('e', 'p'): 2, ('i', 'd'): 2, ('s', 't'): 3, ('o', 't'): 1, ('u', 'n'): 1, ('u', 'l'): 1, ('m', 't'): 2, ('c', 'g'): 1, ('a', 'g'): 1, ('s', 'p'): 2, ('g', 'u'): 1, ('n', 'p'): 3, ('c', 'd'): 1, ('r', 'u'): 1, ('t', 'a'): 1, ('x', 'p'): 1, ('e', 'o'): 1, ('n', 's'): 2, ('m', 'a'): 1, ('o', 'g'): 1, ('s', 'g'): 1, ('s', 'a'): 4, ('g', 'i'): 2, ('u', 'y'): 1, ('i', 'h'): 1, ('n', 'g'): 2, ('a', 'l'): 3, ('a', 'm'): 1, ('n', 'a'): 5, ('m', 'e'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('a', 'k'): 1, ('u', 't'): 2, ('d', 'a'): 2, ('o', 'n'): 1, ('a', 'x'): 1, ('k', 'e'): 1, ('c', 'i'): 1, ('i', 'l'): 1, ('r', 'g'): 1, ('w', 'h'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 2, ('i', 'm'): 1, ('h', 'i'): 1, ('t', 'm'): 2, ('l', 'e'): 2, ('r', 'e'): 1, ('i', 'e'): 4, ('i', 'k'): 1, ('k', 'm'): 1, ('u', 'e'): 2, ('s', 'u'): 2, ('x', 'i'): 1, ('t', 'i'): 2, ('u', 'm'): 1, ('o', 'i'): 1, ('w', 'a'): 1, ('l', 'a'): 3, ('u', 'r'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('g', 'a'): 1, ('i', 't'): 2, ('r', 'n'): 2, ('h', 't'): 1, ('r', 'o'): 1, ('m', 'u'): 1, ('e', 'k'): 1, ('h', 's'): 1, ('n', 'd'): 2, ('g', 'o'): 1, ('a', 'w'): 1, ('h', 'o'): 1, ('e', 'l'): 2, ('p', 'r'): 2, ('a', 'u'): 1, ('d', 'e'): 2, ('l', 'p'): 2, ('r', 'i'): 1, ('b', 'r'): 1, ('g', 'p'): 1, ('m', 's'): 2, ('p', 'l'): 2, ('d', 'g'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('e', 'm'): 1, ('s', 'k'): 1, ('e', 't'): 1, ('n', 'l'): 1, ('n', 'i'): 5, ('c', 'e'): 1, ('s', 'm'): 2, ('s', 'l'): 1, ('e', 'd'): 2, ('g', 'e'): 1, ('n', 'k'): 1, ('g', 'd'): 1, ('g', 's'): 1, ('n', 'o'): 2, ('t', 'k'): 1, ('n', 'r'): 2, ('i', 'x'): 1, ('m', 'i'): 1, ('p', 'n'): 3, ('u', 'i'): 1, ('o', 'w'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('o', 'd'): 1, ('o', 'e'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('s', 'w'): 1, ('n', 'b'): 1, ('o', 'r'): 1, ('s', 'h'): 1, ('i', 'a'): 5, ('g', 'n'): 2, ('n', 'c'): 1, ('e', 'i'): 4, ('a', 'p'): 4, ('k', 't'): 1, ('i', 'r'): 1, ('d', 'i'): 2, ('k', 'n'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('l', 'n'): 1, ('a', 's'): 4, ('r', 'l'): 1, ('t', 'e'): 1, ('p', 'g'): 1, ('p', 'u'): 1, ('t', 'b'): 1, ('e', 'r'): 1, ('y', 'u'): 1, ('i', 'u'): 1, ('i', 'p'): 3, ('e', 'g'): 1, ('d', 'u'): 1, ('r', 'b'): 1, ('u', 'c'): 1, ('s', 'e'): 2, ('o', 'c'): 1, ('l', 'r'): 1, ('i', 's'): 3, ('s', 'r'): 2, ('k', 's'): 1, ('d', 'n'): 2, ('i', 'n'): 5, ('p', 's'): 2, ('d', 'o'): 1, ('i', 'o'): 1, ('y', 'o'): 1, ('u', 'd'): 1, ('o', 'f'): 2, ('f', 'o'): 2, ('k', 'a'): 1, ('u', 'o'): 2, ('r', 'a'): 2, ('p', 'a'): 4, ('t', 'n'): 1, ('a', 'n'): 5, ('u', 's'): 2, ('h', 'w'): 1, ('m', 'n'): 1, ('i', 'g'): 2, ('d', 'c'): 1, ('i', 'c'): 1, ('n', 'e'): 3, ('s', 'n'): 2, ('a', 'r'): 2, ('e', 'c'): 1, ('b', 'n'): 1, ('k', 'i'): 1, ('u', 'p'): 1, ('b', 'o'): 1, ('o', 'h'): 1, ('r', 'p'): 2, ('o', 'y'): 1, ('c', 'u'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('n', 'u'): 1, ('l', 'u'): 1, ('e', 'a'): 4, ('e', 'u'): 2, ('w', 's'): 1, ('r', 's'): 2, ('u', 'a'): 1, ('g', 'c'): 1, ('a', 'd'): 2, ('u', 'g'): 1, ('s', 'i'): 3, ('g', 'r'): 1, ('a', 'e'): 4, ('c', 'n'): 1, ('t', 's'): 3, ('e', 'n'): 3, ('c', 'o'): 1, ('o', 'u'): 2, ('l', 's'): 1, ('p', 'i'): 3, ('e', 's'): 2, ('l', 'i'): 1, ('x', 'n'): 1, ('a', 'i'): 5, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('o', 'b'): 1, ('e', 'p'): 2, ('i', 'd'): 2, ('s', 't'): 3, ('o', 't'): 1, ('u', 'n'): 1, ('u', 'l'): 1, ('m', 't'): 2, ('c', 'g'): 1, ('a', 'g'): 1, ('s', 'p'): 2, ('g', 'u'): 1, ('n', 'p'): 3, ('c', 'd'): 1, ('r', 'u'): 1, ('t', 'a'): 1, ('x', 'p'): 1, ('e', 'o'): 1, ('n', 's'): 2, ('m', 'a'): 1, ('o', 'g'): 1, ('s', 'g'): 1, ('s', 'a'): 4, ('g', 'i'): 2, ('u', 'y'): 1, ('i', 'h'): 1, ('n', 'g'): 2, ('a', 'l'): 3, ('a', 'm'): 1, ('n', 'a'): 5, ('m', 'e'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('a', 'k'): 1, ('u', 't'): 2, ('d', 'a'): 2, ('o', 'n'): 2, ('a', 'x'): 1, ('k', 'e'): 1, ('c', 'i'): 1, ('i', 'l'): 1, ('r', 'g'): 1, ('w', 'h'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 2, ('i', 'm'): 1, ('h', 'i'): 1, ('t', 'm'): 2, ('l', 'e'): 2, ('r', 'e'): 1, ('i', 'e'): 4, ('i', 'k'): 1, ('k', 'm'): 1, ('u', 'e'): 2, ('s', 'u'): 2, ('x', 'i'): 1, ('t', 'i'): 2, ('u', 'm'): 1, ('o', 'i'): 1, ('w', 'a'): 1, ('l', 'a'): 3, ('u', 'r'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('g', 'a'): 1, ('i', 't'): 2, ('r', 'n'): 2, ('h', 't'): 1, ('r', 'o'): 1, ('m', 'u'): 1, ('e', 'k'): 1, ('h', 's'): 1, ('n', 'd'): 3, ('g', 'o'): 1, ('a', 'w'): 1, ('h', 'o'): 1, ('e', 'l'): 2, ('p', 'r'): 2, ('a', 'u'): 1, ('d', 'e'): 2, ('l', 'p'): 2, ('r', 'i'): 1, ('b', 'r'): 1, ('g', 'p'): 1, ('m', 's'): 2, ('p', 'l'): 2, ('d', 'g'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('e', 'm'): 1, ('s', 'k'): 1, ('e', 't'): 1, ('n', 'l'): 1, ('n', 'i'): 5, ('c', 'e'): 1, ('s', 'm'): 2, ('s', 'l'): 1, ('e', 'd'): 2, ('g', 'e'): 1, ('n', 'k'): 1, ('g', 'd'): 1, ('g', 's'): 1, ('n', 'o'): 2, ('t', 'k'): 1, ('n', 'r'): 2, ('i', 'x'): 1, ('m', 'i'): 1, ('p', 'n'): 3, ('u', 'i'): 1, ('o', 'w'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('o', 'd'): 1, ('o', 'e'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('s', 'w'): 1, ('n', 'b'): 1, ('o', 'r'): 1, ('s', 'h'): 1, ('i', 'a'): 5, ('g', 'n'): 2, ('n', 'c'): 1, ('e', 'i'): 4, ('a', 'p'): 4, ('k', 't'): 1, ('i', 'r'): 1, ('d', 'i'): 2, ('k', 'n'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('l', 'n'): 1, ('a', 's'): 4, ('r', 'l'): 1, ('t', 'e'): 1, ('p', 'g'): 1, ('p', 'u'): 1, ('t', 'b'): 1, ('e', 'r'): 1, ('y', 'u'): 1, ('i', 'u'): 1, ('i', 'p'): 3, ('e', 'g'): 1, ('d', 'u'): 1, ('r', 'b'): 1, ('u', 'c'): 1, ('s', 'e'): 2, ('o', 'c'): 1, ('l', 'r'): 1, ('i', 's'): 3, ('s', 'r'): 2, ('k', 's'): 1, ('d', 'n'): 3, ('i', 'n'): 5, ('p', 's'): 2, ('d', 'o'): 1, ('i', 'o'): 1, ('y', 'o'): 1, ('u', 'd'): 1, ('o', 'f'): 2, ('f', 'o'): 2, ('k', 'a'): 1, ('u', 'o'): 2, ('r', 'a'): 2, ('p', 'a'): 4, ('t', 'n'): 1, ('a', 'n'): 6, ('u', 's'): 2, ('h', 'w'): 1, ('m', 'n'): 1, ('i', 'g'): 2, ('d', 'c'): 1, ('i', 'c'): 1, ('n', 'e'): 3, ('s', 'n'): 2, ('a', 'r'): 2, ('e', 'c'): 1, ('b', 'n'): 1, ('k', 'i'): 1, ('u', 'p'): 1, ('b', 'o'): 1, ('o', 'h'): 1, ('r', 'p'): 2, ('o', 'y'): 1, ('c', 'u'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('n', 'u'): 1, ('l', 'u'): 1, ('e', 'a'): 4, ('e', 'u'): 2, ('w', 's'): 1, ('r', 's'): 2, ('u', 'a'): 1, ('g', 'c'): 1, ('a', 'd'): 3, ('u', 'g'): 1, ('s', 'i'): 3, ('g', 'r'): 1, ('a', 'e'): 4, ('c', 'n'): 1, ('t', 's'): 3, ('e', 'n'): 3, ('c', 'o'): 1, ('o', 'u'): 2, ('l', 's'): 1, ('p', 'i'): 3, ('e', 's'): 2, ('l', 'i'): 1, ('x', 'n'): 1, ('a', 'i'): 5, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('o', 'b'): 1, ('e', 'p'): 2, ('i', 'd'): 2, ('s', 't'): 3, ('o', 't'): 1, ('u', 'n'): 1, ('u', 'l'): 1, ('m', 't'): 2, ('c', 'g'): 1, ('a', 'g'): 1, ('s', 'p'): 2, ('g', 'u'): 1, ('n', 'p'): 3, ('c', 'd'): 1, ('r', 'u'): 1, ('t', 'a'): 1, ('x', 'p'): 1, ('e', 'o'): 1, ('n', 's'): 2, ('m', 'a'): 1, ('o', 'g'): 1, ('s', 'g'): 1, ('s', 'a'): 4, ('g', 'i'): 2, ('u', 'y'): 1, ('i', 'h'): 1, ('n', 'g'): 2, ('a', 'l'): 3, ('a', 'm'): 1, ('n', 'a'): 6, ('m', 'e'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('a', 'k'): 1, ('u', 't'): 2, ('d', 'a'): 3, ('o', 'n'): 2, ('a', 'x'): 1, ('k', 'e'): 1, ('c', 'i'): 1, ('i', 'l'): 1, ('r', 'g'): 1, ('w', 'h'): 1})
# defaultdict(<class 'int'>, {('p', 'e'): 2, ('i', 'm'): 1, ('h', 'i'): 1, ('t', 'm'): 2, ('l', 'e'): 2, ('r', 'e'): 1, ('i', 'e'): 4, ('i', 'k'): 1, ('k', 'm'): 1, ('u', 'e'): 2, ('s', 'u'): 2, ('x', 'i'): 1, ('t', 'i'): 2, ('u', 'm'): 1, ('o', 'i'): 1, ('w', 'a'): 1, ('l', 'a'): 3, ('u', 'r'): 1, ('p', 'x'): 1, ('t', 'u'): 2, ('g', 'a'): 1, ('i', 't'): 2, ('r', 'n'): 2, ('h', 't'): 1, ('r', 'o'): 1, ('m', 'u'): 1, ('e', 'k'): 1, ('h', 's'): 1, ('n', 'd'): 3, ('g', 'o'): 1, ('a', 'w'): 1, ('h', 'o'): 1, ('e', 'l'): 2, ('p', 'r'): 2, ('a', 'u'): 1, ('d', 'e'): 2, ('l', 'p'): 2, ('r', 'i'): 1, ('b', 'r'): 1, ('g', 'p'): 1, ('m', 's'): 2, ('p', 'l'): 2, ('d', 'g'): 1, ('x', 'l'): 1, ('w', 'o'): 1, ('e', 'm'): 1, ('s', 'k'): 1, ('e', 't'): 1, ('n', 'l'): 1, ('n', 'i'): 5, ('c', 'e'): 1, ('s', 'm'): 2, ('s', 'l'): 1, ('e', 'd'): 2, ('g', 'e'): 1, ('n', 'k'): 1, ('g', 'd'): 1, ('g', 's'): 1, ('n', 'o'): 2, ('t', 'k'): 1, ('n', 'r'): 2, ('i', 'x'): 1, ('m', 'i'): 1, ('p', 'n'): 3, ('u', 'i'): 1, ('o', 'w'): 1, ('t', 'h'): 1, ('m', 'k'): 1, ('o', 'd'): 1, ('o', 'e'): 1, ('l', 'x'): 1, ('t', 'o'): 1, ('s', 'w'): 1, ('n', 'b'): 1, ('o', 'r'): 1, ('s', 'h'): 1, ('i', 'a'): 5, ('g', 'n'): 2, ('n', 'c'): 1, ('e', 'i'): 4, ('a', 'p'): 4, ('k', 't'): 1, ('i', 'r'): 1, ('d', 'i'): 2, ('k', 'n'): 1, ('a', 't'): 1, ('n', 'm'): 1, ('l', 'n'): 1, ('a', 's'): 4, ('r', 'l'): 1, ('t', 'e'): 1, ('p', 'g'): 1, ('p', 'u'): 1, ('t', 'b'): 1, ('e', 'r'): 1, ('y', 'u'): 1, ('i', 'u'): 1, ('i', 'p'): 3, ('e', 'g'): 1, ('d', 'u'): 1, ('r', 'b'): 1, ('u', 'c'): 1, ('s', 'e'): 2, ('o', 'c'): 1, ('l', 'r'): 1, ('i', 's'): 3, ('s', 'r'): 2, ('k', 's'): 1, ('d', 'n'): 3, ('i', 'n'): 5, ('p', 's'): 2, ('d', 'o'): 1, ('i', 'o'): 1, ('y', 'o'): 1, ('u', 'd'): 1, ('o', 'f'): 2, ('f', 'o'): 2, ('k', 'a'): 1, ('u', 'o'): 2, ('r', 'a'): 2, ('p', 'a'): 4, ('t', 'n'): 1, ('a', 'n'): 6, ('u', 's'): 2, ('h', 'w'): 1, ('m', 'n'): 1, ('i', 'g'): 2, ('d', 'c'): 1, ('i', 'c'): 1, ('n', 'e'): 3, ('s', 'n'): 2, ('a', 'r'): 2, ('e', 'c'): 1, ('b', 'n'): 1, ('k', 'i'): 1, ('u', 'p'): 1, ('b', 'o'): 1, ('o', 'h'): 1, ('r', 'p'): 2, ('o', 'y'): 1, ('c', 'u'): 1, ('u', 'b'): 1, ('n', 'x'): 1, ('n', 'u'): 1, ('l', 'u'): 1, ('e', 'a'): 4, ('e', 'u'): 2, ('w', 's'): 1, ('r', 's'): 2, ('u', 'a'): 1, ('g', 'c'): 1, ('a', 'd'): 3, ('u', 'g'): 1, ('s', 'i'): 3, ('g', 'r'): 1, ('a', 'e'): 4, ('c', 'n'): 1, ('t', 's'): 3, ('e', 'n'): 3, ('c', 'o'): 1, ('o', 'u'): 2, ('l', 's'): 1, ('p', 'i'): 3, ('e', 's'): 2, ('l', 'i'): 1, ('x', 'n'): 1, ('a', 'i'): 5, ('n', 't'): 1, ('b', 'u'): 1, ('x', 'a'): 1, ('b', 't'): 1, ('o', 'b'): 1, ('e', 'p'): 2, ('i', 'd'): 2, ('s', 't'): 3, ('o', 't'): 1, ('u', 'n'): 1, ('u', 'l'): 1, ('m', 't'): 2, ('c', 'g'): 1, ('a', 'g'): 1, ('s', 'p'): 2, ('g', 'u'): 1, ('n', 'p'): 3, ('c', 'd'): 1, ('r', 'u'): 1, ('t', 'a'): 1, ('x', 'p'): 1, ('e', 'o'): 1, ('n', 's'): 2, ('m', 'a'): 1, ('o', 'g'): 1, ('s', 'g'): 1, ('s', 'a'): 4, ('g', 'i'): 2, ('u', 'y'): 1, ('i', 'h'): 1, ('n', 'g'): 2, ('a', 'l'): 3, ('a', 'm'): 1, ('n', 'a'): 6, ('m', 'e'): 1, ('x', 'e'): 1, ('e', 'x'): 1, ('a', 'k'): 1, ('u', 't'): 2, ('d', 'a'): 3, ('o', 'n'): 2, ('a', 'x'): 1, ('k', 'e'): 1, ('c', 'i'): 1, ('i', 'l'): 1, ('r', 'g'): 1, ('w', 'h'): 1})
# ...
# defaultdict(<class 'int'>, {('i', 'm'): 7, ('i', 'l'): 20, ('p', 'm'): 2, ('p', 'r'): 19, ('k', 'm'): 1, ('v', 'a'): 5, ('s', 'u'): 26, ('d', 'm'): 3, ('w', 'g'): 1, ('n', 'x'): 2, ('u', 'm'): 5, ('o', 'i'): 18, ('w', 'a'): 4, ('c', 'x'): 1, ('w', 'r'): 1, ('d', 'p'): 3, ('l', 'a'): 27, ('v', 'l'): 2, ('u', 'r'): 31, ('a', 'y'): 10, ('q', 'l'): 2, ('t', 'u'): 23, ('i', 't'): 25, ('p', 'f'): 1, ('h', 'k'): 1, ('e', 'q'): 3, ('b', 'd'): 3, ('m', 'u'): 5, ('n', 'd'): 25, ('w', 'e'): 8, ('g', 'o'): 10, ('f', 't'): 4, ('l', 'h'): 2, ('h', 'o'): 21, ('e', 'h'): 32, ('e', 'l'): 31, ('a', 'q'): 1, ('i', 'y'): 5, ('w', 'p'): 1, ('w', 'c'): 4, ('l', 'p'): 15, ('h', 'd'): 1, ('q', 'e'): 3, ('r', 'i'): 15, ('n', 'c'): 14, ('o', 'q'): 1, ('r', 'c'): 13, ('q', 't'): 1, ('j', 'o'): 1, ('t', 'm'): 8, ('p', 'l'): 15, ('q', 's'): 1, ('g', 's'): 7, ('h', 'r'): 11, ('s', 'k'): 5, ('e', 't'): 48, ('g', 'c'): 2, ('c', 'j'): 1, ('c', 'y'): 4, ('s', 'e'): 48, ('c', 's'): 17, ('e', 'd'): 16, ('g', 'e'): 11, ('y', 'i'): 5, ('u', 'f'): 2, ('m', 'l'): 8, ('n', 'r'): 16, ('u', 'k'): 1, ('l', 'f'): 4, ('i', 'x'): 1, ('m', 'i'): 7, ('p', 'n'): 12, ('e', 'o'): 31, ('m', 'k'): 1, ('d', 'z'): 1, ('k', 'g'): 1, ('b', 'y'): 2, ('o', 'e'): 31, ('q', 'a'): 1, ('l', 'x'): 3, ('t', 'o'): 39, ('d', 'r'): 7, ('l', 'o'): 14, ('n', 'b'): 9, ('o', 'm'): 7, ('o', 'r'): 30, ('q', 'u'): 3, ('b', 'e'): 13, ('s', 'h'): 15, ('i', 'a'): 33, ('p', 'y'): 2, ('b', 'r'): 3, ('a', 'p'): 19, ('o', 'v'): 3, ('k', 'u'): 1, ('d', 'i'): 12, ('w', 'k'): 2, ('q', 'o'): 1, ('h', 'y'): 2, ('k', 'n'): 5, ('g', 'v'): 2, ('f', 'u'): 2, ('l', 'b'): 8, ('j', 'r'): 1, ('t', 'd'): 7, ('l', 'v'): 2, ('y', 'u'): 5, ('i', 'u'): 8, ('i', 'p'): 13, ('r', 'b'): 3, ('u', 'c'): 16, ('t', 'c'): 12, ('o', 'c'): 16, ('n', 'f'): 2, ('l', 'r'): 20, ('s', 'b'): 7, ('q', 'c'): 1, ('i', 's'): 29, ('k', 's'): 5, ('d', 's'): 8, ('n', 'h'): 6, ('r', 'v'): 5, ('l', 'i'): 20, ('l', 'd'): 7, ('z', 'r'): 1, ('s', 'c'): 17, ('f', 's'): 1, ('y', 'w'): 1, ('n', 'q'): 2, ('o', 'l'): 14, ('o', 'f'): 19, ('v', 'h'): 1, ('e', 'v'): 8, ('f', 'o'): 19, ('u', 'o'): 20, ('n', 't'): 21, ('y', 'b'): 2, ('u', 'd'): 12, ('t', 'b'): 9, ('z', 'd'): 1, ('c', 'd'): 4, ('p', 'g'): 1, ('b', 'u'): 13, ('c', 'a'): 17, ('l', 'y'): 7, ('h', 'g'): 7, ('o', 'z'): 1, ('k', 'h'): 1, ('d', 'c'): 4, ('h', 'a'): 14, ('b', 't'): 9, ('g', 't'): 12, ('s', 'n'): 19, ('r', 'q'): 1, ('w', 'd'): 1, ('b', 'n'): 9, ('n', 'y'): 9, ('p', 't'): 5, ('v', 'e'): 8, ('b', 'o'): 8, ('k', 'r'): 2, ('o', 'y'): 8, ('c', 'u'): 16, ('c', 'p'): 7, ('y', 'g'): 2, ('r', 't'): 29, ('e', 'a'): 43, ('h', 'p'): 1, ('z', 'i'): 1, ('v', 'y'): 2, ('a', 'f'): 2, ('r', 's'): 27, ('r', 'z'): 1, ('a', 'b'): 9, ('h', 'f'): 1, ('j', 't'): 1, ('o', 'w'): 13, ('a', 'e'): 43, ('y', 'l'): 7, ('y', 'h'): 2, ('t', 's'): 18, ('l', 'n'): 10, ('f', 'q'): 1, ('s', 'a'): 39, ('e', 's'): 48, ('w', 'i'): 9, ('f', 'h'): 1, ('a', 'i'): 33, ('w', 'y'): 1, ('v', 't'): 3, ('o', 'h'): 21, ('y', 'n'): 9, ('o', 'p'): 6, ('e', 'p'): 23, ('i', 'd'): 12, ('s', 't'): 18, ('d', 'w'): 1, ('o', 't'): 39, ('x', 'o'): 2, ('b', 'm'): 1, ('w', 't'): 3, ('s', 'd'): 8, ('s', 'p'): 16, ('o', 's'): 20, ('h', 'u'): 4, ('w', 'h'): 17, ('l', 'z'): 1, ('g', 'u'): 5, ('e', 'z'): 1, ('a', 'o'): 15, ('m', 'o'): 7, ('g', 'h'): 7, ('l', 't'): 14, ('h', 'n'): 6, ('b', 'l'): 8, ('n', 's'): 19, ('o', 'a'): 15, ('y', 'c'): 4, ('o', 'g'): 10, ('n', 'j'): 1, ('k', 'o'): 1, ('d', 'v'): 3, ('i', 'v'): 4, ('m', 'w'): 1, ('v', 'd'): 3, ('w', 'l'): 4, ('b', 'g'): 4, ('x', 'm'): 1, ('g', 'b'): 4, ('m', 'e'): 15, ('x', 'e'): 5, ('v', 'o'): 3, ('e', 'x'): 5, ('p', 'v'): 1, ('r', 'w'): 1, ('z', 'm'): 1, ('l', 'g'): 3, ('d', 't'): 7, ('o', 'n'): 31, ('s', 'j'): 1, ('f', 'c'): 1, ('a', 'x'): 1, ('c', 'i'): 13, ('r', 'g'): 9, ('h', 'l'): 2, ('a', 'h'): 14, ('y', 't'): 7, ('p', 'e'): 23, ('h', 'i'): 16, ('t', 'w'): 3, ('l', 'e'): 31, ('f', 'r'): 7, ('m', 'z'): 1, ('m', 'b'): 1, ('i', 'e'): 24, ('i', 'k'): 4, ('j', 'y'): 1, ('d', 'e'): 16, ('p', 'w'): 1 ...
# defaultdict(<class 'int'>, {('i', 'm'): 7, ('i', 'l'): 20, ('p', 'm'): 2, ('p', 'r'): 19, ('k', 'm'): 1, ('v', 'a'): 6, ('s', 'u'): 26, ('d', 'm'): 3, ('w', 'g'): 1, ('n', 'x'): 2, ('u', 'm'): 5, ('o', 'i'): 19, ('w', 'a'): 4, ('c', 'x'): 1, ('w', 'r'): 1, ('d', 'p'): 3, ('l', 'a'): 27, ('v', 'l'): 2, ('u', 'r'): 31, ('a', 'y'): 10, ('q', 'l'): 2, ('t', 'u'): 23, ('i', 't'): 25, ('p', 'f'): 1, ('h', 'k'): 1, ('e', 'q'): 3, ('b', 'd'): 3, ('m', 'u'): 5, ('n', 'd'): 25, ('w', 'e'): 8, ('g', 'o'): 10, ('f', 't'): 4, ('l', 'h'): 2, ('h', 'o'): 21, ('e', 'h'): 32, ('e', 'l'): 31, ('a', 'q'): 1, ('i', 'y'): 5, ('w', 'p'): 1, ('w', 'c'): 4, ('l', 'p'): 15, ('h', 'd'): 1, ('q', 'e'): 3, ('r', 'i'): 15, ('n', 'c'): 14, ('o', 'q'): 1, ('r', 'c'): 13, ('q', 't'): 1, ('j', 'o'): 1, ('t', 'm'): 8, ('p', 'l'): 15, ('q', 's'): 1, ('g', 's'): 7, ('h', 'r'): 11, ('s', 'k'): 5, ('e', 't'): 48, ('g', 'c'): 2, ('c', 'j'): 1, ('c', 'y'): 4, ('s', 'e'): 48, ('c', 's'): 17, ('e', 'd'): 16, ('g', 'e'): 11, ('y', 'i'): 5, ('u', 'f'): 2, ('m', 'l'): 8, ('n', 'r'): 16, ('u', 'k'): 1, ('l', 'f'): 4, ('i', 'x'): 1, ('m', 'i'): 7, ('p', 'n'): 12, ('e', 'o'): 31, ('m', 'k'): 1, ('d', 'z'): 1, ('k', 'g'): 1, ('b', 'y'): 2, ('o', 'e'): 31, ('q', 'a'): 1, ('l', 'x'): 3, ('t', 'o'): 39, ('d', 'r'): 7, ('l', 'o'): 14, ('n', 'b'): 9, ('o', 'm'): 7, ('o', 'r'): 30, ('q', 'u'): 3, ('b', 'e'): 13, ('s', 'h'): 15, ('i', 'a'): 34, ('p', 'y'): 2, ('b', 'r'): 3, ('a', 'p'): 19, ('o', 'v'): 4, ('k', 'u'): 1, ('d', 'i'): 13, ('w', 'k'): 2, ('q', 'o'): 1, ('h', 'y'): 2, ('k', 'n'): 5, ('g', 'v'): 2, ('f', 'u'): 2, ('l', 'b'): 8, ('j', 'r'): 1, ('t', 'd'): 7, ('l', 'v'): 2, ('y', 'u'): 5, ('i', 'u'): 8, ('i', 'p'): 13, ('r', 'b'): 3, ('u', 'c'): 16, ('t', 'c'): 12, ('o', 'c'): 16, ('n', 'f'): 2, ('l', 'r'): 20, ('s', 'b'): 7, ('q', 'c'): 1, ('i', 's'): 29, ('k', 's'): 5, ('d', 's'): 8, ('n', 'h'): 6, ('r', 'v'): 5, ('l', 'i'): 20, ('l', 'd'): 7, ('z', 'r'): 1, ('s', 'c'): 17, ('f', 's'): 1, ('y', 'w'): 1, ('n', 'q'): 2, ('o', 'l'): 14, ('o', 'f'): 19, ('v', 'h'): 1, ('e', 'v'): 8, ('f', 'o'): 19, ('u', 'o'): 20, ('n', 't'): 21, ('y', 'b'): 2, ('u', 'd'): 12, ('t', 'b'): 9, ('z', 'd'): 1, ('c', 'd'): 4, ('p', 'g'): 1, ('b', 'u'): 13, ('c', 'a'): 17, ('l', 'y'): 7, ('h', 'g'): 7, ('o', 'z'): 1, ('k', 'h'): 1, ('d', 'c'): 4, ('h', 'a'): 14, ('b', 't'): 9, ('g', 't'): 12, ('s', 'n'): 19, ('r', 'q'): 1, ('w', 'd'): 1, ('b', 'n'): 9, ('n', 'y'): 9, ('p', 't'): 5, ('v', 'e'): 8, ('b', 'o'): 8, ('k', 'r'): 2, ('o', 'y'): 8, ('c', 'u'): 16, ('c', 'p'): 7, ('y', 'g'): 2, ('r', 't'): 29, ('e', 'a'): 43, ('h', 'p'): 1, ('z', 'i'): 1, ('v', 'y'): 2, ('a', 'f'): 2, ('r', 's'): 27, ('r', 'z'): 1, ('a', 'b'): 9, ('h', 'f'): 1, ('j', 't'): 1, ('o', 'w'): 13, ('a', 'e'): 43, ('y', 'l'): 7, ('y', 'h'): 2, ('t', 's'): 18, ('l', 'n'): 10, ('f', 'q'): 1, ('s', 'a'): 39, ('e', 's'): 48, ('w', 'i'): 9, ('f', 'h'): 1, ('a', 'i'): 34, ('w', 'y'): 1, ('v', 't'): 3, ('o', 'h'): 21, ('y', 'n'): 9, ('o', 'p'): 6, ('e', 'p'): 23, ('i', 'd'): 13, ('s', 't'): 18, ('d', 'w'): 1, ('o', 't'): 39, ('x', 'o'): 2, ('b', 'm'): 1, ('w', 't'): 3, ('s', 'd'): 8, ('s', 'p'): 16, ('o', 's'): 20, ('h', 'u'): 4, ('w', 'h'): 17, ('l', 'z'): 1, ('g', 'u'): 5, ('e', 'z'): 1, ('a', 'o'): 16, ('m', 'o'): 7, ('g', 'h'): 7, ('l', 't'): 14, ('h', 'n'): 6, ('b', 'l'): 8, ('n', 's'): 19, ('o', 'a'): 16, ('y', 'c'): 4, ('o', 'g'): 10, ('n', 'j'): 1, ('k', 'o'): 1, ('d', 'v'): 4, ('i', 'v'): 5, ('m', 'w'): 1, ('v', 'd'): 4, ('w', 'l'): 4, ('b', 'g'): 4, ('x', 'm'): 1, ('g', 'b'): 4, ('m', 'e'): 15, ('x', 'e'): 5, ('v', 'o'): 4, ('e', 'x'): 5, ('p', 'v'): 1, ('r', 'w'): 1, ('z', 'm'): 1, ('l', 'g'): 3, ('d', 't'): 7, ('o', 'n'): 31, ('s', 'j'): 1, ('f', 'c'): 1, ('a', 'x'): 1, ('c', 'i'): 13, ('r', 'g'): 9, ('h', 'l'): 2, ('a', 'h'): 14, ('y', 't'): 7, ('p', 'e'): 23, ('h', 'i'): 16, ('t', 'w'): 3, ('l', 'e'): 31, ('f', 'r'): 7, ('m', 'z'): 1, ('m', 'b'): 1, ('i', 'e'): 24, ('i', 'k'): 4, ('j', 'y'): 1, ('d', 'e'): 16, ('p', 'w'): 1 ...
# defaultdict(<class 'int'>, {('i', 'm'): 7, ('i', 'l'): 20, ('p', 'm'): 2, ('p', 'r'): 19, ('k', 'm'): 1, ('v', 'a'): 6, ('s', 'u'): 26, ('d', 'm'): 3, ('w', 'g'): 1, ('n', 'x'): 2, ('u', 'm'): 5, ('o', 'i'): 19, ('w', 'a'): 4, ('c', 'x'): 1, ('w', 'r'): 2, ('d', 'p'): 3, ('l', 'a'): 27, ('v', 'l'): 2, ('u', 'r'): 31, ('a', 'y'): 10, ('q', 'l'): 2, ('t', 'u'): 23, ('i', 't'): 25, ('p', 'f'): 1, ('h', 'k'): 1, ('e', 'q'): 3, ('b', 'd'): 3, ('m', 'u'): 5, ('n', 'd'): 25, ('w', 'e'): 9, ('g', 'o'): 10, ('f', 't'): 4, ('l', 'h'): 2, ('h', 'o'): 21, ('e', 'h'): 32, ('e', 'l'): 31, ('a', 'q'): 1, ('i', 'y'): 5, ('w', 'p'): 1, ('w', 'c'): 4, ('l', 'p'): 15, ('h', 'd'): 1, ('q', 'e'): 3, ('r', 'i'): 15, ('n', 'c'): 14, ('o', 'q'): 1, ('r', 'c'): 13, ('q', 't'): 1, ('j', 'o'): 1, ('t', 'm'): 8, ('p', 'l'): 15, ('q', 's'): 1, ('g', 's'): 7, ('h', 'r'): 11, ('s', 'k'): 5, ('e', 't'): 48, ('g', 'c'): 2, ('c', 'j'): 1, ('c', 'y'): 4, ('s', 'e'): 49, ('c', 's'): 17, ('e', 'd'): 16, ('g', 'e'): 11, ('y', 'i'): 5, ('u', 'f'): 2, ('m', 'l'): 8, ('n', 'r'): 16, ('u', 'k'): 1, ('l', 'f'): 4, ('i', 'x'): 1, ('m', 'i'): 7, ('p', 'n'): 12, ('e', 'o'): 32, ('m', 'k'): 1, ('d', 'z'): 1, ('k', 'g'): 1, ('b', 'y'): 2, ('o', 'e'): 32, ('q', 'a'): 1, ('l', 'x'): 3, ('t', 'o'): 39, ('d', 'r'): 7, ('l', 'o'): 14, ('n', 'b'): 9, ('o', 'm'): 7, ('o', 'r'): 31, ('q', 'u'): 3, ('b', 'e'): 13, ('s', 'h'): 15, ('i', 'a'): 34, ('p', 'y'): 2, ('b', 'r'): 3, ('a', 'p'): 19, ('o', 'v'): 4, ('k', 'u'): 1, ('d', 'i'): 13, ('w', 'k'): 2, ('q', 'o'): 1, ('h', 'y'): 2, ('k', 'n'): 5, ('g', 'v'): 2, ('f', 'u'): 2, ('l', 'b'): 8, ('j', 'r'): 1, ('t', 'd'): 7, ('l', 'v'): 2, ('y', 'u'): 5, ('i', 'u'): 8, ('i', 'p'): 13, ('r', 'b'): 3, ('u', 'c'): 16, ('t', 'c'): 12, ('o', 'c'): 16, ('n', 'f'): 2, ('l', 'r'): 20, ('s', 'b'): 7, ('q', 'c'): 1, ('i', 's'): 29, ('k', 's'): 5, ('d', 's'): 8, ('n', 'h'): 6, ('r', 'v'): 5, ('l', 'i'): 20, ('l', 'd'): 7, ('z', 'r'): 1, ('s', 'c'): 17, ('f', 's'): 1, ('y', 'w'): 1, ('n', 'q'): 2, ('o', 'l'): 14, ('o', 'f'): 19, ('v', 'h'): 1, ('e', 'v'): 8, ('f', 'o'): 19, ('u', 'o'): 20, ('n', 't'): 21, ('y', 'b'): 2, ('u', 'd'): 12, ('t', 'b'): 9, ('z', 'd'): 1, ('c', 'd'): 4, ('p', 'g'): 1, ('b', 'u'): 13, ('c', 'a'): 17, ('l', 'y'): 7, ('h', 'g'): 7, ('o', 'z'): 1, ('k', 'h'): 1, ('d', 'c'): 4, ('h', 'a'): 14, ('b', 't'): 9, ('g', 't'): 12, ('s', 'n'): 19, ('r', 'q'): 1, ('w', 'd'): 1, ('b', 'n'): 9, ('n', 'y'): 9, ('p', 't'): 5, ('v', 'e'): 8, ('b', 'o'): 8, ('k', 'r'): 2, ('o', 'y'): 8, ('c', 'u'): 16, ('c', 'p'): 7, ('y', 'g'): 2, ('r', 't'): 29, ('e', 'a'): 43, ('h', 'p'): 1, ('z', 'i'): 1, ('v', 'y'): 2, ('a', 'f'): 2, ('r', 's'): 28, ('r', 'z'): 1, ('a', 'b'): 9, ('h', 'f'): 1, ('j', 't'): 1, ('o', 'w'): 14, ('a', 'e'): 43, ('y', 'l'): 7, ('y', 'h'): 2, ('t', 's'): 18, ('l', 'n'): 10, ('f', 'q'): 1, ('s', 'a'): 39, ('e', 's'): 49, ('w', 'i'): 9, ('f', 'h'): 1, ('a', 'i'): 34, ('w', 'y'): 1, ('v', 't'): 3, ('o', 'h'): 21, ('y', 'n'): 9, ('o', 'p'): 6, ('e', 'p'): 23, ('i', 'd'): 13, ('s', 't'): 18, ('d', 'w'): 1, ('o', 't'): 39, ('x', 'o'): 2, ('b', 'm'): 1, ('w', 't'): 3, ('s', 'd'): 8, ('s', 'p'): 16, ('o', 's'): 21, ('h', 'u'): 4, ('w', 'h'): 17, ('l', 'z'): 1, ('g', 'u'): 5, ('e', 'z'): 1, ('a', 'o'): 16, ('m', 'o'): 7, ('g', 'h'): 7, ('l', 't'): 14, ('h', 'n'): 6, ('b', 'l'): 8, ('n', 's'): 19, ('o', 'a'): 16, ('y', 'c'): 4, ('o', 'g'): 10, ('n', 'j'): 1, ('k', 'o'): 1, ('d', 'v'): 4, ('i', 'v'): 5, ('m', 'w'): 1, ('v', 'd'): 4, ('w', 'l'): 4, ('b', 'g'): 4, ('x', 'm'): 1, ('g', 'b'): 4, ('m', 'e'): 15, ('x', 'e'): 5, ('v', 'o'): 4, ('e', 'x'): 5, ('p', 'v'): 1, ('r', 'w'): 2, ('z', 'm'): 1, ('l', 'g'): 3, ('d', 't'): 7, ('o', 'n'): 31, ('s', 'j'): 1, ('f', 'c'): 1, ('a', 'x'): 1, ('c', 'i'): 13, ('r', 'g'): 9, ('h', 'l'): 2, ('a', 'h'): 14, ('y', 't'): 7, ('p', 'e'): 23, ('h', 'i'): 16, ('t', 'w'): 3, ('l', 'e'): 31, ('f', 'r'): 7, ('m', 'z'): 1, ('m', 'b'): 1, ('i', 'e'): 24, ('i', 'k'): 4, ('j', 'y'): 1, ('d', 'e'): 16, ('p', 'w'): 1 ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-8699b78d14cf> in <module>()
#      10 b=make_itemsets(a)
#      11 englist_rules=find_assoc_rules(b,.75)
# ---> 12 common_high_conf_rules=intersect_keys(english_rules,latin_rules)
#      13 print("High-confidence rules common to _lorem ipsum_ in Latin and English:")
#      14 print_rules(common_high_conf_rules)
#
# NameError: name 'latin_rules' is not defined

# %%
# `common_high_conf_rules_test`: Test cell
assert len(common_high_conf_rules) == 2
assert ('x', 'e') in common_high_conf_rules
assert ('q', 'u') in common_high_conf_rules
print("\n(Passed!)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-108-5e53832ffee0> in <module>()
#       1 # `common_high_conf_rules_test`: Test cell
# ----> 2 assert len(common_high_conf_rules) == 2
#       3 assert ('x', 'e') in common_high_conf_rules
#       4 assert ('q', 'u') in common_high_conf_rules
#       5 print("\n(Passed!)")
#
# NameError: name 'common_high_conf_rules' is not defined

# %% [markdown]
# ## Putting it all together: Actual baskets!
#
# Let's take a look at some real data that [someone](http://www.salemmarafi.com/code/market-basket-analysis-with-r/) was kind enough to prepare for a similar exercise designed for the R programming environment.
#
# First, here's a code snippet to download the data, which is a text file:

# %%
import requests
response = requests.get ('https://cse6040.gatech.edu/datasets/groceries.csv')
groceries_file = response.text  # or response.content for raw bytes

print (groceries_file[0:250] + "...\n... (etc.) ...") # Prints the first 250 characters only
# Out:
# citrus fruit,semi-finished bread,margarine,ready soups
# tropical fruit,yogurt,coffee
# whole milk
# pip fruit,yogurt,cream cheese ,meat spreads
# other vegetables,whole milk,condensed milk,long life bakery product
# whole milk,butter,yogurt,rice,abrasive clea...
# ... (etc.) ...

# %% [markdown]
# Each line of this file is some customer's shopping basket. The items that the customer bought are stored as a comma-separated list of values.

# %% [markdown]
# **Exercise 11: Your task.** (`basket_rules_test`: 4 points). Your final task in this notebook is to mine this dataset for pairwise association rules. In particular, your code should produce (no pun intended!) a final dictionary, `basket_rules`, that meet these conditions (read carefully!):
#
# 1. The keys are pairs $(a, b)$, where $a$ and $b$ are item names (as strings).
# 2. The values are the corresponding confidence scores, $\mathrm{conf}(a \Rightarrow b)$.
# 3. Only include rules $a \Rightarrow b$ where item $a$ occurs at least `MIN_COUNT` times and $\mathrm{conf}(a \Rightarrow b)$ is at least `THRESHOLD`.
#
# Pay particular attention to Condition 3: not only do you have to filter by a confidence threshold, but you must exclude rules $a \Rightarrow b$ where the item $a$ does not appear "often enough." There is a code cell below that defines values of `MIN_COUNT` and `THRESHOLD`, but your code should work even if we decide to change those values later on.
#
# > _Aside_: Why would an analyst want to enforce Condition 3?
#
# Your solution can use the `groceries_file` string variable defined above as its starting point. And since it's in the same notebook, you may, of course, reuse any of the code you've written above as needed. Lastly, if you feel you need additional code cells, you can create them _after_ the code cell marked for your solution but _before_ the code marked, `### TEST CODE ###`.

# %%
# Confidence threshold
THRESHOLD = 0.5

# Only consider rules for items appearing at least `MIN_COUNT` times.
MIN_COUNT = 10

# %%
#
# YOUR CODE HERE
#
normal=groceries_file.splitlines()

receipt=[]
for i in range(0,len(normal)):
    receipt.append(normal[i].split(','))

pair_counts=defaultdict(int)
item_counts=defaultdict(int)
for i in receipt:
    item=update_item_counts(item_counts, i)

item2 = { key:value for key, value in item.items() if value <10 }
keys=item2.keys()
for j in receipt:
    j=j-keys
    pair= update_pair_counts (pair_counts,j)
#item = dict((k, v) for k, v in item.items() if v >= MIN_COUNT)
basket_rules=filter_rules_by_conf (pair, item, THRESHOLD)


#item2 = { key:value for key, value in item.items() if value <10 }
#entries=set(item2.keys())

#print(basket_rules)
#print(basket_rules.keys())


#for key in entries:
        #if key in basket_rules.keys()[0]:
            #del basket_rules[key]
#for k,v in basket_rules.items():
    #print(k[0])


#print(basket_rules)

# %%
### `basket_rules_test`: TEST CODE ###
print("Found {} rules whose confidence exceeds {}.".format(len(basket_rules), THRESHOLD))
print("Here they are:\n")
print_rules(basket_rules)

assert len(basket_rules) == 19
assert all([THRESHOLD <= v < 1.0 for v in basket_rules.values()])
ans_keys = [("pudding powder", "whole milk"), ("tidbits", "rolls/buns"), ("cocoa drinks", "whole milk"), ("cream", "sausage"), ("rubbing alcohol", "whole milk"), ("honey", "whole milk"), ("frozen fruits", "other vegetables"), ("cream", "other vegetables"), ("ready soups", "rolls/buns"), ("cooking chocolate", "whole milk"), ("cereals", "whole milk"), ("rice", "whole milk"), ("specialty cheese", "other vegetables"), ("baking powder", "whole milk"), ("rubbing alcohol", "butter"), ("rubbing alcohol", "citrus fruit"), ("jam", "whole milk"), ("frozen fruits", "whipped/sour cream"), ("rice", "other vegetables")]
for k in ans_keys:
    assert k in basket_rules

print("\n(Passed!)")
# Out:
# Found 19 rules whose confidence exceeds 0.5.
# Here they are:
#
# conf(honey => whole milk) = 0.733
# conf(frozen fruits => other vegetables) = 0.667
# conf(cereals => whole milk) = 0.643
# conf(rice => whole milk) = 0.613
# conf(rubbing alcohol => whole milk) = 0.600
# conf(cocoa drinks => whole milk) = 0.591
# conf(pudding powder => whole milk) = 0.565
# conf(jam => whole milk) = 0.547
# conf(cream => other vegetables) = 0.538
# conf(cream => sausage) = 0.538
# conf(baking powder => whole milk) = 0.523
# conf(tidbits => rolls/buns) = 0.522
# conf(cooking chocolate => whole milk) = 0.520
# conf(rice => other vegetables) = 0.520
# conf(frozen fruits => whipped/sour cream) = 0.500
# conf(rubbing alcohol => butter) = 0.500
# conf(rubbing alcohol => citrus fruit) = 0.500
# conf(specialty cheese => other vegetables) = 0.500
# conf(ready soups => rolls/buns) = 0.500
#
# (Passed!)
